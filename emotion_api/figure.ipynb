# %%
import matplotlib.pyplot as plt

modalities = ["Acoustic Branch", "Statistical Branch", "Semantic Branch"]
sufficiency_values = [0.0261, 0.3739, 0.0261]

plt.figure(figsize=(6, 6))
bars1 = plt.bar(modalities, sufficiency_values, color=['#4285F4', '#EA4335', '#FBBC05'], edgecolor='black', width=0.8)
plt.axhline(0.5153, color='red', linestyle='--', label=f'Baseline ({0.5153:.4f})')

#plt.title("Feature Sufficiency", fontsize=12, fontweight='bold')
plt.ylabel("Accuracy", fontsize=11)
plt.ylim(0, 0.6)
plt.grid(axis='y', linestyle=':', alpha=0.6)
plt.legend(loc='upper right')

for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.02, f"{yval:.4f}", ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

modalities = ["Acoustic Branch", "Statistical Branch", "Semantic Branch"]
necessity_values = [0.4885, 0.0958, 0.4510]

plt.figure(figsize=(6, 6))
bars2 = plt.bar(modalities, necessity_values, color=['#A0C2F9', '#F3A39C', '#FDE09A'], edgecolor='black', width=0.8)
plt.axhline(0.5153, color='red', linestyle='--', label=f'Baseline ({0.5153:.4f})')

#plt.title("Feature Necessity", fontsize=12, fontweight='bold')
plt.ylabel("Accuracy", fontsize=11)
plt.ylim(0, 0.6)
plt.grid(axis='y', linestyle=':', alpha=0.6)
plt.legend(loc='upper right')

for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.02, f"{yval:.4f}", ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

stat_features = ["Chroma\n(12 dims)", "Spectral\nContrast\n(7 dims)", "ZCR\n(1 dim)", "RMS Energy\n(1 dim)"]
sufficiency_values = [0.0785, 0.1690, 0.0261, 0.0261]

plt.figure(figsize=(6, 6))
bars1 = plt.bar(stat_features, sufficiency_values, color=['#FF9999', '#FFB366', '#FFCC99', '#FFE6CC'], edgecolor='black', width=0.8)
plt.axhline(0.5153, color='red', linestyle='--', label='Baseline (0.5153)')

plt.ylabel("Accuracy", fontsize=11)
plt.ylim(0, 0.6)
plt.grid(axis='y', linestyle=':', alpha=0.6)
plt.legend(loc='upper right')

for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.015, f"{yval:.4f}", ha='center', va='bottom', fontweight='bold', fontsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

stat_features = ["Chroma\n(12 dims)", "Spectral\nContrast\n(7 dims)", "ZCR\n(1 dim)", "RMS Energy\n(1 dim)"]
necessity_values = [0.4858, 0.0789, 0.5119, 0.5134]

plt.figure(figsize=(6, 6))
bars2 = plt.bar(stat_features, necessity_values, color=['#99CCFF', '#99E6FF', '#CCE6FF', '#E6F2FF'], edgecolor='black', width=0.8)
plt.axhline(0.5153, color='red', linestyle='--', label='Baseline (0.5153)')

plt.ylabel("Accuracy", fontsize=11)
plt.ylim(0, 0.6)
plt.grid(axis='y', linestyle=':', alpha=0.6)
plt.legend(loc='upper right')

for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.015, f"{yval:.4f}", ha='center', va='bottom', fontweight='bold', fontsize=12)

plt.tight_layout()
plt.show()
