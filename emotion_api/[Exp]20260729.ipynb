# %% [markdown]
# 1. Augmentation on.
# 2. Per-class evaluation on Augmentation and Ablation Study on different class.

# %% [markdown]
# # Section 0. Setup
# - Experiment settings (constants)
# - Setup with GPU
# - Define the 2 model architectures at the beginning

# %%
import os
import gc
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score, recall_score
from sklearn.utils import class_weight
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from tqdm import tqdm
import whisper
from transformers import pipeline
import torch
from collections import defaultdict
from datetime import datetime
import noisereduce as nr
from IPython.display import display

# Reproducibility for Reviewer Validation
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
tf.config.experimental.enable_op_determinism()

class Config:
    # Data Settings
    DATA_PATH = 'dataset_meld/'
    FILE_PREFIX = 'prepared_'
    SR = 16000
    MAX_DURATION = 3
    MAX_SAMPLES = SR * MAX_DURATION
    
    # Feature Settings
    N_MFCC = 40
    MAX_MFCC_LEN = 94  
    
    # Training Parameters 
    BATCH_SIZE = 32
    LEARNING_RATE = 0.001
    EPOCHS = 50
    DROPOUT = 0.3
    
    DEFAULT_CLASSES = ['neutral', 'joy', 'sadness', 'anger', 'fear', 'disgust', 'surprise']

print("=== Hyperparameters ===")
for k, v in vars(Config).items():
    if not k.startswith('__'): print(f"{k}: {v}")
# Out:
# === Hyperparameters ===
# DATA_PATH: dataset_meld/
# FILE_PREFIX: prepared_
# SR: 16000
# MAX_DURATION: 3
# MAX_SAMPLES: 48000
# N_MFCC: 40
# MAX_MFCC_LEN: 94
# BATCH_SIZE: 32
# LEARNING_RATE: 0.001
# EPOCHS: 50
# DROPOUT: 0.3
# DEFAULT_CLASSES: ['neutral', 'joy', 'sadness', 'anger', 'fear', 'disgust', 'surprise']

# %%
import shutil
import imageio_ffmpeg

# 1. Get the directory where imageio_ffmpeg stores its binary
ffmpeg_bin_dir = os.path.dirname(imageio_ffmpeg.get_ffmpeg_exe())

# 2. Whisper looks specifically for "ffmpeg.exe". Let's make sure a copy exists with that exact name.
target_exe = os.path.join(ffmpeg_bin_dir, "ffmpeg.exe")
if not os.path.exists(target_exe):
    shutil.copy(imageio_ffmpeg.get_ffmpeg_exe(), target_exe)

# 3. Inject this directory into the system PATH for this session
os.environ["PATH"] += os.pathsep + ffmpeg_bin_dir

# %% [markdown]
# ### Setup with GPU

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %%
# 1. Check GPU availability and set up device formatting
cuda_available = torch.cuda.is_available()
target_device = "cuda" if cuda_available else "cpu"
hf_device = 0 if cuda_available else -1

print(f"CUDA Available: {cuda_available}")
if cuda_available:
    print(f"Activating GPU: {torch.cuda.get_device_name(0)}\n")
else:
    print("GPU not detected. Running on CPU instead.\n")
# Out:
# CUDA Available: True
# Activating GPU: NVIDIA GeForce RTX 5080 Laptop GPU

# %% [markdown]
# ### Load Sentiment Classifer - RoBERTa

# %%
# Load RoBERTa Sentiment Classifier on the target device
print("Loading RoBERTa Sentiment Classifier...")
sentiment_classifier = pipeline(
    "sentiment-analysis", 
    model="cardiffnlp/twitter-roberta-base-sentiment-latest", 
    device=hf_device
)
# Out:
# Loading RoBERTa Sentiment Classifier...
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 50175.88it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment-latest
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.weight | UNEXPECTED |  |
# roberta.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# ### Define Model Architectures

# %%
# ==========================================
# 1. HYBRID CNN-LSTM — BUILDER FUNCTION
# (Instantiation happens later, after data is loaded — see Section 2/3)
# ==========================================
def build_hybrid_cnn_lstm(num_classes, stats_dim, sent_dim):
    in_mfcc = layers.Input(shape=(Config.MAX_MFCC_LEN, Config.N_MFCC), name="in_mfcc")
    x_mfcc = layers.Conv1D(64, 3, activation='relu', padding='same')(in_mfcc)
    x_mfcc = layers.MaxPooling1D(2)(x_mfcc)
    x_mfcc = layers.LSTM(64)(x_mfcc)

    in_stats = layers.Input(shape=(stats_dim,), name="in_stats")
    x_stats = layers.Dense(32, activation='relu')(in_stats)
    x_stats = layers.BatchNormalization()(x_stats)

    in_text = layers.Input(shape=(sent_dim,), name="in_text")
    x_text = layers.Dense(16, activation='relu')(in_text)

    merged = layers.Concatenate()([x_mfcc, x_stats, x_text])
    x = layers.Dense(128, activation='relu')(merged)
    x = layers.Dropout(Config.DROPOUT)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=[in_mfcc, in_stats, in_text], outputs=outputs)
    model.compile(optimizer=optimizers.Adam(learning_rate=Config.LEARNING_RATE),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# ==========================================
# 2. BAN — BUILDER FUNCTION
# ==========================================
def build_ban(num_classes, stats_dim, sent_dim):
    in_mfcc = layers.Input(shape=(Config.MAX_MFCC_LEN, Config.N_MFCC), name="in_mfcc")
    x_mfcc = layers.Conv1D(64, 3, activation='relu', padding='same')(in_mfcc)
    x_mfcc = layers.MaxPooling1D(2)(x_mfcc)
    x_mfcc = layers.LSTM(64)(x_mfcc)

    in_stats = layers.Input(shape=(stats_dim,), name="in_stats")
    x_stats = layers.Dense(32, activation='relu')(in_stats)
    x_stats = layers.BatchNormalization()(x_stats)

    x_audio_combined = layers.Concatenate()([x_mfcc, x_stats])
    x_audio_proj = layers.Dense(64, activation='relu')(x_audio_combined)

    in_text = layers.Input(shape=(sent_dim,), name="in_text")
    x_text = layers.Dense(64, activation='relu')(in_text)

    attention_weights = layers.Dense(64, activation='sigmoid', name="text_guided_attention")(x_text)
    attended_audio = layers.Multiply(name="attended_audio")([x_audio_proj, attention_weights])

    merged = layers.Concatenate()([attended_audio, x_text])
    x = layers.Dense(128, activation='relu')(merged)
    x = layers.Dropout(Config.DROPOUT)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=[in_mfcc, in_stats, in_text], outputs=outputs)
    model.compile(optimizer=optimizers.Adam(learning_rate=Config.LEARNING_RATE),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Section 1. Pre-processing and Data Augmentation
# - Silence Removal x Noise Reduction
# - Normal Data Augmentation vs Targeted Data Augmentation
#
# **Two-stage design:**
# - **Stage A**: Compare preprocessing options alone (no augmentation) → select the best.
# - **Stage B**: Apply the winning preprocessing, then compare augmentation strategies on top of it

# %%
# Preprocessing function for audio waveform
def preprocess_waveform(y, sr, clean_noise=False, trim_silence=False):
    """
    Preprocessing so its effect stays isolated from augmentation
    """
    if clean_noise:
        try:
            if len(y) > sr * 0.1:
                y = nr.reduce_noise(y=y, sr=sr, prop_decrease=0.8)
        except Exception:
            pass
    if trim_silence:
        try:
            y, _ = librosa.effects.trim(y, top_db=20)
        except Exception:
            pass
    return y

# Settings for TARGETED AUGMENTATION
STRATEGY = {
    'neutral': [],
    'joy':     ['time_stretch_fast', 'pitch_shift_up'],
    'sadness': ['time_stretch_slow', 'pitch_shift_down'],
    'anger':   ['noise', 'pitch_shift_up', 'time_stretch_fast'],
    'fear':    ['pitch_shift_up', 'time_stretch_fast', 'noise'],
    'disgust': ['time_stretch_slow', 'pitch_shift_down', 'noise'],
    'surprise':['pitch_shift_up', 'time_stretch_fast', 'noise'] 
}

def apply_augmentation(y, sr, aug_type):
    """aug_type='random' = generic normal augmentation; others = targeted methods."""
    try:
        if aug_type == 'random':
            choice = np.random.randint(0, 3)
            if choice == 0:
                return librosa.effects.time_stretch(y, rate=np.random.uniform(0.8, 1.2))
            elif choice == 1:
                return librosa.effects.pitch_shift(y, sr=sr, n_steps=np.random.randint(-2, 3))
            else:
                noise_amp = 0.005 * np.random.uniform() * np.amax(y)
                return y + noise_amp * np.random.normal(size=y.shape[0])
        elif aug_type == 'pitch_shift_up':
            return librosa.effects.pitch_shift(y, sr=sr, n_steps=np.random.uniform(1.5, 2.5))
        elif aug_type == 'pitch_shift_down':
            return librosa.effects.pitch_shift(y, sr=sr, n_steps=np.random.uniform(-2.5, -1.5))
        elif aug_type == 'time_stretch_fast':
            return librosa.effects.time_stretch(y, rate=np.random.uniform(1.1, 1.25))
        elif aug_type == 'time_stretch_slow':
            return librosa.effects.time_stretch(y, rate=np.random.uniform(0.75, 0.9))
        elif aug_type == 'noise':
            noise_amp = 0.005 * np.random.uniform() * np.amax(y)
            return y + noise_amp * np.random.normal(size=y.shape[0])
        return y
    except Exception:
        return y

# %%
# LOAD RAW SPLITS + PRECOMPUTE SENTIMENT (once — reused by every config)
def build_sentiment_annotated_df(split):
    path = os.path.join(Config.DATA_PATH, f"{split}_sent_emo.csv")
    df = pd.read_csv(path)
    df = df[df['Emotion'].str.lower().isin(Config.DEFAULT_CLASSES)].copy()

    df['file_path'] = df.apply(
        lambda r: os.path.join(Config.DATA_PATH, "audio", f"wav_{split}",
                                f"dia{r['Dialogue_ID']}_utt{r['Utterance_ID']}.wav"),
        axis=1
    )

    preds = sentiment_classifier(df['Utterance'].astype(str).tolist())
    df['textual_sentiment_predicted'] = [p['label'].lower() for p in preds]
    return df

print("Pre-annotating splits with RoBERTa sentiment (once, reused across all configs)...")
SPLIT_DFS = {split: build_sentiment_annotated_df(split) for split in ['train', 'dev', 'test']}
for split, df in SPLIT_DFS.items():
    print(f"  {split}: {len(df)} samples")
# Out:
# Pre-annotating splits with RoBERTa sentiment (once, reused across all configs)...
#   train: 9989 samples
#   dev: 1109 samples
#   test: 2610 samples

# %%
# ==========================================
# UNIFIED FEATURE EXTRACTOR (routes 'none' / 'normal' / 'targeted')
# ==========================================
def process_single_row(row, clean_noise, trim_silence, aug_type=None):
    # --- Guard 1: file existence check (fast path, avoids librosa exception overhead) ---
    if not os.path.exists(row['file_path']):
        return None, 'missing_file'

    # --- Guard 2: load failure (corrupt/unreadable audio) ---
    try:
        y, _ = librosa.load(row['file_path'], sr=Config.SR)
    except Exception:
        return None, 'load_failed'

    if len(y) < 500:
        return None, 'too_short'

    y = preprocess_waveform(y, Config.SR, clean_noise, trim_silence)
    if aug_type is not None:
        y = apply_augmentation(y, Config.SR, aug_type)
    if len(y) < 500:
        return None, 'too_short_after_processing'

    if len(y) > Config.MAX_SAMPLES:
        y = y[:Config.MAX_SAMPLES]
    else:
        y = np.pad(y, (0, int(Config.MAX_SAMPLES - len(y))), 'constant')

    mfcc = librosa.feature.mfcc(y=y, sr=Config.SR, n_mfcc=Config.N_MFCC).T
    if mfcc.shape[0] > Config.MAX_MFCC_LEN:
        mfcc = mfcc[:Config.MAX_MFCC_LEN, :]
    else:
        mfcc = np.pad(mfcc, ((0, Config.MAX_MFCC_LEN - mfcc.shape[0]), (0, 0)), 'constant')

    try:
        chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=Config.SR).T, axis=0)
        contrast = np.mean(librosa.feature.spectral_contrast(y=y, sr=Config.SR).T, axis=0)
        zcr = np.mean(librosa.feature.zero_crossing_rate(y=y).T, axis=0)
        rms = np.mean(librosa.feature.rms(y=y).T, axis=0)
        stats = np.hstack([chroma, contrast, zcr, rms])
    except Exception:
        return None, 'stats_extraction_failed'

    return (mfcc, stats), None


def extract_features_for_config(df, clean_noise=False, trim_silence=False,
                                 augmentation='none', is_train=True, target_count=1700):
    X_mfcc, X_stats, X_sent, y_labels = [], [], [], []
    skip_counts = defaultdict(int)

    if augmentation == 'targeted' and is_train:
        for emotion in Config.DEFAULT_CLASSES:
            sub_df = df[df['Emotion'].str.lower() == emotion]
            if len(sub_df) == 0:
                continue
            if len(sub_df) > target_count:
                sub_df = sub_df.sample(n=target_count, random_state=SEED)
                multiplier = 1
            else:
                multiplier = max(1, int(np.ceil(target_count / len(sub_df))))
            aug_methods = STRATEGY.get(emotion, ['random'])

            for _, row in tqdm(sub_df.iterrows(), total=len(sub_df), desc=f"[{emotion}]"):
                for i in range(multiplier):
                    aug_type = aug_methods[i % len(aug_methods)] if (i > 0 and aug_methods) else None
                    result, fail_reason = process_single_row(row, clean_noise, trim_silence, aug_type)
                    if result is None:
                        skip_counts[fail_reason] += 1
                        continue
                    mfcc, stats = result
                    X_mfcc.append(mfcc); X_stats.append(stats)
                    X_sent.append(row['textual_sentiment_predicted'])
                    y_labels.append(emotion)
    else:
        for _, row in tqdm(df.iterrows(), total=len(df)):
            aug_type = 'random' if (augmentation == 'normal' and is_train) else None
            result, fail_reason = process_single_row(row, clean_noise, trim_silence, aug_type)
            if result is None:
                skip_counts[fail_reason] += 1
                continue
            mfcc, stats = result
            X_mfcc.append(mfcc); X_stats.append(stats)
            X_sent.append(row['textual_sentiment_predicted'])
            y_labels.append(row['Emotion'].lower())

    total_skipped = sum(skip_counts.values())
    print(f"  ⚠️ Skipped {total_skipped} samples: {dict(skip_counts)}")

    return np.array(X_mfcc), np.array(X_stats), np.array(X_sent), np.array(y_labels), dict(skip_counts)

# %%
# DATA PREP FOR A GIVEN CONFIG + TRAINING WRAPPER
def prepare_and_encode(clean_noise, trim_silence, augmentation):
    label_encoder = LabelEncoder().fit(Config.DEFAULT_CLASSES)
    sent_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

    splits_out = {}
    skip_report = {}
    for split in ['train', 'dev', 'test']:
        m, s, txt, y, skips = extract_features_for_config(
            SPLIT_DFS[split], clean_noise=clean_noise, trim_silence=trim_silence,
            augmentation=augmentation, is_train=(split == 'train')
        )
        splits_out[split] = {'mfcc': m, 'stats': s, 'sent_raw': txt, 'y_raw': y}
        skip_report[split] = skips

    scaler = StandardScaler().fit(splits_out['train']['stats'])
    sent_encoder.fit(splits_out['train']['sent_raw'].reshape(-1, 1))

    for split in splits_out:
        splits_out[split]['stats'] = scaler.transform(splits_out[split]['stats'])
        splits_out[split]['sent'] = sent_encoder.transform(splits_out[split]['sent_raw'].reshape(-1, 1))
        splits_out[split]['y'] = label_encoder.transform(splits_out[split]['y_raw'])

    return splits_out, skip_report

def print_per_class_matrix(results_dict, metric='per_class_recall', title=""):
    """
    results_dict: e.g. stageA_hybrid, where each value is the dict returned by run_training
    metric: 'per_class_recall' or 'per_class_f1'
    """
    matrix = pd.DataFrame({
        config_name: result[metric] for config_name, result in results_dict.items()
    }).T  # rows = config, columns = class

    matrix['Overall Accuracy'] = [results_dict[c]['test_accuracy'] for c in results_dict]

    print(f"\n=== {title} ({metric}) ===")
    print(matrix.round(4).to_string())
    return matrix

def run_training(model_builder, splits_out, model_name=""):
    tf.keras.backend.clear_session(); gc.collect()

    X_train = [splits_out['train']['mfcc'], splits_out['train']['stats'], splits_out['train']['sent']]
    X_dev   = [splits_out['dev']['mfcc'],   splits_out['dev']['stats'],   splits_out['dev']['sent']]
    X_test  = [splits_out['test']['mfcc'],  splits_out['test']['stats'],  splits_out['test']['sent']]
    y_train, y_dev, y_test = splits_out['train']['y'], splits_out['dev']['y'], splits_out['test']['y']

    model = model_builder(len(Config.DEFAULT_CLASSES), X_train[1].shape[1], X_train[2].shape[1])

    hist = model.fit(
        X_train, y_train, validation_data=(X_dev, y_dev),
        epochs=Config.EPOCHS, batch_size=Config.BATCH_SIZE, verbose=1
    )

    y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

    # Per-class recall, in the same label order as Config.DEFAULT_CLASSES
    # (label_encoder.transform gives 0..N-1 in this same sorted/fitted order)
    all_labels = list(range(len(Config.DEFAULT_CLASSES)))
    per_class_recall = recall_score(y_test, y_pred, average=None, labels=all_labels, zero_division=0)
    per_class_f1     = f1_score(y_test, y_pred, average=None, labels=all_labels, zero_division=0)

    per_class_recall_dict = dict(zip(Config.DEFAULT_CLASSES, per_class_recall))
    per_class_f1_dict     = dict(zip(Config.DEFAULT_CLASSES, per_class_f1))

    return {
        'model_name': model_name,
        'val_accuracy': max(hist.history['val_accuracy']),
        'test_accuracy': accuracy_score(y_test, y_pred),
        'test_macro_recall': recall_score(y_test, y_pred, average='macro'),
        'test_macro_f1': f1_score(y_test, y_pred, average='macro'),
        'per_class_recall': per_class_recall_dict,
        'per_class_f1': per_class_f1_dict,
    }

# %%
# ==========================================
# STAGE A: PREPROCESSING ONLY (no augmentation)
# ==========================================
PREPROCESS_CONFIGS = {
    "P0_None":        {"clean_noise": False, "trim_silence": False},
    "P1_SilenceOnly":  {"clean_noise": False, "trim_silence": True},
    "P2_NoiseOnly":    {"clean_noise": True,  "trim_silence": False},
    "P3_Both":         {"clean_noise": True,  "trim_silence": True},
}

stageA_hybrid, stageA_ban, stageA_skips = {}, {}, {}
stageA_splits_cache = {}

for name, cfg in PREPROCESS_CONFIGS.items():
    print(f"\n=== Stage A: {name} ===")
    splits_out, skip_report = prepare_and_encode(cfg['clean_noise'], cfg['trim_silence'], augmentation='none')
    stageA_splits_cache[name] = (splits_out, cfg)
    stageA_skips[name] = skip_report

    stageA_hybrid[name] = run_training(build_hybrid_cnn_lstm, splits_out, "Hybrid")
    stageA_ban[name]    = run_training(build_ban, splits_out, "BAN")

    total_skipped = sum(sum(v.values()) for v in skip_report.values())
    print(f"{name}: Hybrid test={stageA_hybrid[name]['test_accuracy']:.4f} | "
          f"BAN test={stageA_ban[name]['test_accuracy']:.4f} | Total skipped samples: {total_skipped}")
    del splits_out; gc.collect()

recall_matrix_hybrid = print_per_class_matrix(stageA_hybrid, metric='per_class_recall', title="Hybrid CNN-LSTM — Preprocessing Configs")
recall_matrix_ban    = print_per_class_matrix(stageA_ban,    metric='per_class_recall', title="BAN — Preprocessing Configs")
# Out:
# === Stage A: P0_None ===
# 100%|██████████| 9989/9989 [02:24<00:00, 68.96it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 1109/1109 [00:15<00:00, 72.74it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 2610/2610 [00:35<00:00, 72.82it/s]
#   ⚠️ Skipped 0 samples: {}
# WARNING:tensorflow:From c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4816 - loss: 1.4916 - val_accuracy: 0.4702 - val_loss: 1.4942
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5101 - loss: 1.3993 - val_accuracy: 0.4711 - val_loss: 1.4901
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5099 - loss: 1.3853 - val_accuracy: 0.4747 - val_loss: 1.4913
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5206 - loss: 1.3751 - val_accuracy: 0.4783 - val_loss: 1.4916
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5194 - loss: 1.3709 - val_accuracy: 0.4738 - val_loss: 1.4907
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5257 - loss: 1.3601 - val_accuracy: 0.4747 - val_loss: 1.4940
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5229 - loss: 1.3577 - val_accuracy: 0.4738 - val_loss: 1.5071
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5256 - loss: 1.3574 - val_accuracy: 0.4756 - val_loss: 1.4971
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5259 - loss: 1.3473 - val_accuracy: 0.4738 - val_loss: 1.5148
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5284 - loss: 1.3490 - val_accuracy: 0.4702 - val_loss: 1.5007
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5293 - loss: 1.3430 - val_accuracy: 0.4774 - val_loss: 1.5108
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5330 - loss: 1.3323 - val_accuracy: 0.4765 - val_loss: 1.5191
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5297 - loss: 1.3306 - val_accuracy: 0.4774 - val_loss: 1.5230
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5294 - loss: 1.3270 - val_accuracy: 0.4738 - val_loss: 1.5200
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5313 - loss: 1.3222 - val_accuracy: 0.4774 - val_loss: 1.5203
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5329 - loss: 1.3179 - val_accuracy: 0.4829 - val_loss: 1.5268
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5354 - loss: 1.3121 - val_accuracy: 0.4819 - val_loss: 1.5324
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5401 - loss: 1.3066 - val_accuracy: 0.4774 - val_loss: 1.5409
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5353 - loss: 1.3100 - val_accuracy: 0.4747 - val_loss: 1.5483
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5359 - loss: 1.3020 - val_accuracy: 0.4747 - val_loss: 1.5492
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5387 - loss: 1.3070 - val_accuracy: 0.4711 - val_loss: 1.5417
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5400 - loss: 1.2992 - val_accuracy: 0.4774 - val_loss: 1.5444
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5413 - loss: 1.2917 - val_accuracy: 0.4783 - val_loss: 1.5480
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5425 - loss: 1.2909 - val_accuracy: 0.4729 - val_loss: 1.5454
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5437 - loss: 1.2822 - val_accuracy: 0.4810 - val_loss: 1.5551
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5425 - loss: 1.2814 - val_accuracy: 0.4783 - val_loss: 1.5580
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5447 - loss: 1.2770 - val_accuracy: 0.4792 - val_loss: 1.5617
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5472 - loss: 1.2701 - val_accuracy: 0.4792 - val_loss: 1.5661
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5460 - loss: 1.2664 - val_accuracy: 0.4819 - val_loss: 1.5698
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5508 - loss: 1.2676 - val_accuracy: 0.4819 - val_loss: 1.5693
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5455 - loss: 1.2653 - val_accuracy: 0.4711 - val_loss: 1.5758
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5492 - loss: 1.2635 - val_accuracy: 0.4774 - val_loss: 1.5707
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5525 - loss: 1.2553 - val_accuracy: 0.4792 - val_loss: 1.5750
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5496 - loss: 1.2555 - val_accuracy: 0.4819 - val_loss: 1.5822
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5535 - loss: 1.2509 - val_accuracy: 0.4747 - val_loss: 1.5890
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5527 - loss: 1.2540 - val_accuracy: 0.4729 - val_loss: 1.5846
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5522 - loss: 1.2487 - val_accuracy: 0.4738 - val_loss: 1.5940
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5555 - loss: 1.2441 - val_accuracy: 0.4829 - val_loss: 1.5822
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5592 - loss: 1.2385 - val_accuracy: 0.4774 - val_loss: 1.5917
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5524 - loss: 1.2345 - val_accuracy: 0.4801 - val_loss: 1.5924
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5546 - loss: 1.2408 - val_accuracy: 0.4756 - val_loss: 1.6000
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5526 - loss: 1.2343 - val_accuracy: 0.4792 - val_loss: 1.6174
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5601 - loss: 1.2251 - val_accuracy: 0.4711 - val_loss: 1.6219
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5590 - loss: 1.2183 - val_accuracy: 0.4729 - val_loss: 1.6235
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5573 - loss: 1.2223 - val_accuracy: 0.4720 - val_loss: 1.6272
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5607 - loss: 1.2208 - val_accuracy: 0.4711 - val_loss: 1.6334
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5585 - loss: 1.2164 - val_accuracy: 0.4720 - val_loss: 1.6275
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5619 - loss: 1.2083 - val_accuracy: 0.4729 - val_loss: 1.6329
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5656 - loss: 1.2120 - val_accuracy: 0.4774 - val_loss: 1.6326
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5659 - loss: 1.2065 - val_accuracy: 0.4711 - val_loss: 1.6525
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5019 - loss: 1.4288 - val_accuracy: 0.4702 - val_loss: 1.4808
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5128 - loss: 1.3844 - val_accuracy: 0.4747 - val_loss: 1.4759
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5168 - loss: 1.3766 - val_accuracy: 0.4783 - val_loss: 1.4802
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5225 - loss: 1.3652 - val_accuracy: 0.4774 - val_loss: 1.4803
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5251 - loss: 1.3594 - val_accuracy: 0.4783 - val_loss: 1.4822
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5271 - loss: 1.3533 - val_accuracy: 0.4774 - val_loss: 1.4865
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5243 - loss: 1.3455 - val_accuracy: 0.4765 - val_loss: 1.4922
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5282 - loss: 1.3341 - val_accuracy: 0.4792 - val_loss: 1.4887
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5332 - loss: 1.3303 - val_accuracy: 0.4829 - val_loss: 1.4972
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5305 - loss: 1.3218 - val_accuracy: 0.4829 - val_loss: 1.4930
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5340 - loss: 1.3182 - val_accuracy: 0.4810 - val_loss: 1.5110
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5318 - loss: 1.3144 - val_accuracy: 0.4765 - val_loss: 1.5179
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5340 - loss: 1.3100 - val_accuracy: 0.4765 - val_loss: 1.5167
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5390 - loss: 1.3005 - val_accuracy: 0.4747 - val_loss: 1.5258
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5371 - loss: 1.2954 - val_accuracy: 0.4657 - val_loss: 1.5296
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5422 - loss: 1.2842 - val_accuracy: 0.4684 - val_loss: 1.5442
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5436 - loss: 1.2710 - val_accuracy: 0.4720 - val_loss: 1.5580
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5452 - loss: 1.2663 - val_accuracy: 0.4693 - val_loss: 1.5610
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5479 - loss: 1.2573 - val_accuracy: 0.4729 - val_loss: 1.5656
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5458 - loss: 1.2537 - val_accuracy: 0.4675 - val_loss: 1.5737
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5527 - loss: 1.2408 - val_accuracy: 0.4657 - val_loss: 1.5874
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5557 - loss: 1.2303 - val_accuracy: 0.4702 - val_loss: 1.6014
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5559 - loss: 1.2266 - val_accuracy: 0.4738 - val_loss: 1.6220
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5597 - loss: 1.2144 - val_accuracy: 0.4666 - val_loss: 1.6287
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5600 - loss: 1.2104 - val_accuracy: 0.4648 - val_loss: 1.6425
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5621 - loss: 1.1968 - val_accuracy: 0.4702 - val_loss: 1.6416
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5664 - loss: 1.1897 - val_accuracy: 0.4747 - val_loss: 1.6601
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5684 - loss: 1.1831 - val_accuracy: 0.4711 - val_loss: 1.6554
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5704 - loss: 1.1708 - val_accuracy: 0.4522 - val_loss: 1.6964
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5734 - loss: 1.1654 - val_accuracy: 0.4657 - val_loss: 1.6961
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5768 - loss: 1.1542 - val_accuracy: 0.4657 - val_loss: 1.7012
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5774 - loss: 1.1452 - val_accuracy: 0.4594 - val_loss: 1.7125
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5846 - loss: 1.1374 - val_accuracy: 0.4458 - val_loss: 1.7553
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5844 - loss: 1.1290 - val_accuracy: 0.4558 - val_loss: 1.7662
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5856 - loss: 1.1216 - val_accuracy: 0.4495 - val_loss: 1.7685
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5909 - loss: 1.1111 - val_accuracy: 0.4486 - val_loss: 1.7657
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5920 - loss: 1.1071 - val_accuracy: 0.4603 - val_loss: 1.7734
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5944 - loss: 1.0937 - val_accuracy: 0.4612 - val_loss: 1.8546
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5994 - loss: 1.0916 - val_accuracy: 0.4531 - val_loss: 1.8460
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5973 - loss: 1.0809 - val_accuracy: 0.4522 - val_loss: 1.8452
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6075 - loss: 1.0638 - val_accuracy: 0.4504 - val_loss: 1.9011
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6039 - loss: 1.0653 - val_accuracy: 0.4540 - val_loss: 1.8934
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6050 - loss: 1.0642 - val_accuracy: 0.4413 - val_loss: 1.9060
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6046 - loss: 1.0539 - val_accuracy: 0.4531 - val_loss: 1.9014
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6096 - loss: 1.0453 - val_accuracy: 0.4495 - val_loss: 1.9303
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6137 - loss: 1.0373 - val_accuracy: 0.4522 - val_loss: 1.9423
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6170 - loss: 1.0302 - val_accuracy: 0.4449 - val_loss: 1.9770
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6176 - loss: 1.0210 - val_accuracy: 0.4540 - val_loss: 1.9750
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6196 - loss: 1.0207 - val_accuracy: 0.4513 - val_loss: 2.0136
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6171 - loss: 1.0112 - val_accuracy: 0.4395 - val_loss: 1.9907
# P0_None: Hybrid test=0.5046 | BAN test=0.4812 | Total skipped samples: 2
#
# === Stage A: P1_SilenceOnly ===
# 100%|██████████| 9989/9989 [01:26<00:00, 115.64it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 1109/1109 [00:09<00:00, 116.38it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 2610/2610 [00:22<00:00, 116.78it/s]
#   ⚠️ Skipped 0 samples: {}
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4786 - loss: 1.4906 - val_accuracy: 0.4783 - val_loss: 1.4941
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5092 - loss: 1.4014 - val_accuracy: 0.4829 - val_loss: 1.4890
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5140 - loss: 1.3846 - val_accuracy: 0.4765 - val_loss: 1.4742
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5178 - loss: 1.3746 - val_accuracy: 0.4774 - val_loss: 1.4710
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5171 - loss: 1.3698 - val_accuracy: 0.4783 - val_loss: 1.4690
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5220 - loss: 1.3600 - val_accuracy: 0.4801 - val_loss: 1.4750
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5243 - loss: 1.3504 - val_accuracy: 0.4865 - val_loss: 1.4704
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5238 - loss: 1.3496 - val_accuracy: 0.4856 - val_loss: 1.4744
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5265 - loss: 1.3448 - val_accuracy: 0.4792 - val_loss: 1.4743
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5301 - loss: 1.3350 - val_accuracy: 0.4774 - val_loss: 1.4814
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5311 - loss: 1.3290 - val_accuracy: 0.4810 - val_loss: 1.4727
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5341 - loss: 1.3206 - val_accuracy: 0.4810 - val_loss: 1.4752
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5340 - loss: 1.3178 - val_accuracy: 0.4819 - val_loss: 1.4852
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5376 - loss: 1.3087 - val_accuracy: 0.4801 - val_loss: 1.4947
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5389 - loss: 1.2985 - val_accuracy: 0.4819 - val_loss: 1.4974
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5388 - loss: 1.3016 - val_accuracy: 0.4747 - val_loss: 1.5120
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5426 - loss: 1.2908 - val_accuracy: 0.4783 - val_loss: 1.5089
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5455 - loss: 1.2852 - val_accuracy: 0.4729 - val_loss: 1.5119
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5435 - loss: 1.2807 - val_accuracy: 0.4747 - val_loss: 1.5161
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5465 - loss: 1.2749 - val_accuracy: 0.4729 - val_loss: 1.5186
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5475 - loss: 1.2645 - val_accuracy: 0.4792 - val_loss: 1.5320
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5540 - loss: 1.2546 - val_accuracy: 0.4756 - val_loss: 1.5403
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5540 - loss: 1.2476 - val_accuracy: 0.4783 - val_loss: 1.5352
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5570 - loss: 1.2354 - val_accuracy: 0.4738 - val_loss: 1.5437
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5638 - loss: 1.2272 - val_accuracy: 0.4747 - val_loss: 1.5600
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5609 - loss: 1.2210 - val_accuracy: 0.4774 - val_loss: 1.5580
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5677 - loss: 1.2122 - val_accuracy: 0.4738 - val_loss: 1.5796
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5689 - loss: 1.2036 - val_accuracy: 0.4792 - val_loss: 1.5742
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5713 - loss: 1.1929 - val_accuracy: 0.4738 - val_loss: 1.5916
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5757 - loss: 1.1858 - val_accuracy: 0.4648 - val_loss: 1.5956
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5762 - loss: 1.1763 - val_accuracy: 0.4783 - val_loss: 1.5863
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5823 - loss: 1.1611 - val_accuracy: 0.4684 - val_loss: 1.5959
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5857 - loss: 1.1494 - val_accuracy: 0.4675 - val_loss: 1.6414
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5900 - loss: 1.1465 - val_accuracy: 0.4756 - val_loss: 1.6119
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5916 - loss: 1.1338 - val_accuracy: 0.4702 - val_loss: 1.6347
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5919 - loss: 1.1242 - val_accuracy: 0.4801 - val_loss: 1.6647
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5949 - loss: 1.1189 - val_accuracy: 0.4792 - val_loss: 1.6596
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5984 - loss: 1.1104 - val_accuracy: 0.4675 - val_loss: 1.6691
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6048 - loss: 1.0979 - val_accuracy: 0.4648 - val_loss: 1.6953
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6093 - loss: 1.0814 - val_accuracy: 0.4747 - val_loss: 1.7274
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6086 - loss: 1.0745 - val_accuracy: 0.4594 - val_loss: 1.7492
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6118 - loss: 1.0693 - val_accuracy: 0.4594 - val_loss: 1.7618
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6092 - loss: 1.0727 - val_accuracy: 0.4567 - val_loss: 1.7772
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6235 - loss: 1.0451 - val_accuracy: 0.4549 - val_loss: 1.8192
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6252 - loss: 1.0338 - val_accuracy: 0.4531 - val_loss: 1.8105
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6305 - loss: 1.0234 - val_accuracy: 0.4477 - val_loss: 1.8380
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6386 - loss: 1.0067 - val_accuracy: 0.4440 - val_loss: 1.8293
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6405 - loss: 0.9992 - val_accuracy: 0.4440 - val_loss: 1.8514
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6413 - loss: 0.9958 - val_accuracy: 0.4386 - val_loss: 1.8989
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6407 - loss: 0.9826 - val_accuracy: 0.4341 - val_loss: 1.8876
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4942 - loss: 1.4384 - val_accuracy: 0.4693 - val_loss: 1.4820
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5178 - loss: 1.3843 - val_accuracy: 0.4756 - val_loss: 1.4742
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5203 - loss: 1.3791 - val_accuracy: 0.4765 - val_loss: 1.4804
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5227 - loss: 1.3686 - val_accuracy: 0.4747 - val_loss: 1.4780
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5204 - loss: 1.3614 - val_accuracy: 0.4720 - val_loss: 1.4881
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5260 - loss: 1.3555 - val_accuracy: 0.4765 - val_loss: 1.4826
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5283 - loss: 1.3486 - val_accuracy: 0.4747 - val_loss: 1.4829
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5295 - loss: 1.3386 - val_accuracy: 0.4684 - val_loss: 1.4911
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5324 - loss: 1.3330 - val_accuracy: 0.4747 - val_loss: 1.4905
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5360 - loss: 1.3208 - val_accuracy: 0.4792 - val_loss: 1.4973
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5361 - loss: 1.3174 - val_accuracy: 0.4720 - val_loss: 1.4967
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5374 - loss: 1.3095 - val_accuracy: 0.4693 - val_loss: 1.5013
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5410 - loss: 1.3037 - val_accuracy: 0.4639 - val_loss: 1.5136
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5443 - loss: 1.2926 - val_accuracy: 0.4765 - val_loss: 1.5215
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5425 - loss: 1.2843 - val_accuracy: 0.4603 - val_loss: 1.5437
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5450 - loss: 1.2798 - val_accuracy: 0.4666 - val_loss: 1.5471
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5484 - loss: 1.2721 - val_accuracy: 0.4621 - val_loss: 1.5461
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5528 - loss: 1.2571 - val_accuracy: 0.4621 - val_loss: 1.5646
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5499 - loss: 1.2482 - val_accuracy: 0.4540 - val_loss: 1.5779
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5545 - loss: 1.2420 - val_accuracy: 0.4594 - val_loss: 1.5781
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5601 - loss: 1.2358 - val_accuracy: 0.4603 - val_loss: 1.5738
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5607 - loss: 1.2261 - val_accuracy: 0.4594 - val_loss: 1.5945
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5662 - loss: 1.2125 - val_accuracy: 0.4612 - val_loss: 1.6204
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5674 - loss: 1.2033 - val_accuracy: 0.4612 - val_loss: 1.6265
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5699 - loss: 1.1963 - val_accuracy: 0.4594 - val_loss: 1.6371
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5734 - loss: 1.1805 - val_accuracy: 0.4603 - val_loss: 1.6462
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5749 - loss: 1.1740 - val_accuracy: 0.4567 - val_loss: 1.6526
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5742 - loss: 1.1701 - val_accuracy: 0.4567 - val_loss: 1.6823
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5759 - loss: 1.1639 - val_accuracy: 0.4585 - val_loss: 1.6767
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5836 - loss: 1.1562 - val_accuracy: 0.4612 - val_loss: 1.6913
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5847 - loss: 1.1438 - val_accuracy: 0.4621 - val_loss: 1.7238
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5849 - loss: 1.1482 - val_accuracy: 0.4594 - val_loss: 1.7335
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5860 - loss: 1.1357 - val_accuracy: 0.4468 - val_loss: 1.7624
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5910 - loss: 1.1293 - val_accuracy: 0.4486 - val_loss: 1.7745
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5894 - loss: 1.1206 - val_accuracy: 0.4504 - val_loss: 1.7924
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5992 - loss: 1.1038 - val_accuracy: 0.4359 - val_loss: 1.7980
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6016 - loss: 1.0959 - val_accuracy: 0.4395 - val_loss: 1.8487
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6053 - loss: 1.0859 - val_accuracy: 0.4431 - val_loss: 1.8611
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6050 - loss: 1.0779 - val_accuracy: 0.4422 - val_loss: 1.8850
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6009 - loss: 1.0869 - val_accuracy: 0.4449 - val_loss: 1.8751
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6053 - loss: 1.0805 - val_accuracy: 0.4413 - val_loss: 1.8737
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6137 - loss: 1.0588 - val_accuracy: 0.4377 - val_loss: 1.9217
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6172 - loss: 1.0449 - val_accuracy: 0.4332 - val_loss: 1.9620
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6161 - loss: 1.0443 - val_accuracy: 0.4413 - val_loss: 1.9611
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6227 - loss: 1.0244 - val_accuracy: 0.4341 - val_loss: 1.9630
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6236 - loss: 1.0297 - val_accuracy: 0.4341 - val_loss: 2.0189
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6243 - loss: 1.0201 - val_accuracy: 0.4296 - val_loss: 2.0257
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6316 - loss: 1.0010 - val_accuracy: 0.4278 - val_loss: 2.0659
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6220 - loss: 1.0169 - val_accuracy: 0.4368 - val_loss: 2.0677
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6326 - loss: 1.0073 - val_accuracy: 0.4260 - val_loss: 2.0457
# P1_SilenceOnly: Hybrid test=0.4801 | BAN test=0.4789 | Total skipped samples: 2
#
# === Stage A: P2_NoiseOnly ===
# 100%|██████████| 9989/9989 [06:15<00:00, 26.59it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 1109/1109 [00:41<00:00, 26.68it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 2610/2610 [01:42<00:00, 25.58it/s]
#   ⚠️ Skipped 0 samples: {}
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4758 - loss: 1.4996 - val_accuracy: 0.4756 - val_loss: 1.4872
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5048 - loss: 1.4045 - val_accuracy: 0.4765 - val_loss: 1.4813
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5177 - loss: 1.3868 - val_accuracy: 0.4792 - val_loss: 1.4787
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5174 - loss: 1.3765 - val_accuracy: 0.4801 - val_loss: 1.4798
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5181 - loss: 1.3734 - val_accuracy: 0.4801 - val_loss: 1.4786
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5210 - loss: 1.3675 - val_accuracy: 0.4765 - val_loss: 1.4794
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5264 - loss: 1.3631 - val_accuracy: 0.4738 - val_loss: 1.4807
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5258 - loss: 1.3519 - val_accuracy: 0.4765 - val_loss: 1.4856
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5244 - loss: 1.3517 - val_accuracy: 0.4774 - val_loss: 1.4804
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5286 - loss: 1.3461 - val_accuracy: 0.4829 - val_loss: 1.4880
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5300 - loss: 1.3423 - val_accuracy: 0.4829 - val_loss: 1.4775
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5332 - loss: 1.3328 - val_accuracy: 0.4747 - val_loss: 1.4790
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5330 - loss: 1.3309 - val_accuracy: 0.4783 - val_loss: 1.4953
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5338 - loss: 1.3266 - val_accuracy: 0.4819 - val_loss: 1.4928
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5349 - loss: 1.3238 - val_accuracy: 0.4783 - val_loss: 1.4972
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5384 - loss: 1.3139 - val_accuracy: 0.4810 - val_loss: 1.4875
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5383 - loss: 1.3160 - val_accuracy: 0.4801 - val_loss: 1.5025
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5359 - loss: 1.3158 - val_accuracy: 0.4756 - val_loss: 1.5042
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5405 - loss: 1.3092 - val_accuracy: 0.4819 - val_loss: 1.5035
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5377 - loss: 1.3073 - val_accuracy: 0.4747 - val_loss: 1.5094
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5380 - loss: 1.3070 - val_accuracy: 0.4765 - val_loss: 1.5102
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5421 - loss: 1.2994 - val_accuracy: 0.4738 - val_loss: 1.5073
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5470 - loss: 1.2932 - val_accuracy: 0.4765 - val_loss: 1.5041
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5471 - loss: 1.2882 - val_accuracy: 0.4756 - val_loss: 1.5083
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5449 - loss: 1.2879 - val_accuracy: 0.4684 - val_loss: 1.5344
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5424 - loss: 1.2881 - val_accuracy: 0.4774 - val_loss: 1.5287
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5449 - loss: 1.2870 - val_accuracy: 0.4684 - val_loss: 1.5334
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5493 - loss: 1.2795 - val_accuracy: 0.4666 - val_loss: 1.5357
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5498 - loss: 1.2774 - val_accuracy: 0.4612 - val_loss: 1.5396
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5477 - loss: 1.2676 - val_accuracy: 0.4648 - val_loss: 1.5327
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5506 - loss: 1.2672 - val_accuracy: 0.4603 - val_loss: 1.5362
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5522 - loss: 1.2592 - val_accuracy: 0.4729 - val_loss: 1.5450
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5531 - loss: 1.2594 - val_accuracy: 0.4720 - val_loss: 1.5490
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5518 - loss: 1.2534 - val_accuracy: 0.4765 - val_loss: 1.5485
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5504 - loss: 1.2444 - val_accuracy: 0.4657 - val_loss: 1.5475
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5560 - loss: 1.2427 - val_accuracy: 0.4648 - val_loss: 1.5541
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5568 - loss: 1.2390 - val_accuracy: 0.4675 - val_loss: 1.5730
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5606 - loss: 1.2371 - val_accuracy: 0.4720 - val_loss: 1.5665
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5585 - loss: 1.2379 - val_accuracy: 0.4765 - val_loss: 1.5848
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5530 - loss: 1.2380 - val_accuracy: 0.4630 - val_loss: 1.5886
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5594 - loss: 1.2306 - val_accuracy: 0.4612 - val_loss: 1.5944
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5603 - loss: 1.2237 - val_accuracy: 0.4639 - val_loss: 1.6025
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5580 - loss: 1.2256 - val_accuracy: 0.4603 - val_loss: 1.6040
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5624 - loss: 1.2173 - val_accuracy: 0.4630 - val_loss: 1.6054
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5607 - loss: 1.2169 - val_accuracy: 0.4621 - val_loss: 1.6221
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5618 - loss: 1.2186 - val_accuracy: 0.4567 - val_loss: 1.6138
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5603 - loss: 1.2144 - val_accuracy: 0.4639 - val_loss: 1.6248
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5616 - loss: 1.2059 - val_accuracy: 0.4540 - val_loss: 1.6194
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5664 - loss: 1.1986 - val_accuracy: 0.4621 - val_loss: 1.6314
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5656 - loss: 1.1959 - val_accuracy: 0.4612 - val_loss: 1.6385
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5035 - loss: 1.4300 - val_accuracy: 0.4729 - val_loss: 1.4795
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5146 - loss: 1.3907 - val_accuracy: 0.4711 - val_loss: 1.4807
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5201 - loss: 1.3793 - val_accuracy: 0.4738 - val_loss: 1.4758
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5219 - loss: 1.3723 - val_accuracy: 0.4765 - val_loss: 1.4734
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5239 - loss: 1.3645 - val_accuracy: 0.4774 - val_loss: 1.4788
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5211 - loss: 1.3619 - val_accuracy: 0.4765 - val_loss: 1.4883
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5262 - loss: 1.3532 - val_accuracy: 0.4720 - val_loss: 1.4899
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5260 - loss: 1.3448 - val_accuracy: 0.4720 - val_loss: 1.4958
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5312 - loss: 1.3410 - val_accuracy: 0.4720 - val_loss: 1.5010
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5294 - loss: 1.3328 - val_accuracy: 0.4720 - val_loss: 1.5091
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5314 - loss: 1.3244 - val_accuracy: 0.4738 - val_loss: 1.5195
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5347 - loss: 1.3195 - val_accuracy: 0.4648 - val_loss: 1.5288
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5400 - loss: 1.3090 - val_accuracy: 0.4702 - val_loss: 1.5377
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5381 - loss: 1.3021 - val_accuracy: 0.4702 - val_loss: 1.5357
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5380 - loss: 1.2979 - val_accuracy: 0.4711 - val_loss: 1.5445
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5444 - loss: 1.2857 - val_accuracy: 0.4684 - val_loss: 1.5533
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5445 - loss: 1.2781 - val_accuracy: 0.4639 - val_loss: 1.5573
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5500 - loss: 1.2703 - val_accuracy: 0.4612 - val_loss: 1.5698
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5525 - loss: 1.2658 - val_accuracy: 0.4666 - val_loss: 1.5893
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5529 - loss: 1.2553 - val_accuracy: 0.4639 - val_loss: 1.6052
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5575 - loss: 1.2464 - val_accuracy: 0.4612 - val_loss: 1.5991
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5591 - loss: 1.2366 - val_accuracy: 0.4639 - val_loss: 1.6141
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5605 - loss: 1.2303 - val_accuracy: 0.4702 - val_loss: 1.6238
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5635 - loss: 1.2219 - val_accuracy: 0.4576 - val_loss: 1.6327
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5652 - loss: 1.2162 - val_accuracy: 0.4567 - val_loss: 1.6476
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5644 - loss: 1.2071 - val_accuracy: 0.4585 - val_loss: 1.6768
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5688 - loss: 1.1975 - val_accuracy: 0.4594 - val_loss: 1.6844
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5743 - loss: 1.1921 - val_accuracy: 0.4558 - val_loss: 1.6963
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5748 - loss: 1.1806 - val_accuracy: 0.4549 - val_loss: 1.7057
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5751 - loss: 1.1777 - val_accuracy: 0.4567 - val_loss: 1.7099
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5772 - loss: 1.1686 - val_accuracy: 0.4531 - val_loss: 1.7310
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5754 - loss: 1.1629 - val_accuracy: 0.4513 - val_loss: 1.7474
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5819 - loss: 1.1555 - val_accuracy: 0.4513 - val_loss: 1.7742
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5809 - loss: 1.1513 - val_accuracy: 0.4558 - val_loss: 1.7832
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5863 - loss: 1.1392 - val_accuracy: 0.4513 - val_loss: 1.8064
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5905 - loss: 1.1388 - val_accuracy: 0.4468 - val_loss: 1.8047
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5875 - loss: 1.1277 - val_accuracy: 0.4449 - val_loss: 1.8608
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5963 - loss: 1.1166 - val_accuracy: 0.4449 - val_loss: 1.8834
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5917 - loss: 1.1112 - val_accuracy: 0.4495 - val_loss: 1.8925
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5954 - loss: 1.1033 - val_accuracy: 0.4513 - val_loss: 1.9362
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5957 - loss: 1.1024 - val_accuracy: 0.4486 - val_loss: 1.9124
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6007 - loss: 1.0911 - val_accuracy: 0.4477 - val_loss: 1.9469
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5996 - loss: 1.0871 - val_accuracy: 0.4531 - val_loss: 1.9760
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6076 - loss: 1.0750 - val_accuracy: 0.4504 - val_loss: 2.0114
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5992 - loss: 1.0786 - val_accuracy: 0.4477 - val_loss: 2.0097
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6068 - loss: 1.0666 - val_accuracy: 0.4431 - val_loss: 2.0235
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6055 - loss: 1.0741 - val_accuracy: 0.4431 - val_loss: 1.9872
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6096 - loss: 1.0555 - val_accuracy: 0.4413 - val_loss: 2.0401
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6051 - loss: 1.0576 - val_accuracy: 0.4458 - val_loss: 2.0445
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6118 - loss: 1.0463 - val_accuracy: 0.4395 - val_loss: 2.0481
# P2_NoiseOnly: Hybrid test=0.5161 | BAN test=0.4885 | Total skipped samples: 2
#
# === Stage A: P3_Both ===
# 100%|██████████| 9989/9989 [06:13<00:00, 26.73it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 1109/1109 [00:41<00:00, 26.92it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 2610/2610 [01:40<00:00, 25.92it/s]
#   ⚠️ Skipped 0 samples: {}
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4761 - loss: 1.4976 - val_accuracy: 0.4729 - val_loss: 1.4910
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5083 - loss: 1.4044 - val_accuracy: 0.4765 - val_loss: 1.4931
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5145 - loss: 1.3952 - val_accuracy: 0.4765 - val_loss: 1.4916
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5172 - loss: 1.3846 - val_accuracy: 0.4783 - val_loss: 1.4909
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5211 - loss: 1.3743 - val_accuracy: 0.4756 - val_loss: 1.4815
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5210 - loss: 1.3697 - val_accuracy: 0.4783 - val_loss: 1.4794
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5228 - loss: 1.3627 - val_accuracy: 0.4720 - val_loss: 1.4830
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5231 - loss: 1.3574 - val_accuracy: 0.4711 - val_loss: 1.4866
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5222 - loss: 1.3559 - val_accuracy: 0.4783 - val_loss: 1.4807
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5300 - loss: 1.3498 - val_accuracy: 0.4792 - val_loss: 1.4970
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5254 - loss: 1.3499 - val_accuracy: 0.4702 - val_loss: 1.5033
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5278 - loss: 1.3449 - val_accuracy: 0.4783 - val_loss: 1.5141
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5264 - loss: 1.3382 - val_accuracy: 0.4729 - val_loss: 1.5085
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5305 - loss: 1.3317 - val_accuracy: 0.4747 - val_loss: 1.5083
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5294 - loss: 1.3249 - val_accuracy: 0.4747 - val_loss: 1.5118
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5293 - loss: 1.3271 - val_accuracy: 0.4765 - val_loss: 1.5114
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5325 - loss: 1.3238 - val_accuracy: 0.4747 - val_loss: 1.5124
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5322 - loss: 1.3178 - val_accuracy: 0.4883 - val_loss: 1.5064
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5367 - loss: 1.3137 - val_accuracy: 0.4792 - val_loss: 1.5133
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5355 - loss: 1.3079 - val_accuracy: 0.4747 - val_loss: 1.5169
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5393 - loss: 1.3027 - val_accuracy: 0.4747 - val_loss: 1.5305
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5352 - loss: 1.3061 - val_accuracy: 0.4729 - val_loss: 1.5338
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5385 - loss: 1.2984 - val_accuracy: 0.4693 - val_loss: 1.5334
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5395 - loss: 1.2945 - val_accuracy: 0.4729 - val_loss: 1.5505
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5391 - loss: 1.2902 - val_accuracy: 0.4702 - val_loss: 1.5455
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5421 - loss: 1.2865 - val_accuracy: 0.4738 - val_loss: 1.5336
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5427 - loss: 1.2830 - val_accuracy: 0.4720 - val_loss: 1.5603
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5425 - loss: 1.2795 - val_accuracy: 0.4729 - val_loss: 1.5536
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5446 - loss: 1.2739 - val_accuracy: 0.4702 - val_loss: 1.5711
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5459 - loss: 1.2739 - val_accuracy: 0.4765 - val_loss: 1.5703
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5446 - loss: 1.2683 - val_accuracy: 0.4666 - val_loss: 1.5856
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5469 - loss: 1.2670 - val_accuracy: 0.4684 - val_loss: 1.5791
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5506 - loss: 1.2597 - val_accuracy: 0.4720 - val_loss: 1.5876
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5481 - loss: 1.2608 - val_accuracy: 0.4639 - val_loss: 1.5915
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5455 - loss: 1.2577 - val_accuracy: 0.4684 - val_loss: 1.6018
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5525 - loss: 1.2542 - val_accuracy: 0.4702 - val_loss: 1.5908
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5490 - loss: 1.2562 - val_accuracy: 0.4666 - val_loss: 1.5911
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5544 - loss: 1.2493 - val_accuracy: 0.4621 - val_loss: 1.6094
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5506 - loss: 1.2460 - val_accuracy: 0.4576 - val_loss: 1.6102
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5539 - loss: 1.2429 - val_accuracy: 0.4648 - val_loss: 1.6146
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5512 - loss: 1.2453 - val_accuracy: 0.4630 - val_loss: 1.6190
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5587 - loss: 1.2385 - val_accuracy: 0.4684 - val_loss: 1.6193
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5560 - loss: 1.2318 - val_accuracy: 0.4639 - val_loss: 1.6558
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5538 - loss: 1.2315 - val_accuracy: 0.4576 - val_loss: 1.6459
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5542 - loss: 1.2304 - val_accuracy: 0.4612 - val_loss: 1.6353
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5564 - loss: 1.2292 - val_accuracy: 0.4684 - val_loss: 1.6242
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5554 - loss: 1.2241 - val_accuracy: 0.4648 - val_loss: 1.6405
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5558 - loss: 1.2183 - val_accuracy: 0.4639 - val_loss: 1.6474
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5575 - loss: 1.2228 - val_accuracy: 0.4594 - val_loss: 1.6513
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5602 - loss: 1.2145 - val_accuracy: 0.4576 - val_loss: 1.6483
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4971 - loss: 1.4405 - val_accuracy: 0.4711 - val_loss: 1.4925
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5140 - loss: 1.3948 - val_accuracy: 0.4675 - val_loss: 1.4846
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5139 - loss: 1.3842 - val_accuracy: 0.4711 - val_loss: 1.4861
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5146 - loss: 1.3803 - val_accuracy: 0.4720 - val_loss: 1.4824
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5186 - loss: 1.3723 - val_accuracy: 0.4702 - val_loss: 1.4835
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5218 - loss: 1.3669 - val_accuracy: 0.4729 - val_loss: 1.4909
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5215 - loss: 1.3613 - val_accuracy: 0.4729 - val_loss: 1.4880
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5256 - loss: 1.3531 - val_accuracy: 0.4720 - val_loss: 1.4953
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5260 - loss: 1.3469 - val_accuracy: 0.4720 - val_loss: 1.4962
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5275 - loss: 1.3419 - val_accuracy: 0.4729 - val_loss: 1.5084
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5322 - loss: 1.3368 - val_accuracy: 0.4756 - val_loss: 1.5023
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5306 - loss: 1.3289 - val_accuracy: 0.4738 - val_loss: 1.5122
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5307 - loss: 1.3238 - val_accuracy: 0.4729 - val_loss: 1.5188
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5357 - loss: 1.3179 - val_accuracy: 0.4702 - val_loss: 1.5297
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5358 - loss: 1.3131 - val_accuracy: 0.4720 - val_loss: 1.5439
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5374 - loss: 1.3058 - val_accuracy: 0.4711 - val_loss: 1.5471
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5356 - loss: 1.3027 - val_accuracy: 0.4666 - val_loss: 1.5514
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5357 - loss: 1.2900 - val_accuracy: 0.4666 - val_loss: 1.5657
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5430 - loss: 1.2874 - val_accuracy: 0.4711 - val_loss: 1.5598
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5432 - loss: 1.2785 - val_accuracy: 0.4675 - val_loss: 1.5840
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5467 - loss: 1.2736 - val_accuracy: 0.4567 - val_loss: 1.5942
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5500 - loss: 1.2602 - val_accuracy: 0.4648 - val_loss: 1.5908
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5468 - loss: 1.2556 - val_accuracy: 0.4702 - val_loss: 1.6117
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5536 - loss: 1.2496 - val_accuracy: 0.4729 - val_loss: 1.6191
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5544 - loss: 1.2422 - val_accuracy: 0.4675 - val_loss: 1.6335
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5575 - loss: 1.2347 - val_accuracy: 0.4630 - val_loss: 1.6434
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5597 - loss: 1.2272 - val_accuracy: 0.4639 - val_loss: 1.6445
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5581 - loss: 1.2187 - val_accuracy: 0.4675 - val_loss: 1.6593
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5645 - loss: 1.2094 - val_accuracy: 0.4648 - val_loss: 1.6760
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5641 - loss: 1.2017 - val_accuracy: 0.4513 - val_loss: 1.6926
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5651 - loss: 1.1959 - val_accuracy: 0.4558 - val_loss: 1.6972
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5711 - loss: 1.1942 - val_accuracy: 0.4477 - val_loss: 1.6960
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5703 - loss: 1.1859 - val_accuracy: 0.4639 - val_loss: 1.7110
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5753 - loss: 1.1822 - val_accuracy: 0.4594 - val_loss: 1.7007
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5778 - loss: 1.1716 - val_accuracy: 0.4431 - val_loss: 1.7289
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5755 - loss: 1.1650 - val_accuracy: 0.4477 - val_loss: 1.7528
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5835 - loss: 1.1527 - val_accuracy: 0.4440 - val_loss: 1.7650
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5874 - loss: 1.1472 - val_accuracy: 0.4422 - val_loss: 1.7563
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5875 - loss: 1.1422 - val_accuracy: 0.4531 - val_loss: 1.7771
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5855 - loss: 1.1311 - val_accuracy: 0.4540 - val_loss: 1.7990
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5875 - loss: 1.1300 - val_accuracy: 0.4422 - val_loss: 1.7809
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5903 - loss: 1.1216 - val_accuracy: 0.4504 - val_loss: 1.8267
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5967 - loss: 1.1129 - val_accuracy: 0.4422 - val_loss: 1.8118
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5888 - loss: 1.1120 - val_accuracy: 0.4495 - val_loss: 1.8271
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5952 - loss: 1.0981 - val_accuracy: 0.4422 - val_loss: 1.8546
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6012 - loss: 1.0962 - val_accuracy: 0.4440 - val_loss: 1.8551
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6024 - loss: 1.0840 - val_accuracy: 0.4395 - val_loss: 1.9165
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6043 - loss: 1.0814 - val_accuracy: 0.4468 - val_loss: 1.8786
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5989 - loss: 1.0804 - val_accuracy: 0.4413 - val_loss: 1.8804
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6043 - loss: 1.0742 - val_accuracy: 0.4422 - val_loss: 1.9223
# P3_Both: Hybrid test=0.5222 | BAN test=0.4759 | Total skipped samples: 2
#
# === Hybrid CNN-LSTM — Preprocessing Configs (per_class_recall) ===
#                 neutral     joy  sadness   anger    fear  disgust  surprise  Overall Accuracy
# P0_None          0.1942  0.0000     0.00  0.6194  0.7779   0.0673    0.0356            0.5046
# P1_SilenceOnly   0.2725  0.0147     0.02  0.5025  0.7142   0.0962    0.1352            0.4801
# P2_NoiseOnly     0.1797  0.0441     0.00  0.6020  0.8105   0.0673    0.0285            0.5161
# P3_Both          0.1826  0.0000     0.00  0.6095  0.8177   0.0865    0.0356            0.5222
#
# === BAN — Preprocessing Configs (per_class_recall) ===
#                 neutral     joy  sadness   anger    fear  disgust  surprise  Overall Accuracy
# P0_None          0.1710  0.0294     0.06  0.6070  0.7237   0.1058    0.0605            0.4812
# P1_SilenceOnly   0.1652  0.0000     0.02  0.5746  0.7333   0.1010    0.0676            0.4789
# P2_NoiseOnly     0.1826  0.0000     0.02  0.5199  0.7651   0.0769    0.0890            0.4885
# P3_Both          0.1594  0.0000     0.06  0.5249  0.7468   0.0817    0.0641            0.4759

# %%
df_stageA_hybrid = pd.DataFrame([{'Config': k, **v} for k, v in stageA_hybrid.items()]).drop(columns='model_name')
df_stageA_ban    = pd.DataFrame([{'Config': k, **v} for k, v in stageA_ban.items()]).drop(columns='model_name')

print("=== Table A1: Hybrid CNN-LSTM — Preprocessing ===")
display(df_stageA_hybrid)
print("\n=== Table A2: BAN — Preprocessing ===")
display(df_stageA_ban)

combined_A = df_stageA_hybrid.merge(df_stageA_ban, on='Config', suffixes=('_Hybrid', '_BAN'))
combined_A['Avg_Test_Accuracy']  = combined_A[['test_accuracy_Hybrid', 'test_accuracy_BAN']].mean(axis=1)
combined_A['Avg_Macro_Recall']   = combined_A[['test_macro_recall_Hybrid', 'test_macro_recall_BAN']].mean(axis=1)
combined_A['Avg_Macro_F1']       = combined_A[['test_macro_f1_Hybrid', 'test_macro_f1_BAN']].mean(axis=1)
combined_A = combined_A.sort_values('Avg_Macro_F1', ascending=False).reset_index(drop=True)

print("\n=== Combined Decision Table — Best Preprocessing (ranked by Macro F1) ===")
display(combined_A)

best_preprocess_name = combined_A.iloc[0]['Config']
best_preprocess_cfg = PREPROCESS_CONFIGS[best_preprocess_name]
print(f"\n✅ Best preprocessing: {best_preprocess_name} -> {best_preprocess_cfg}")
# Out:
# === Table A1: Hybrid CNN-LSTM — Preprocessing ===
#            Config  val_accuracy  test_accuracy  test_macro_recall  \
# 0         P0_None      0.482852       0.504598           0.242052
# 1  P1_SilenceOnly      0.486462       0.480077           0.250745
# 2    P2_NoiseOnly      0.482852       0.516092           0.247444
# 3         P3_Both      0.488267       0.522222           0.247409
#
#    test_macro_f1                                   per_class_recall  \
# 0       0.225614  {'neutral': 0.19420289855072465, 'joy': 0.0, '...
# 1       0.248466  {'neutral': 0.27246376811594203, 'joy': 0.0147...
# 2       0.235956  {'neutral': 0.17971014492753623, 'joy': 0.0441...
# 3       0.232702  {'neutral': 0.1826086956521739, 'joy': 0.0, 's...
#
#                                         per_class_f1
# 0  {'neutral': 0.2338568935427574, 'joy': 0.0, 's...
# 1  {'neutral': 0.2874617737003058, 'joy': 0.02409...
# 2  {'neutral': 0.22423146473779385, 'joy': 0.0789...
# 3  {'neutral': 0.23863636363636365, 'joy': 0.0, '...
# === Table A2: BAN — Preprocessing ===
#            Config  val_accuracy  test_accuracy  test_macro_recall  \
# 0         P0_None      0.482852       0.481226           0.251055
# 1  P1_SilenceOnly      0.479242       0.478927           0.237386
# 2    P2_NoiseOnly      0.477437       0.488506           0.236218
# 3         P3_Both      0.475632       0.475862           0.233843
#
#    test_macro_f1                                   per_class_recall  \
# 0       0.242188  {'neutral': 0.17101449275362318, 'joy': 0.0294...
# 1       0.227687  {'neutral': 0.16521739130434782, 'joy': 0.0, '...
# 2       0.231060  {'neutral': 0.1826086956521739, 'joy': 0.0, 's...
# 3       0.226500  {'neutral': 0.15942028985507245, 'joy': 0.0, '...
#
#                                         per_class_f1
# 0  {'neutral': 0.21973929236499068, 'joy': 0.0465...
# 1  {'neutral': 0.2007042253521127, 'joy': 0.0, 's...
# 2  {'neutral': 0.22066549912434325, 'joy': 0.0, '...
# 3  {'neutral': 0.1981981981981982, 'joy': 0.0, 's...
# === Combined Decision Table — Best Preprocessing (ranked by Macro F1) ===
#            Config  val_accuracy_Hybrid  test_accuracy_Hybrid  \
# 0  P1_SilenceOnly             0.486462              0.480077
# 1         P0_None             0.482852              0.504598
# 2    P2_NoiseOnly             0.482852              0.516092
# 3         P3_Both             0.488267              0.522222
#
#    test_macro_recall_Hybrid  test_macro_f1_Hybrid  \
# 0                  0.250745              0.248466
# 1                  0.242052              0.225614
# 2                  0.247444              0.235956
# 3                  0.247409              0.232702
#
#                              per_class_recall_Hybrid  \
# 0  {'neutral': 0.27246376811594203, 'joy': 0.0147...
# 1  {'neutral': 0.19420289855072465, 'joy': 0.0, '...
# 2  {'neutral': 0.17971014492753623, 'joy': 0.0441...
# 3  {'neutral': 0.1826086956521739, 'joy': 0.0, 's...
#
#                                  per_class_f1_Hybrid  val_accuracy_BAN  \
# 0  {'neutral': 0.2874617737003058, 'joy': 0.02409...          0.479242
# 1  {'neutral': 0.2338568935427574, 'joy': 0.0, 's...          0.482852
# 2  {'neutral': 0.22423146473779385, 'joy': 0.0789...          0.477437
# 3  {'neutral': 0.23863636363636365, 'joy': 0.0, '...          0.475632
#
#    test_accuracy_BAN  test_macro_recall_BAN  test_macro_f1_BAN  \
# 0           0.478927               0.237386           0.227687
# 1           0.481226               0.251055           0.242188
# 2           0.488506               0.236218           0.231060
# 3           0.475862               0.233843           0.226500
#
#                                 per_class_recall_BAN  \
# 0  {'neutral': 0.16521739130434782, 'joy': 0.0, '...
# 1  {'neutral': 0.17101449275362318, 'joy': 0.0294...
# 2  {'neutral': 0.1826086956521739, 'joy': 0.0, 's...
# 3  {'neutral': 0.15942028985507245, 'joy': 0.0, '...
#
#                                     per_class_f1_BAN  Avg_Test_Accuracy  \
# 0  {'neutral': 0.2007042253521127, 'joy': 0.0, 's...           0.479502
# 1  {'neutral': 0.21973929236499068, 'joy': 0.0465...           0.492912
# 2  {'neutral': 0.22066549912434325, 'joy': 0.0, '...           0.502299
# 3  {'neutral': 0.1981981981981982, 'joy': 0.0, 's...           0.499042
#
#    Avg_Macro_Recall  Avg_Macro_F1
# 0          0.244065      0.238077
# 1          0.246554      0.233901
# 2          0.241831      0.233508
# 3          0.240626      0.229601
# ✅ Best preprocessing: P1_SilenceOnly -> {'clean_noise': False, 'trim_silence': True}

# %%
# ==========================================
# STAGE B: AUGMENTATION, using the winning preprocessing from Stage A
# ==========================================
import random

AUGMENTATION_MODES = {"A1_NormalAug": "normal", "A2_TargetedAug": "targeted"}

# Get the winning Stage-A config's actual settings (not a stale `cfg`)
best_preprocess_name = "P2_NoiseOnly"
best_cfg = {"clean_noise": True,  "trim_silence": False}

stageB_hybrid, stageB_ban, stageB_skips = {}, {}, {}
stageB_splits_cache = {}

# A0 (no augmentation) = the winning Stage-A run itself — reuse instead of recomputing
stageB_hybrid["A0_NoAug"] = stageA_hybrid[best_preprocess_name]
stageB_ban["A0_NoAug"]    = stageA_ban[best_preprocess_name]

for name, aug_mode in AUGMENTATION_MODES.items():
    print(f"\n=== Stage B: {name} (on {best_preprocess_name}) ===")

    np.random.seed(SEED)
    random.seed(SEED)

    splits_out, skip_report = prepare_and_encode(
        best_cfg['clean_noise'], best_cfg['trim_silence'], augmentation=aug_mode
    )
    stageB_splits_cache[name] = (splits_out, best_cfg)
    stageB_skips[name] = skip_report

    stageB_hybrid[name] = run_training(build_hybrid_cnn_lstm, splits_out, "Hybrid")
    stageB_ban[name]    = run_training(build_ban, splits_out, "BAN")

    print(f"{name}: Hybrid test={stageB_hybrid[name]['test_accuracy']:.4f} | "
          f"BAN test={stageB_ban[name]['test_accuracy']:.4f}")
    del splits_out; gc.collect()

recall_matrix_hybrid_augment = print_per_class_matrix(
    stageB_hybrid, metric='per_class_recall', title="Hybrid CNN-LSTM — Augmentation Configs"
)
recall_matrix_ban_augment = print_per_class_matrix(
    stageB_ban, metric='per_class_recall', title="BAN — Augmentation Configs"
)
# Out:
# === Stage B: A1_NormalAug (on P2_NoiseOnly) ===
#  17%|█▋        | 1672/9989 [01:24<05:35, 24.76it/s]c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1024
#   warnings.warn(
#  33%|███▎      | 3280/9989 [02:41<06:25, 17.39it/s]c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1365
#   warnings.warn(
# 100%|██████████| 9989/9989 [09:10<00:00, 18.14it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 1109/1109 [00:51<00:00, 21.61it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 2610/2610 [02:06<00:00, 20.67it/s]
#   ⚠️ Skipped 0 samples: {}
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.4834 - loss: 1.4799 - val_accuracy: 0.4720 - val_loss: 1.4886
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5100 - loss: 1.4044 - val_accuracy: 0.4702 - val_loss: 1.4915
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5164 - loss: 1.3904 - val_accuracy: 0.4720 - val_loss: 1.4904
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5209 - loss: 1.3796 - val_accuracy: 0.4756 - val_loss: 1.4960
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5207 - loss: 1.3723 - val_accuracy: 0.4702 - val_loss: 1.4991
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5238 - loss: 1.3679 - val_accuracy: 0.4738 - val_loss: 1.4900
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5247 - loss: 1.3622 - val_accuracy: 0.4765 - val_loss: 1.5065
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5222 - loss: 1.3583 - val_accuracy: 0.4738 - val_loss: 1.4996
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5257 - loss: 1.3534 - val_accuracy: 0.4720 - val_loss: 1.5073
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5308 - loss: 1.3477 - val_accuracy: 0.4720 - val_loss: 1.5039
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5271 - loss: 1.3450 - val_accuracy: 0.4738 - val_loss: 1.5124
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5314 - loss: 1.3399 - val_accuracy: 0.4756 - val_loss: 1.5147
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5330 - loss: 1.3375 - val_accuracy: 0.4729 - val_loss: 1.5272
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5294 - loss: 1.3339 - val_accuracy: 0.4684 - val_loss: 1.5262
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5337 - loss: 1.3331 - val_accuracy: 0.4765 - val_loss: 1.5251
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5354 - loss: 1.3262 - val_accuracy: 0.4747 - val_loss: 1.5309
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5325 - loss: 1.3243 - val_accuracy: 0.4747 - val_loss: 1.5321
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5377 - loss: 1.3166 - val_accuracy: 0.4747 - val_loss: 1.5420
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5345 - loss: 1.3082 - val_accuracy: 0.4747 - val_loss: 1.5398
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5388 - loss: 1.3096 - val_accuracy: 0.4648 - val_loss: 1.5445
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5379 - loss: 1.3048 - val_accuracy: 0.4765 - val_loss: 1.5470
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5365 - loss: 1.2998 - val_accuracy: 0.4720 - val_loss: 1.5520
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5422 - loss: 1.2967 - val_accuracy: 0.4738 - val_loss: 1.5538
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5426 - loss: 1.3009 - val_accuracy: 0.4720 - val_loss: 1.5522
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5427 - loss: 1.2912 - val_accuracy: 0.4639 - val_loss: 1.5688
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5442 - loss: 1.2895 - val_accuracy: 0.4702 - val_loss: 1.5709
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5476 - loss: 1.2810 - val_accuracy: 0.4639 - val_loss: 1.5746
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5402 - loss: 1.2812 - val_accuracy: 0.4639 - val_loss: 1.5860
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5449 - loss: 1.2791 - val_accuracy: 0.4693 - val_loss: 1.5848
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5444 - loss: 1.2720 - val_accuracy: 0.4702 - val_loss: 1.5845
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5468 - loss: 1.2695 - val_accuracy: 0.4657 - val_loss: 1.5984
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5471 - loss: 1.2698 - val_accuracy: 0.4720 - val_loss: 1.5920
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5529 - loss: 1.2657 - val_accuracy: 0.4666 - val_loss: 1.5994
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5487 - loss: 1.2613 - val_accuracy: 0.4675 - val_loss: 1.6004
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5529 - loss: 1.2570 - val_accuracy: 0.4675 - val_loss: 1.5941
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5541 - loss: 1.2530 - val_accuracy: 0.4657 - val_loss: 1.6113
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5519 - loss: 1.2526 - val_accuracy: 0.4639 - val_loss: 1.6175
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5509 - loss: 1.2546 - val_accuracy: 0.4675 - val_loss: 1.6266
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5518 - loss: 1.2494 - val_accuracy: 0.4693 - val_loss: 1.6284
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5557 - loss: 1.2448 - val_accuracy: 0.4702 - val_loss: 1.6305
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5542 - loss: 1.2392 - val_accuracy: 0.4648 - val_loss: 1.6244
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5565 - loss: 1.2413 - val_accuracy: 0.4630 - val_loss: 1.6441
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5577 - loss: 1.2376 - val_accuracy: 0.4702 - val_loss: 1.6231
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5576 - loss: 1.2329 - val_accuracy: 0.4612 - val_loss: 1.6359
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5543 - loss: 1.2310 - val_accuracy: 0.4585 - val_loss: 1.6456
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5580 - loss: 1.2265 - val_accuracy: 0.4657 - val_loss: 1.6453
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5631 - loss: 1.2245 - val_accuracy: 0.4576 - val_loss: 1.6531
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5589 - loss: 1.2314 - val_accuracy: 0.4594 - val_loss: 1.6557
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5620 - loss: 1.2247 - val_accuracy: 0.4594 - val_loss: 1.6480
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5594 - loss: 1.2194 - val_accuracy: 0.4549 - val_loss: 1.6695
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.4975 - loss: 1.4428 - val_accuracy: 0.4765 - val_loss: 1.4920
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5155 - loss: 1.3955 - val_accuracy: 0.4747 - val_loss: 1.4835
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5181 - loss: 1.3850 - val_accuracy: 0.4729 - val_loss: 1.4791
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5198 - loss: 1.3766 - val_accuracy: 0.4738 - val_loss: 1.4875
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5242 - loss: 1.3741 - val_accuracy: 0.4774 - val_loss: 1.4870
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5232 - loss: 1.3678 - val_accuracy: 0.4729 - val_loss: 1.4932
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5267 - loss: 1.3606 - val_accuracy: 0.4711 - val_loss: 1.4982
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5277 - loss: 1.3528 - val_accuracy: 0.4711 - val_loss: 1.5096
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5279 - loss: 1.3471 - val_accuracy: 0.4720 - val_loss: 1.5121
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5325 - loss: 1.3383 - val_accuracy: 0.4729 - val_loss: 1.5167
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5318 - loss: 1.3315 - val_accuracy: 0.4702 - val_loss: 1.5341
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5358 - loss: 1.3257 - val_accuracy: 0.4657 - val_loss: 1.5389
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5362 - loss: 1.3134 - val_accuracy: 0.4675 - val_loss: 1.5490
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5400 - loss: 1.3076 - val_accuracy: 0.4666 - val_loss: 1.5612
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5428 - loss: 1.3010 - val_accuracy: 0.4612 - val_loss: 1.5709
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5464 - loss: 1.2907 - val_accuracy: 0.4657 - val_loss: 1.5821
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5467 - loss: 1.2853 - val_accuracy: 0.4603 - val_loss: 1.6053
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5513 - loss: 1.2747 - val_accuracy: 0.4639 - val_loss: 1.6077
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5509 - loss: 1.2669 - val_accuracy: 0.4648 - val_loss: 1.6304
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5533 - loss: 1.2639 - val_accuracy: 0.4648 - val_loss: 1.6329
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5557 - loss: 1.2529 - val_accuracy: 0.4621 - val_loss: 1.6412
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5567 - loss: 1.2494 - val_accuracy: 0.4603 - val_loss: 1.6522
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5579 - loss: 1.2355 - val_accuracy: 0.4540 - val_loss: 1.6832
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5620 - loss: 1.2312 - val_accuracy: 0.4594 - val_loss: 1.6920
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5648 - loss: 1.2233 - val_accuracy: 0.4486 - val_loss: 1.7061
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5657 - loss: 1.2149 - val_accuracy: 0.4468 - val_loss: 1.7141
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5711 - loss: 1.2037 - val_accuracy: 0.4504 - val_loss: 1.7142
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5715 - loss: 1.2000 - val_accuracy: 0.4468 - val_loss: 1.7349
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5769 - loss: 1.1887 - val_accuracy: 0.4458 - val_loss: 1.7706
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5765 - loss: 1.1796 - val_accuracy: 0.4458 - val_loss: 1.7786
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5770 - loss: 1.1772 - val_accuracy: 0.4431 - val_loss: 1.7850
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5829 - loss: 1.1672 - val_accuracy: 0.4486 - val_loss: 1.8139
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5859 - loss: 1.1573 - val_accuracy: 0.4458 - val_loss: 1.8250
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5847 - loss: 1.1506 - val_accuracy: 0.4449 - val_loss: 1.8395
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5868 - loss: 1.1454 - val_accuracy: 0.4458 - val_loss: 1.8944
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5841 - loss: 1.1421 - val_accuracy: 0.4486 - val_loss: 1.8449
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5953 - loss: 1.1285 - val_accuracy: 0.4413 - val_loss: 1.8969
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5934 - loss: 1.1255 - val_accuracy: 0.4413 - val_loss: 1.9025
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5952 - loss: 1.1179 - val_accuracy: 0.4395 - val_loss: 1.9413
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6004 - loss: 1.1091 - val_accuracy: 0.4377 - val_loss: 1.9291
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6036 - loss: 1.1036 - val_accuracy: 0.4377 - val_loss: 1.9538
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6034 - loss: 1.0970 - val_accuracy: 0.4395 - val_loss: 1.9690
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6022 - loss: 1.0851 - val_accuracy: 0.4296 - val_loss: 2.0097
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6043 - loss: 1.0885 - val_accuracy: 0.4377 - val_loss: 2.0185
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6103 - loss: 1.0783 - val_accuracy: 0.4386 - val_loss: 2.0294
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6070 - loss: 1.0744 - val_accuracy: 0.4440 - val_loss: 2.0375
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6086 - loss: 1.0697 - val_accuracy: 0.4341 - val_loss: 2.0976
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6078 - loss: 1.0656 - val_accuracy: 0.4431 - val_loss: 2.0906
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6110 - loss: 1.0569 - val_accuracy: 0.4359 - val_loss: 2.0936
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6184 - loss: 1.0479 - val_accuracy: 0.4359 - val_loss: 2.1188
# A1_NormalAug: Hybrid test=0.5065 | BAN test=0.4778
#
# === Stage B: A2_TargetedAug (on P2_NoiseOnly) ===
# [neutral]: 100%|██████████| 1700/1700 [01:14<00:00, 22.73it/s]
# [joy]: 100%|██████████| 1700/1700 [01:14<00:00, 22.68it/s]
# [sadness]: 100%|██████████| 683/683 [01:41<00:00,  6.72it/s]
# [anger]:  29%|██▉       | 326/1109 [00:29<01:11, 10.91it/s]c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1024
#   warnings.warn(
# [anger]: 100%|██████████| 1109/1109 [01:42<00:00, 10.79it/s]
# [fear]: 100%|██████████| 268/268 [01:28<00:00,  3.03it/s]
# [disgust]: 100%|██████████| 271/271 [01:38<00:00,  2.74it/s]
# [surprise]:  72%|███████▏  | 873/1205 [01:20<00:32, 10.32it/s]c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1365
#   warnings.warn(
# [surprise]: 100%|██████████| 1205/1205 [01:48<00:00, 11.09it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 1109/1109 [00:43<00:00, 25.53it/s]
#   ⚠️ Skipped 1 samples: {'missing_file': 1}
# 100%|██████████| 2610/2610 [01:46<00:00, 24.51it/s]
#   ⚠️ Skipped 0 samples: {}
# Epoch 1/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2867 - loss: 1.7644 - val_accuracy: 0.2834 - val_loss: 1.7695
# Epoch 2/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3424 - loss: 1.6443 - val_accuracy: 0.2825 - val_loss: 1.7485
# Epoch 3/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3643 - loss: 1.5947 - val_accuracy: 0.3014 - val_loss: 1.7423
# Epoch 4/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3774 - loss: 1.5613 - val_accuracy: 0.3032 - val_loss: 1.7325
# Epoch 5/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3886 - loss: 1.5352 - val_accuracy: 0.3177 - val_loss: 1.7141
# Epoch 6/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3945 - loss: 1.5180 - val_accuracy: 0.3087 - val_loss: 1.7204
# Epoch 7/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4056 - loss: 1.4973 - val_accuracy: 0.3069 - val_loss: 1.7196
# Epoch 8/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4114 - loss: 1.4785 - val_accuracy: 0.3186 - val_loss: 1.7081
# Epoch 9/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4188 - loss: 1.4646 - val_accuracy: 0.3195 - val_loss: 1.7072
# Epoch 10/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4284 - loss: 1.4521 - val_accuracy: 0.3195 - val_loss: 1.7060
# Epoch 11/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4302 - loss: 1.4395 - val_accuracy: 0.3231 - val_loss: 1.7068
# Epoch 12/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4328 - loss: 1.4262 - val_accuracy: 0.3294 - val_loss: 1.6993
# Epoch 13/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4424 - loss: 1.4089 - val_accuracy: 0.3222 - val_loss: 1.6934
# Epoch 14/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4465 - loss: 1.3998 - val_accuracy: 0.3213 - val_loss: 1.7115
# Epoch 15/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4504 - loss: 1.3850 - val_accuracy: 0.3159 - val_loss: 1.7083
# Epoch 16/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4522 - loss: 1.3798 - val_accuracy: 0.3276 - val_loss: 1.7148
# Epoch 17/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4551 - loss: 1.3708 - val_accuracy: 0.3159 - val_loss: 1.7278
# Epoch 18/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4606 - loss: 1.3599 - val_accuracy: 0.3204 - val_loss: 1.7200
# Epoch 19/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4644 - loss: 1.3450 - val_accuracy: 0.3051 - val_loss: 1.7406
# Epoch 20/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4682 - loss: 1.3389 - val_accuracy: 0.3168 - val_loss: 1.7270
# Epoch 21/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4695 - loss: 1.3389 - val_accuracy: 0.3177 - val_loss: 1.7390
# Epoch 22/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4782 - loss: 1.3270 - val_accuracy: 0.3159 - val_loss: 1.7408
# Epoch 23/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4737 - loss: 1.3314 - val_accuracy: 0.3096 - val_loss: 1.7369
# Epoch 24/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4844 - loss: 1.3131 - val_accuracy: 0.3159 - val_loss: 1.7514
# Epoch 25/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4783 - loss: 1.3134 - val_accuracy: 0.3150 - val_loss: 1.7656
# Epoch 26/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4824 - loss: 1.3104 - val_accuracy: 0.3150 - val_loss: 1.7377
# Epoch 27/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4870 - loss: 1.3008 - val_accuracy: 0.3060 - val_loss: 1.7515
# Epoch 28/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4872 - loss: 1.2872 - val_accuracy: 0.3231 - val_loss: 1.7410
# Epoch 29/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4944 - loss: 1.2847 - val_accuracy: 0.3105 - val_loss: 1.7457
# Epoch 30/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4924 - loss: 1.2788 - val_accuracy: 0.3168 - val_loss: 1.7526
# Epoch 31/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4953 - loss: 1.2779 - val_accuracy: 0.3096 - val_loss: 1.7512
# Epoch 32/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4942 - loss: 1.2744 - val_accuracy: 0.2978 - val_loss: 1.7727
# Epoch 33/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4935 - loss: 1.2725 - val_accuracy: 0.3096 - val_loss: 1.7549
# Epoch 34/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5026 - loss: 1.2644 - val_accuracy: 0.3060 - val_loss: 1.7740
# Epoch 35/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5002 - loss: 1.2634 - val_accuracy: 0.3051 - val_loss: 1.7790
# Epoch 36/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5031 - loss: 1.2542 - val_accuracy: 0.2951 - val_loss: 1.7752
# Epoch 37/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5089 - loss: 1.2476 - val_accuracy: 0.2942 - val_loss: 1.7757
# Epoch 38/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5027 - loss: 1.2606 - val_accuracy: 0.3375 - val_loss: 1.7337
# Epoch 39/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5099 - loss: 1.2527 - val_accuracy: 0.3267 - val_loss: 1.7524
# Epoch 40/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5080 - loss: 1.2471 - val_accuracy: 0.3141 - val_loss: 1.7692
# Epoch 41/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5065 - loss: 1.2443 - val_accuracy: 0.3032 - val_loss: 1.8062
# Epoch 42/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5105 - loss: 1.2458 - val_accuracy: 0.3114 - val_loss: 1.7784
# Epoch 43/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5081 - loss: 1.2401 - val_accuracy: 0.3177 - val_loss: 1.7854
# Epoch 44/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5045 - loss: 1.2452 - val_accuracy: 0.3141 - val_loss: 1.8020
# Epoch 45/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5081 - loss: 1.2373 - val_accuracy: 0.3087 - val_loss: 1.7872
# Epoch 46/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5165 - loss: 1.2286 - val_accuracy: 0.3087 - val_loss: 1.8010
# Epoch 47/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5127 - loss: 1.2321 - val_accuracy: 0.3168 - val_loss: 1.7743
# Epoch 48/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5152 - loss: 1.2253 - val_accuracy: 0.3114 - val_loss: 1.7775
# Epoch 49/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5122 - loss: 1.2305 - val_accuracy: 0.3150 - val_loss: 1.7911
# Epoch 50/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5174 - loss: 1.2253 - val_accuracy: 0.3105 - val_loss: 1.7927
# Epoch 1/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.2949 - loss: 1.7412 - val_accuracy: 0.2834 - val_loss: 1.7564
# Epoch 2/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3540 - loss: 1.6151 - val_accuracy: 0.3150 - val_loss: 1.7253
# Epoch 3/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3771 - loss: 1.5637 - val_accuracy: 0.3177 - val_loss: 1.7353
# Epoch 4/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.3857 - loss: 1.5349 - val_accuracy: 0.2978 - val_loss: 1.7261
# Epoch 5/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4049 - loss: 1.4958 - val_accuracy: 0.3303 - val_loss: 1.7078
# Epoch 6/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4193 - loss: 1.4559 - val_accuracy: 0.3348 - val_loss: 1.7036
# Epoch 7/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.4227 - loss: 1.4344 - val_accuracy: 0.3312 - val_loss: 1.7061
# Epoch 8/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4358 - loss: 1.4130 - val_accuracy: 0.3258 - val_loss: 1.7031
# Epoch 9/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4402 - loss: 1.4005 - val_accuracy: 0.3204 - val_loss: 1.7178
# Epoch 10/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4491 - loss: 1.3805 - val_accuracy: 0.3042 - val_loss: 1.7149
# Epoch 11/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4540 - loss: 1.3690 - val_accuracy: 0.3240 - val_loss: 1.6965
# Epoch 12/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4628 - loss: 1.3573 - val_accuracy: 0.3267 - val_loss: 1.7033
# Epoch 13/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4631 - loss: 1.3458 - val_accuracy: 0.3186 - val_loss: 1.7085
# Epoch 14/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4719 - loss: 1.3301 - val_accuracy: 0.3195 - val_loss: 1.7210
# Epoch 15/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4748 - loss: 1.3197 - val_accuracy: 0.3186 - val_loss: 1.7280
# Epoch 16/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4797 - loss: 1.3101 - val_accuracy: 0.3096 - val_loss: 1.7343
# Epoch 17/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4847 - loss: 1.2989 - val_accuracy: 0.3087 - val_loss: 1.7605
# Epoch 18/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4868 - loss: 1.2836 - val_accuracy: 0.3069 - val_loss: 1.7574
# Epoch 19/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4946 - loss: 1.2742 - val_accuracy: 0.3168 - val_loss: 1.7475
# Epoch 20/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4968 - loss: 1.2649 - val_accuracy: 0.3312 - val_loss: 1.7394
# Epoch 21/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4992 - loss: 1.2621 - val_accuracy: 0.3204 - val_loss: 1.7487
# Epoch 22/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5029 - loss: 1.2504 - val_accuracy: 0.3141 - val_loss: 1.7680
# Epoch 23/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5075 - loss: 1.2336 - val_accuracy: 0.3014 - val_loss: 1.7891
# Epoch 24/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5148 - loss: 1.2233 - val_accuracy: 0.3087 - val_loss: 1.7694
# Epoch 25/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5150 - loss: 1.2157 - val_accuracy: 0.3032 - val_loss: 1.7970
# Epoch 26/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5224 - loss: 1.2037 - val_accuracy: 0.3042 - val_loss: 1.8000
# Epoch 27/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5231 - loss: 1.2025 - val_accuracy: 0.2942 - val_loss: 1.7896
# Epoch 28/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5294 - loss: 1.1897 - val_accuracy: 0.3195 - val_loss: 1.7766
# Epoch 29/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5294 - loss: 1.1840 - val_accuracy: 0.3105 - val_loss: 1.7956
# Epoch 30/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5392 - loss: 1.1663 - val_accuracy: 0.3060 - val_loss: 1.8148
# Epoch 31/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5321 - loss: 1.1669 - val_accuracy: 0.3114 - val_loss: 1.8148
# Epoch 32/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5398 - loss: 1.1623 - val_accuracy: 0.2888 - val_loss: 1.8151
# Epoch 33/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5487 - loss: 1.1446 - val_accuracy: 0.3051 - val_loss: 1.8318
# Epoch 34/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5498 - loss: 1.1397 - val_accuracy: 0.2870 - val_loss: 1.8465
# Epoch 35/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5525 - loss: 1.1387 - val_accuracy: 0.3087 - val_loss: 1.8461
# Epoch 36/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5596 - loss: 1.1265 - val_accuracy: 0.3069 - val_loss: 1.8613
# Epoch 37/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5581 - loss: 1.1214 - val_accuracy: 0.2951 - val_loss: 1.8498
# Epoch 38/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5595 - loss: 1.1176 - val_accuracy: 0.3159 - val_loss: 1.8687
# Epoch 39/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5595 - loss: 1.1128 - val_accuracy: 0.3014 - val_loss: 1.8733
# Epoch 40/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5646 - loss: 1.1014 - val_accuracy: 0.3042 - val_loss: 1.8850
# Epoch 41/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5647 - loss: 1.1018 - val_accuracy: 0.3213 - val_loss: 1.8788
# Epoch 42/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5673 - loss: 1.0931 - val_accuracy: 0.3159 - val_loss: 1.8856
# Epoch 43/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5702 - loss: 1.0850 - val_accuracy: 0.3023 - val_loss: 1.9435
# Epoch 44/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5725 - loss: 1.0817 - val_accuracy: 0.3032 - val_loss: 1.9485
# Epoch 45/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5705 - loss: 1.0859 - val_accuracy: 0.3014 - val_loss: 1.9100
# Epoch 46/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5743 - loss: 1.0754 - val_accuracy: 0.3078 - val_loss: 1.9146
# Epoch 47/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5797 - loss: 1.0660 - val_accuracy: 0.3249 - val_loss: 1.9317
# Epoch 48/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5808 - loss: 1.0630 - val_accuracy: 0.2969 - val_loss: 1.9487
# Epoch 49/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5805 - loss: 1.0611 - val_accuracy: 0.3195 - val_loss: 1.9135
# Epoch 50/50
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5869 - loss: 1.0454 - val_accuracy: 0.3213 - val_loss: 1.9310
# A2_TargetedAug: Hybrid test=0.3100 | BAN test=0.3326
#
# === Hybrid CNN-LSTM — Augmentation Configs (per_class_recall) ===
#                 neutral     joy  sadness   anger    fear  disgust  surprise  Overall Accuracy
# A0_NoAug         0.1797  0.0441     0.00  0.6020  0.8105   0.0673    0.0285            0.5161
# A1_NormalAug     0.2058  0.0000     0.00  0.6343  0.7795   0.0385    0.0320            0.5065
# A2_TargetedAug   0.1565  0.0882     0.12  0.5697  0.3010   0.1442    0.3772            0.3100
#
# === BAN — Augmentation Configs (per_class_recall) ===
#                 neutral     joy  sadness   anger    fear  disgust  surprise  Overall Accuracy
# A0_NoAug         0.1826  0.0000     0.02  0.5199  0.7651   0.0769    0.0890            0.4885
# A1_NormalAug     0.1710  0.0000     0.00  0.5448  0.7548   0.0433    0.0427            0.4778
# A2_TargetedAug   0.2087  0.0588     0.08  0.5075  0.3686   0.0865    0.3665            0.3326

# %%
df_stageB_hybrid = pd.DataFrame([{'Config': k, **v} for k, v in stageB_hybrid.items()]).drop(columns='model_name')
df_stageB_ban    = pd.DataFrame([{'Config': k, **v} for k, v in stageB_ban.items()]).drop(columns='model_name')

print("=== Table B1: Hybrid CNN-LSTM — Augmentation ===")
display(df_stageB_hybrid)
print("\n=== Table B2: BAN — Augmentation ===")
display(df_stageB_ban)

combined_B = df_stageB_hybrid.merge(df_stageB_ban, on='Config', suffixes=('_Hybrid', '_BAN'))
combined_B['Avg_Test_Accuracy'] = combined_B[['test_accuracy_Hybrid', 'test_accuracy_BAN']].mean(axis=1)
combined_B = combined_B.sort_values('Avg_Test_Accuracy', ascending=False).reset_index(drop=True)

print("\n=== Combined Decision Table — Best Augmentation ===")
display(combined_B)

best_aug_name = combined_B.iloc[0]['Config']
print(f"\n✅ FINAL CONFIG for the rest of the notebook:")
print(f"   Preprocessing: {best_preprocess_name} -> {best_preprocess_cfg}")
print(f"   Augmentation:  {best_aug_name}")
# Out:
# === Table B1: Hybrid CNN-LSTM — Augmentation ===
#            Config  val_accuracy  test_accuracy  test_macro_recall  \
# 0        A0_NoAug      0.482852       0.516092           0.247444
# 1    A1_NormalAug      0.476534       0.506513           0.241439
# 2  A2_TargetedAug      0.337545       0.309962           0.250974
#
#    test_macro_f1                                   per_class_recall  \
# 0       0.235956  {'neutral': 0.17971014492753623, 'joy': 0.0441...
# 1       0.220166  {'neutral': 0.20579710144927535, 'joy': 0.0, '...
# 2       0.223297  {'neutral': 0.1565217391304348, 'joy': 0.08823...
#
#                                         per_class_f1
# 0  {'neutral': 0.22423146473779385, 'joy': 0.0789...
# 1  {'neutral': 0.24027072758037224, 'joy': 0.0, '...
# 2  {'neutral': 0.18914185639229422, 'joy': 0.0459...
# === Table B2: BAN — Augmentation ===
#            Config  val_accuracy  test_accuracy  test_macro_recall  \
# 0        A0_NoAug      0.477437       0.488506           0.236218
# 1    A1_NormalAug      0.477437       0.477778           0.222363
# 2  A2_TargetedAug      0.334838       0.332567           0.239528
#
#    test_macro_f1                                   per_class_recall  \
# 0       0.231060  {'neutral': 0.1826086956521739, 'joy': 0.0, 's...
# 1       0.207706  {'neutral': 0.17101449275362318, 'joy': 0.0, '...
# 2       0.221446  {'neutral': 0.20869565217391303, 'joy': 0.0588...
#
#                                         per_class_f1
# 0  {'neutral': 0.22066549912434325, 'joy': 0.0, '...
# 1  {'neutral': 0.20848056537102475, 'joy': 0.0, '...
# 2  {'neutral': 0.23491027732463296, 'joy': 0.0408...
# === Combined Decision Table — Best Augmentation ===
#            Config  val_accuracy_Hybrid  test_accuracy_Hybrid  \
# 0        A0_NoAug             0.482852              0.516092
# 1    A1_NormalAug             0.476534              0.506513
# 2  A2_TargetedAug             0.337545              0.309962
#
#    test_macro_recall_Hybrid  test_macro_f1_Hybrid  \
# 0                  0.247444              0.235956
# 1                  0.241439              0.220166
# 2                  0.250974              0.223297
#
#                              per_class_recall_Hybrid  \
# 0  {'neutral': 0.17971014492753623, 'joy': 0.0441...
# 1  {'neutral': 0.20579710144927535, 'joy': 0.0, '...
# 2  {'neutral': 0.1565217391304348, 'joy': 0.08823...
#
#                                  per_class_f1_Hybrid  val_accuracy_BAN  \
# 0  {'neutral': 0.22423146473779385, 'joy': 0.0789...          0.477437
# 1  {'neutral': 0.24027072758037224, 'joy': 0.0, '...          0.477437
# 2  {'neutral': 0.18914185639229422, 'joy': 0.0459...          0.334838
#
#    test_accuracy_BAN  test_macro_recall_BAN  test_macro_f1_BAN  \
# 0           0.488506               0.236218           0.231060
# 1           0.477778               0.222363           0.207706
# 2           0.332567               0.239528           0.221446
#
#                                 per_class_recall_BAN  \
# 0  {'neutral': 0.1826086956521739, 'joy': 0.0, 's...
# 1  {'neutral': 0.17101449275362318, 'joy': 0.0, '...
# 2  {'neutral': 0.20869565217391303, 'joy': 0.0588...
#
#                                     per_class_f1_BAN  Avg_Test_Accuracy
# 0  {'neutral': 0.22066549912434325, 'joy': 0.0, '...           0.502299
# 1  {'neutral': 0.20848056537102475, 'joy': 0.0, '...           0.492146
# 2  {'neutral': 0.23491027732463296, 'joy': 0.0408...           0.321264
# ✅ FINAL CONFIG for the rest of the notebook:
#    Preprocessing: P2_NoiseOnly -> {'clean_noise': False, 'trim_silence': True}
#    Augmentation:  A0_NoAug

# %%
# ==========================================
# MISSING-SAMPLE SUMMARY (for documentation)
# ==========================================
rows = []
for name, skip_report in {**stageA_skips, **stageB_skips}.items():
    for split, reasons in skip_report.items():
        for reason, count in reasons.items():
            rows.append({'Config': name, 'Split': split, 'Reason': reason, 'Count': count})

df_skips = pd.DataFrame(rows)
print("=== Missing / Skipped Sample Report (all configs) ===")
display(df_skips.pivot_table(index='Config', columns='Reason', values='Count', aggfunc='sum', fill_value=0))

print(f"\nTotal skipped across all configs and splits: {df_skips['Count'].sum()}")
# Out:
# === Missing / Skipped Sample Report (all configs) ===
# Reason          missing_file
# Config
# A1_NormalAug               2
# A2_TargetedAug             2
# P0_None                    2
# P1_SilenceOnly             2
# P2_NoiseOnly               2
# P3_Both                    2
# Total skipped across all configs and splits: 12

# %% [markdown]
# ### Best Preprocessing Configuration

# %%
"""
import soundfile as sf

AUDIO_DIRECTORY = "dataset_meld/audio/"
# Define the new base directory for clean audio
CLEAN_AUDIO_DIRECTORY = "dataset_meld/audio/wav_clean/" 
splits = ['train', 'dev', 'test']

print("Starting global silence removal (P1_SilenceOnly) on all audio files...")

for split in splits:
    split_dir = os.path.join(AUDIO_DIRECTORY, f"wav_{split}")
    
    # Define the target directory for this specific split (e.g., wav_clean/wav_train)
    clean_split_dir = os.path.join(CLEAN_AUDIO_DIRECTORY, f"wav_{split}")
    
    # Check if original directory exists to avoid errors
    if not os.path.exists(split_dir):
        print(f"Directory not found: {split_dir}. Skipping...")
        continue
        
    # Create the clean folder if it doesn't exist
    os.makedirs(clean_split_dir, exist_ok=True)
        
    print(f"\nApplying silence removal to {split.upper()} split...")
    
    # Target all wav files in the original directory
    wav_files = [f for f in os.listdir(split_dir) if f.endswith(".wav")]
    
    for filename in tqdm(wav_files, desc=f"Processing {split}"):
        orig_file_path = os.path.join(split_dir, filename)
        clean_file_path = os.path.join(clean_split_dir, filename)
        
        try:
            # Load the audio file using the target sample rate (Config.SR = 16000)
            y, sr = librosa.load(orig_file_path, sr=16000)
            
            # Perform silence removal matching your Stage A preprocessing (top_db=20)
            y_trimmed, _ = librosa.effects.trim(y, top_db=20)
            
            # Save the processed file into the new clean folder
            sf.write(clean_file_path, y_trimmed, sr)
            
        except Exception as e:
            # Skip unreadable/corrupted files silently; Section 2's error handling will catch them
            pass

"""

# %%
import soundfile as sf

AUDIO_DIRECTORY = "dataset_meld/audio/"
# New directory for noise-reduced audio
CLEAN_AUDIO_DIRECTORY = "dataset_meld/audio/wav_clean/" 
splits = ['train', 'dev', 'test']

print("Starting global noise reduction on all audio files...")

for split in splits:
    split_dir = os.path.join(AUDIO_DIRECTORY, f"wav_{split}")
    clean_split_dir = os.path.join(CLEAN_AUDIO_DIRECTORY, f"wav_{split}")
    
    if not os.path.exists(split_dir):
        print(f"Directory not found: {split_dir}. Skipping...")
        continue
        
    os.makedirs(clean_split_dir, exist_ok=True)
        
    print(f"\nApplying noise reduction to {split.upper()} split...")
    
    wav_files = [f for f in os.listdir(split_dir) if f.endswith(".wav")]
    
    for filename in tqdm(wav_files, desc=f"Processing {split}"):
        orig_file_path = os.path.join(split_dir, filename)
        clean_file_path = os.path.join(clean_split_dir, filename)
        
        try:
            # 1. Load the audio file
            y, sr = librosa.load(orig_file_path, sr=16000)
            
            # 2. Perform Noise Reduction
            # prop_decrease=0.8 matches your Stage A configuration
            if len(y) > sr * 0.1:
                y_reduced = nr.reduce_noise(y=y, sr=sr, prop_decrease=0.8)
            else:
                y_reduced = y
            
            # 3. Save the processed file into the new clean folder
            sf.write(clean_file_path, y_reduced, sr)
            
        except Exception as e:
            # Silence failure to maintain continuity for Section 2 processing
            pass

print(f"\n✅ Noise reduction complete! Processed files are saved in: {CLEAN_AUDIO_DIRECTORY}")

# %% [markdown]
# # Section 2. Feature Extraction

# %% [markdown]
# ### 2.1 Textual Sentiment
# Exclude ASR, import RoBERTa, classify textual sentiment from transcription

# %%
AUDIO_DIRECTORY = "dataset_meld/audio/wav_clean/"
AUDIO_EXT = ".wav"
splits = ['train', 'dev', 'test']

os.makedirs("dataset_meld", exist_ok=True)

# Create a timestamp string for the filenames (e.g., "20260617_2030")
timestamp = datetime.now().strftime("%Y%m%d_%H%M")

# --- GLOBAL STATS (per split) ---
stats = defaultdict(int)
failed_samples = []

# Lists to collect data for final graphs
global_sentiment_scores = []

# --- PROCESSING LOOP ---
for split in splits:
    print(f"\n================ {split.upper()} SPLIT ================\n")

    orig_csv = os.path.join("dataset_meld", f"{split}_sent_emo.csv")
    out_csv = os.path.join("dataset_meld", f"prepared_{split}_{timestamp}_sent_emo.csv")

    print(f"Processing: {orig_csv}")
    df = pd.read_csv(orig_csv)

    # --- MOCK RUN MECHANISM ---
    MOCK_MODE = False  # Toggle this to False to run the full dataset
    if MOCK_MODE:
        # Take 10% of the data, sampled randomly
        df = df.sample(frac=0.10, random_state=SEED) 
        print(f"⚠️ MOCK MODE ACTIVE: Processing only 10% of {split} ({len(df)} samples)")
    # --------------------------

    prepared_data = []

    for idx, row in tqdm(df.iterrows(), total=len(df)):
        dia_id = row['Dialogue_ID']
        utt_id = row['Utterance_ID']

        raw_path = os.path.join(
            AUDIO_DIRECTORY,
            f"wav_{split}",
            f"dia{dia_id}_utt{utt_id}{AUDIO_EXT}"
        )
        file_path = os.path.abspath(raw_path)

        # ---------------------------
        # Missing audio
        # ---------------------------
        if not os.path.exists(file_path):
            stats["missing_audio"] += 1
            failed_samples.append({
                "split": split,
                "file_path": file_path,
                "reason": "missing_audio"
            })
            continue

        # ---------------------------
        # Validate CSV fields
        # ---------------------------
        if pd.isna(row['Emotion']) or pd.isna(row['Sentiment']) or pd.isna(row['Utterance']):
            stats["invalid_csv_data"] += 1
            failed_samples.append({
                "split": split,
                "file_path": file_path,
                "reason": "invalid_csv_data"
            })
            continue

        emo_gt = str(row['Emotion']).lower()
        sent_gt = str(row['Sentiment']).lower()
        trans_gt = str(row['Utterance']).strip()

        # ---------------------------
        # Sentiment prediction (on ground-truth transcription)
        # ---------------------------
        try:
            bert_out = sentiment_classifier(trans_gt)[0]
            sent_pred = bert_out['label'].lower()
            sent_score = bert_out['score']

        except Exception as e:
            stats["sentiment_failed"] += 1
            failed_samples.append({
                "split": split, "file_path": file_path, "reason": "sentiment_failed", "error": str(e)
            })
            continue

        # ---------------------------
        # SUCCESS CASE
        # ---------------------------
        prepared_data.append({
            'emotion': emo_gt,
            'sentiment': sent_gt,  
            'textual_sentiment_predicted': sent_pred,
            'textual_sentiment_score': sent_score,
            'transcription_ground_truth': trans_gt,
            'file_path': file_path
        })

        stats["success"] += 1
        global_sentiment_scores.append(sent_score)

    # ---------------------------
    # Save entire batch at once (Optimised for GPU speed)
    # ---------------------------
    if prepared_data:
        chunk_df = pd.DataFrame(prepared_data)
        chunk_df.to_csv(out_csv, index=False)

    print(f"\n✅ Finished {split}. Saved to {out_csv}")
# ---------------------------
# FINAL REPORT
# ---------------------------
print("\n================ FINAL DATASET REPORT ================\n")

total_failures = (
    stats["missing_audio"] + stats["invalid_csv_data"] +
    stats["sentiment_failed"]
)

# Calculate Averages
avg_sent = sum(global_sentiment_scores) / len(global_sentiment_scores) if global_sentiment_scores else 0

print(f"Success samples           : {stats['success']}")
print(f"Missing audio             : {stats['missing_audio']}")
print(f"Invalid CSV data          : {stats['invalid_csv_data']}")
print(f"Sentiment prediction fail : {stats['sentiment_failed']}")
print(f"TOTAL FAILURES            : {total_failures}")
print("-" * 54)
print(f"Average Sentiment Score   : {avg_sent:.4f}")

# ---------------------------
# SAVE FAILURE LOG
# ---------------------------
failed_df = pd.DataFrame(failed_samples)
log_filename = f"dataset_meld/failed_samples_log_{timestamp}.csv"
failed_df.to_csv(log_filename, index=False)

print(f"\nFailure log saved: {log_filename}")

# ---------------------------
# GENERATE DISTRIBUTION GRAPH
# ---------------------------
if global_sentiment_scores:
    plt.figure(figsize=(7, 5))

    sns.histplot(global_sentiment_scores, bins=50, kde=True, color='salmon')
    plt.title("Distribution of RoBERTa Sentiment Confidence")
    plt.xlabel("Confidence Score (0.0 to 1.0)")
    plt.ylabel("Number of Samples")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 2.2 Acoustic Feature & 2.3 Statistical Features
# MFCCs <br>
# Chroma, contrast, zcr, rms

# %%
# ==========================================
# 1. CONFIGURATION
# ==========================================
SR = 16000
MAX_DURATION = 3
MAX_SAMPLES = SR * MAX_DURATION
N_MFCC = 40
MAX_MFCC_LEN = 94 

previous_timestamp = "20260718_1824"

csv_files = {
    'train': os.path.join(Config.DATA_PATH, f"prepared_train_{previous_timestamp}_sent_emo.csv"),
    'dev': os.path.join(Config.DATA_PATH, f"prepared_dev_{previous_timestamp}_sent_emo.csv"),
    'test': os.path.join(Config.DATA_PATH, f"prepared_test_{previous_timestamp}_sent_emo.csv")
}

timestamp = datetime.now().strftime("%Y%m%d_%H%M")
path = os.path.join(Config.DATA_PATH, f"all_features_{split}_{timestamp}.npz")

print(f"Starting Independent Feature Extraction to NPZ (Timestamp: {timestamp})...\n")

# ==========================================
# 2. EXTRACTION & SAVING LOOP (Per Split)
# ==========================================
for split, path in csv_files.items():
    if not os.path.exists(path):
        print(f"File not found: {path}")
        continue
        
    print(f"Processing {split.upper()} set from {path}")
    df = pd.read_csv(path)
    
    successful_rows = []
    mfcc_data = []
    stats_data = []
    
    for _, row in tqdm(df.iterrows(), total=len(df)):
        file_path = row['file_path']
        
        try:
            # 1. Load Audio
            y, _ = librosa.load(file_path, sr=SR)
            
            # 2. Safeguard against ultra-short clips
            if len(y) < 500:
                continue
                
            # 3. Pad or Crop to exactly 3 seconds
            if len(y) > MAX_SAMPLES:
                y = y[:MAX_SAMPLES]
            else:
                y = np.pad(y, (0, int(MAX_SAMPLES - len(y))), 'constant')
                
            # 4. Extract MFCC
            mfcc = librosa.feature.mfcc(y=y, sr=SR, n_mfcc=N_MFCC).T
            if mfcc.shape[0] > MAX_MFCC_LEN:
                mfcc = mfcc[:MAX_MFCC_LEN, :]
            else:
                mfcc = np.pad(mfcc, ((0, MAX_MFCC_LEN - mfcc.shape[0]), (0, 0)), 'constant')
                
            # 5. Extract Statistical Features
            chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=SR).T, axis=0)
            contrast = np.mean(librosa.feature.spectral_contrast(y=y, sr=SR).T, axis=0)
            zcr = np.mean(librosa.feature.zero_crossing_rate(y=y).T, axis=0)
            rms = np.mean(librosa.feature.rms(y=y).T, axis=0)
            
            stats = np.hstack([chroma, contrast, zcr, rms])
            
            # 6. Append to lists 
            successful_rows.append(row)
            mfcc_data.append(mfcc.flatten())
            stats_data.append(stats)
            
        except Exception as e:
            continue

    # ==========================================
    # 3. BUILD ARRAYS & SAVE FOR THIS SPLIT
    # ==========================================
    if successful_rows:
        print(f"Constructing NPZ archive for {split.upper()}...")
        
        # Convert the original rows back into a DataFrame to format them cleanly
        df_meta = pd.DataFrame(successful_rows).reset_index(drop=True)
        if 'split' not in df_meta.columns:
            df_meta.insert(0, 'split', split)
            
        out_npz = f"dataset_meld/all_features_{split}_{timestamp}.npz"
        print(f"Saving {split.upper()} to {out_npz}...")

        # Convert numerical lists to strict numpy arrays (float32 saves 50% memory)
        np_mfcc = np.array(mfcc_data, dtype=np.float32)
        np_stats = np.array(stats_data, dtype=np.float32)
        
        # Convert metadata to numpy structures
        np_meta = df_meta.to_numpy(dtype=str)
        meta_cols = df_meta.columns.to_numpy(dtype=str)

        # Save as a compressed NumPy archive
        np.savez_compressed(
            out_npz,
            mfcc=np_mfcc,
            stats=np_stats,
            meta=np_meta,
            meta_cols=meta_cols
        )
        print(f"{split.upper()} Matrix shapes -> Meta: {np_meta.shape}, MFCC: {np_mfcc.shape}, Stats: {np_stats.shape}\n")
    else:
        print(f"No valid samples extracted for {split.upper()}.\n")

    # ==========================================
    # 4. MEMORY CLEANUP
    # ==========================================
    del successful_rows, mfcc_data, stats_data, df_meta, np_mfcc, np_stats, np_meta
    gc.collect()

print("All splits processed and saved independently as NPZ archives!")

# %% [markdown]
# # 3.0 Load and Import (features and functions)

# %% [markdown]
# ### Import NPZs (labels + acoustic features + textual sentiment predicted)

# %%
def load_and_prepare_npz(split, timestamp="20260718_1827"):
    path = os.path.join(Config.DATA_PATH, f"all_features_{split}_{timestamp}.npz")
    data = np.load(path, allow_pickle=True)
    
    # Reshape MFCCs back to 2D sequence (Batch, TimeSteps, Features)
    X_mfcc = data['mfcc'].reshape(-1, Config.MAX_MFCC_LEN, Config.N_MFCC)
    X_stats = data['stats']
    
    meta_cols = data['meta_cols'].tolist()
    
    # Extract Target Labels (Emotion)
    emo_idx = meta_cols.index('emotion')
    y_raw = data['meta'][:, emo_idx]
    
    # Extract Textual Sentiment Predicted strings (Bimodal setup)
    pred_idx = meta_cols.index('textual_sentiment_predicted')
    X_text_pred_raw = data['meta'][:, pred_idx]
    
    return X_mfcc, X_stats, X_text_pred_raw, y_raw

print("Loading Data...")
X_train_mfcc, X_train_stats, X_train_txt_raw, y_train_raw = load_and_prepare_npz('train')
X_dev_mfcc, X_dev_stats, X_dev_txt_raw, y_dev_raw = load_and_prepare_npz('dev')
X_test_mfcc, X_test_stats, X_test_txt_raw, y_test_raw = load_and_prepare_npz('test')

# --- ENCODE TARGETS (Emotion) ---
label_encoder = LabelEncoder()
label_encoder.fit(Config.DEFAULT_CLASSES)

y_train = label_encoder.transform(y_train_raw)
y_dev = label_encoder.transform(y_dev_raw)
y_test = label_encoder.transform(y_test_raw)
num_classes = len(Config.DEFAULT_CLASSES)

# --- ENCODE TEXT MODALITY (Sentiment Predictions) ---
# OneHotEncoder transforms 'positive', 'neutral', 'negative' into 2D numerical vectors 
sentiment_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# We reshape to (-1, 1) because OneHotEncoder expects a 2D array matrix 
X_train_txt = sentiment_encoder.fit_transform(X_train_txt_raw.reshape(-1, 1))
X_dev_txt = sentiment_encoder.transform(X_dev_txt_raw.reshape(-1, 1))
X_test_txt = sentiment_encoder.transform(X_test_txt_raw.reshape(-1, 1))

print(f"✅ Data Loaded & Encoded.")
print(f"Train MFCC Shape: {X_train_mfcc.shape}")
print(f"Train Stats Shape: {X_train_stats.shape}")
print(f"Train Text Modality Shape: {X_train_txt.shape} (One-Hot Encoded Sentiment)")
# Out:
# Loading Data...
# ✅ Data Loaded & Encoded.
# Train MFCC Shape: (9988, 94, 40)
# Train Stats Shape: (9988, 21)
# Train Text Modality Shape: (9988, 3) (One-Hot Encoded Sentiment)

# %% [markdown]
# ### Evaluation Functions

# %%
def plot_training_history(history, model_name):
    """Plots training/validation accuracy and loss."""
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Accuracy Plot
    axes[0].plot(history.history['accuracy'], label='Train Accuracy', color='blue')
    axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')
    axes[0].set_title(f'{model_name} - Model Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(True, linestyle='--', alpha=0.6)
    
    # Loss Plot
    axes[1].plot(history.history['loss'], label='Train Loss', color='blue')
    axes[1].plot(history.history['val_loss'], label='Validation Loss', color='orange')
    axes[1].set_title(f'{model_name} - Model Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(True, linestyle='--', alpha=0.6)
    
    plt.tight_layout()
    plt.show()

def evaluate_model_performance(model, X_test, y_test, model_name):
    """Generates Classification Report and Percentage-based Confusion Matrix."""
    print(f"\n================ Evaluating {model_name} ================")
    
    # Predictions
    y_pred_probs = model.predict(X_test, verbose=0)
    y_pred = np.argmax(y_pred_probs, axis=1)
    
    # 1. Classification Report
    print("\n--- Classification Report ---")
    print(classification_report(y_test, y_pred, target_names=label_encoder.classes_, digits=4))
    
    # 2. Confusion Matrix (Raw & Percentages)
    cm = confusion_matrix(y_test, y_pred)
    # Calculate percentages across rows (true labels)
    cm_percentages = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cm_percentages = np.nan_to_num(cm_percentages) # Handle division by zero
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_percentages, annot=True, fmt='.2%', cmap='Blues',
                xticklabels=label_encoder.classes_,
                yticklabels=label_encoder.classes_,
                cbar_kws={'label': 'Percentage of True Class'})
    plt.title(f'{model_name} - Confusion Matrix (Percentages)')
    plt.ylabel('Ground Truth (True Label)')
    plt.xlabel('Predicted Label')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Section 3. Train and Test

# %% [markdown]
# ## CNN-LSTM Model (Training & Testing)

# %%
# TRAIN
cnn_lstm_model = build_hybrid_cnn_lstm(num_classes, X_train_stats.shape[1], X_train_txt.shape[1])

print(f"Training for exactly {Config.EPOCHS} epochs...")
history_cnn_lstm = cnn_lstm_model.fit(
    [X_train_mfcc, X_train_stats, X_train_txt], y_train,             
    validation_data=([X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev),     
    epochs=Config.EPOCHS,
    batch_size=Config.BATCH_SIZE,
    verbose=1,
)
# Out:
# Training for exactly 50 epochs...
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.4769 - loss: 1.4810 - val_accuracy: 0.4639 - val_loss: 1.4988
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5082 - loss: 1.4067 - val_accuracy: 0.4756 - val_loss: 1.4918
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5099 - loss: 1.3972 - val_accuracy: 0.4756 - val_loss: 1.5071
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5125 - loss: 1.3938 - val_accuracy: 0.4765 - val_loss: 1.4947
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5123 - loss: 1.3865 - val_accuracy: 0.4765 - val_loss: 1.4958
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5145 - loss: 1.3851 - val_accuracy: 0.4765 - val_loss: 1.4931
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5133 - loss: 1.3845 - val_accuracy: 0.4684 - val_loss: 1.5352
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5171 - loss: 1.3804 - val_accuracy: 0.4684 - val_loss: 1.5391
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5171 - loss: 1.3785 - val_accuracy: 0.4666 - val_loss: 1.5304
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5146 - loss: 1.3796 - val_accuracy: 0.4693 - val_loss: 1.5185
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5150 - loss: 1.3798 - val_accuracy: 0.4684 - val_loss: 1.5025
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5175 - loss: 1.3757 - val_accuracy: 0.4720 - val_loss: 1.5159
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5147 - loss: 1.3761 - val_accuracy: 0.4702 - val_loss: 1.4981
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5189 - loss: 1.3732 - val_accuracy: 0.4666 - val_loss: 1.5087
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5178 - loss: 1.3736 - val_accuracy: 0.4702 - val_loss: 1.5343
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5157 - loss: 1.3729 - val_accuracy: 0.4675 - val_loss: 1.5291
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5198 - loss: 1.3713 - val_accuracy: 0.4720 - val_loss: 1.5474
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5166 - loss: 1.3699 - val_accuracy: 0.4648 - val_loss: 1.5965
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5184 - loss: 1.3689 - val_accuracy: 0.4675 - val_loss: 1.5544
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5166 - loss: 1.3650 - val_accuracy: 0.4684 - val_loss: 1.5783
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5213 - loss: 1.3644 - val_accuracy: 0.4711 - val_loss: 1.5137
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5158 - loss: 1.3669 - val_accuracy: 0.4657 - val_loss: 1.5751
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5186 - loss: 1.3642 - val_accuracy: 0.4693 - val_loss: 1.5835
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5152 - loss: 1.3637 - val_accuracy: 0.4630 - val_loss: 1.5794
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5219 - loss: 1.3633 - val_accuracy: 0.4729 - val_loss: 1.5526
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5202 - loss: 1.3597 - val_accuracy: 0.4657 - val_loss: 1.6055
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5253 - loss: 1.3591 - val_accuracy: 0.4675 - val_loss: 1.5893
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5232 - loss: 1.3584 - val_accuracy: 0.4603 - val_loss: 1.5787
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5240 - loss: 1.3592 - val_accuracy: 0.4621 - val_loss: 1.5796
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5238 - loss: 1.3522 - val_accuracy: 0.4603 - val_loss: 1.5777
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5231 - loss: 1.3568 - val_accuracy: 0.4594 - val_loss: 1.6113
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5201 - loss: 1.3559 - val_accuracy: 0.4648 - val_loss: 1.5716
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5232 - loss: 1.3552 - val_accuracy: 0.4549 - val_loss: 1.6202
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5229 - loss: 1.3561 - val_accuracy: 0.4594 - val_loss: 1.5641
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5220 - loss: 1.3538 - val_accuracy: 0.4567 - val_loss: 1.6078
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5253 - loss: 1.3506 - val_accuracy: 0.4630 - val_loss: 1.6370
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5192 - loss: 1.3545 - val_accuracy: 0.4603 - val_loss: 1.5681
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5213 - loss: 1.3576 - val_accuracy: 0.4522 - val_loss: 1.5798
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5202 - loss: 1.3576 - val_accuracy: 0.4621 - val_loss: 1.5819
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5227 - loss: 1.3543 - val_accuracy: 0.4522 - val_loss: 1.5539
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5203 - loss: 1.3545 - val_accuracy: 0.4612 - val_loss: 1.5429
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5228 - loss: 1.3500 - val_accuracy: 0.4540 - val_loss: 1.5550
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5221 - loss: 1.3488 - val_accuracy: 0.4603 - val_loss: 1.5699
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5223 - loss: 1.3487 - val_accuracy: 0.4567 - val_loss: 1.5207
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5209 - loss: 1.3516 - val_accuracy: 0.4558 - val_loss: 1.5613
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5215 - loss: 1.3483 - val_accuracy: 0.4576 - val_loss: 1.5564
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5233 - loss: 1.3517 - val_accuracy: 0.4594 - val_loss: 1.5624
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5244 - loss: 1.3453 - val_accuracy: 0.4612 - val_loss: 1.5580
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5252 - loss: 1.3423 - val_accuracy: 0.4639 - val_loss: 1.5804
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5232 - loss: 1.3431 - val_accuracy: 0.4612 - val_loss: 1.5897

# %%
# ==========================================
# 4. EVALUATE
# ==========================================
plot_training_history(history_cnn_lstm, "Bimodal CNN-LSTM Model")
evaluate_model_performance(cnn_lstm_model, [X_test_mfcc, X_test_stats, X_test_txt], y_test, "Bimodal CNN-LSTM Model")
# Out:
# ================ Evaluating Bimodal CNN-LSTM Model ================
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#        anger     0.3086    0.0725    0.1174       345
#      disgust     0.0000    0.0000    0.0000        68
#         fear     0.0000    0.0000    0.0000        50
#          joy     0.4432    0.6891    0.5394       402
#      neutral     0.5693    0.8177    0.6712      1256
#      sadness     0.0968    0.0288    0.0444       208
#     surprise     0.0571    0.0071    0.0127       281
#
#     accuracy                         0.5123      2610
#    macro avg     0.2107    0.2307    0.1979      2610
# weighted avg     0.3969    0.5123    0.4265      2610
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
evaluate_model_performance(cnn_lstm_model, [X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev, "Bimodal CNN-LSTM Model")
# Out:
# ================ Evaluating Bimodal CNN-LSTM Model ================
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#        anger     0.3585    0.1242    0.1845       153
#      disgust     0.0000    0.0000    0.0000        22
#         fear     0.0000    0.0000    0.0000        40
#          joy     0.3722    0.6074    0.4615       163
#      neutral     0.5166    0.8273    0.6361       469
#      sadness     0.1600    0.0360    0.0588       111
#     surprise     0.1250    0.0067    0.0127       150
#
#     accuracy                         0.4612      1108
#    macro avg     0.2189    0.2288    0.1934      1108
# weighted avg     0.3559    0.4612    0.3702      1108
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ### 1. Modality ablation — test the "text branch is doing all the work" hypothesis
# Run inference three times, each time zeroing out one branch's input, and compare accuracy drop:

# %%
def eval_with_branch_masked(model, X_mfcc, X_stats, X_txt, y, mask_branch=None):
    Xm, Xs, Xt = X_mfcc.copy(), X_stats.copy(), X_txt.copy()
    if mask_branch == "mfcc":
        Xm[:] = 0
    elif mask_branch == "stats":
        Xs[:] = 0
    elif mask_branch == "text":
        Xt[:] = 0
    loss, acc = model.evaluate([Xm, Xs, Xt], y, verbose=0)
    return loss, acc

# %%
baseline_acc = cnn_lstm_model.evaluate([X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev, verbose=0)[1]
loss_no_mfcc, acc_no_mfcc = eval_with_branch_masked(cnn_lstm_model, X_dev_mfcc, X_dev_stats, X_dev_txt, y_dev, "mfcc")
loss_no_stats, acc_no_stats = eval_with_branch_masked(cnn_lstm_model, X_dev_mfcc, X_dev_stats, X_dev_txt, y_dev, "stats")
loss_no_text, acc_no_text = eval_with_branch_masked(cnn_lstm_model, X_dev_mfcc, X_dev_stats, X_dev_txt, y_dev, "text")

print(f"Baseline (all branches):    Accuracy - {baseline_acc:.4f}, ")
print(f"Text branch zeroed:         Accuracy - {acc_no_text:.4f}  (drop = {baseline_acc-acc_no_text:.4f}), Loss - {loss_no_text:.4f}")
print(f"MFCC branch zeroed:         Accuracy - {acc_no_mfcc:.4f}  (drop = {baseline_acc-acc_no_mfcc:.4f}), Loss - {loss_no_mfcc:.4f}")
print(f"Stats branch zeroed:        Accuracy - {acc_no_stats:.4f}  (drop = {baseline_acc-acc_no_stats:.4f}), Loss - {loss_no_stats:.4f}")
# Out:
# Baseline (all branches):    Accuracy - 0.4612,
# Text branch zeroed:         Accuracy - 0.4079  (drop = 0.0532), Loss - 1.7011
# MFCC branch zeroed:         Accuracy - 0.4440  (drop = 0.0171), Loss - 1.7350
# Stats branch zeroed:        Accuracy - 0.0912  (drop = 0.3700), Loss - 6.5376

# %%
baseline_acc = cnn_lstm_model.evaluate([X_test_mfcc, X_test_stats, X_test_txt], y_test, verbose=0)[1]
loss_no_mfcc, acc_no_mfcc = eval_with_branch_masked(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, "mfcc")
loss_no_stats, acc_no_stats = eval_with_branch_masked(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, "stats")
loss_no_text, acc_no_text = eval_with_branch_masked(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, "text")

print(f"Baseline (all branches):    Accuracy - {baseline_acc:.4f}, ")
print(f"Text branch zeroed:         Accuracy - {acc_no_text:.4f}  (drop = {baseline_acc-acc_no_text:.4f}), Loss - {loss_no_text:.4f}")
print(f"MFCC branch zeroed:         Accuracy - {acc_no_mfcc:.4f}  (drop = {baseline_acc-acc_no_mfcc:.4f}), Loss - {loss_no_mfcc:.4f}")
print(f"Stats branch zeroed:        Accuracy - {acc_no_stats:.4f}  (drop = {baseline_acc-acc_no_stats:.4f}), Loss - {loss_no_stats:.4f}")
# Out:
# Baseline (all branches):    Accuracy - 0.5123,
# Text branch zeroed:         Accuracy - 0.4674  (drop = 0.0448), Loss - 1.5782
# MFCC branch zeroed:         Accuracy - 0.4648  (drop = 0.0475), Loss - 1.6055
# Stats branch zeroed:        Accuracy - 0.0885  (drop = 0.4238), Loss - 6.4197

# %% [markdown]
# ### 2. Permutation importance (more rigorous than zeroing)
# Zeroing can be an out-of-distribution input the model has never seen. Permutation (shuffling that branch's values across the batch) keeps the same distribution:

# %%
def permutation_importance(model, X_mfcc, X_stats, X_txt, y, branch, n_repeats=5):
    baseline = model.evaluate([X_mfcc, X_stats, X_txt], y, verbose=0)[1]
    drops = []
    for _ in range(n_repeats):
        idx = np.random.permutation(len(y))
        Xm, Xs, Xt = X_mfcc.copy(), X_stats.copy(), X_txt.copy()
        if branch == "mfcc": Xm = Xm[idx]
        elif branch == "stats": Xs = Xs[idx]
        elif branch == "text": Xt = Xt[idx]
        acc = model.evaluate([Xm, Xs, Xt], y, verbose=0)[1]
        drops.append(baseline - acc)
    return np.mean(drops), np.std(drops)

for branch in ["mfcc", "stats", "text"]:
    mean_drop, std_drop = permutation_importance(cnn_lstm_model, X_dev_mfcc, X_dev_stats, X_dev_txt, y_dev, branch)
    print(f"{branch:6s}: mean accuracy drop = {mean_drop:.4f} ± {std_drop:.4f}")

# %%
print("Stats feature means:", X_dev_stats.mean(axis=0)[:5])
print("Stats feature stds:", X_dev_stats.std(axis=0)[:5])

# %% [markdown]
# ### 3. Investigate why stats contributes nothing
# — worth checking whether the stats features themselves carry emotion-relevant signal at all, independent of the model:

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200, random_state=SEED)
rf.fit(X_train_stats, y_train)
print("Stats-only RF dev accuracy:", rf.score(X_dev_stats, y_dev))

# %% [markdown]
# ### 4. CONFUSION MATRIX: within-valence vs cross-valence error analysis

# %%
# ==========================================
# CONFUSION MATRIX: within-valence vs cross-valence error analysis
# ==========================================
# Define emotion label order (must match your label encoding, e.g., LabelEncoder classes_)
emotion_labels = ['anger', 'disgust', 'fear', 'joy', 'neutral', 'sadness', 'surprise']

# Get model predictions on the dev set
y_pred_probs = cnn_lstm_model.predict([X_dev_mfcc, X_dev_stats, X_dev_txt])
y_pred = np.argmax(y_pred_probs, axis=1)

# Full classification report
print("=" * 60)
print("CLASSIFICATION REPORT (Dev Set)")
print("=" * 60)
print(classification_report(y_dev, y_pred, target_names=emotion_labels, digits=4))

# Confusion matrix
cm = confusion_matrix(y_dev, y_pred)

plt.figure(figsize=(9, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.title("Confusion Matrix — Dev Set")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()

# ==========================================
# Group emotions into valence buckets and quantify within- vs cross-valence errors
# ==========================================
valence_map = {
    'joy': 'positive',
    'surprise': 'positive',      # surprise is ambiguous but often grouped positive in MELD's own sentiment mapping
    'neutral': 'neutral',
    'anger': 'negative',
    'disgust': 'negative',
    'fear': 'negative',
    'sadness': 'negative'
}

within_valence_errors = 0
cross_valence_errors = 0
correct = 0

for true_idx, pred_idx in zip(y_dev, y_pred):
    true_label = emotion_labels[true_idx]
    pred_label = emotion_labels[pred_idx]

    if true_label == pred_label:
        correct += 1
    elif valence_map[true_label] == valence_map[pred_label]:
        within_valence_errors += 1
    else:
        cross_valence_errors += 1

total = len(y_dev)
print("\n" + "=" * 60)
print("ERROR BREAKDOWN BY VALENCE")
print("=" * 60)
print(f"Correct predictions        : {correct} ({correct/total:.4f})")
print(f"Within-valence errors      : {within_valence_errors} ({within_valence_errors/total:.4f})")
print(f"Cross-valence errors       : {cross_valence_errors} ({cross_valence_errors/total:.4f})")
print(f"Total errors               : {within_valence_errors + cross_valence_errors}")
print(f"\nOf all errors, {within_valence_errors / (within_valence_errors + cross_valence_errors):.1%} stay within the same valence group")

# %% [markdown]
# ### 5. Feature Sufficiency and Feature Necessity

# %%
def evaluate_masked_accuracy(model, X_mfcc, X_stats, X_txt, y, mask_target=None):
    Xm, Xs, Xt = X_mfcc.copy(), X_stats.copy(), X_txt.copy()
    if mask_target == "mfcc":
        Xm[:] = 0.0
    elif mask_target == "stats":
        Xs[:] = 0.0
    elif mask_target == "text":
        Xt[:] = 0.0
    
    loss, acc = model.evaluate([Xm, Xs, Xt], y, verbose=0)
    return acc

baseline_test_acc = cnn_lstm_model.evaluate([X_test_mfcc, X_test_stats, X_test_txt], y_test, verbose=0)[1]

# 1. Feature Sufficiency Evaluation (Individual modalities active)
sufficiency_scores = {
    "Acoustic Sequence (MFCC)": evaluate_masked_accuracy(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, mask_target="none"), # Handled via baseline logic definition
    "Acoustic Stats": evaluate_masked_accuracy(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, mask_target="none"),
    "Textual Sentiment": evaluate_masked_accuracy(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, mask_target="none")
}

# Explicitly isolate each single modality condition
suff_mfcc = evaluate_masked_accuracy(cnn_lstm_model, X_test_mfcc, np.zeros_like(X_test_stats), np.zeros_like(X_test_txt), y_test, mask_target=None)
suff_stats = evaluate_masked_accuracy(cnn_lstm_model, np.zeros_like(X_test_mfcc), X_test_stats, np.zeros_like(X_test_txt), y_test, mask_target=None)
suff_text = evaluate_masked_accuracy(cnn_lstm_model, np.zeros_like(X_test_mfcc), np.zeros_like(X_test_stats), X_test_txt, y_test, mask_target=None)

# 2. Feature Necessity Evaluation (Individual modalities completely zeroed out)
nec_no_mfcc = evaluate_masked_accuracy(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, mask_target="mfcc")
nec_no_stats = evaluate_masked_accuracy(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, mask_target="stats")
nec_no_text = evaluate_masked_accuracy(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, mask_target="text")

# --- PLOTTING DATA GENERATION ---
modalities = ["Acoustic Sequence (MFCC)", "Acoustic Stats", "Textual Sentiment"]
sufficiency_values = [suff_mfcc, suff_stats, suff_text]
necessity_values = [nec_no_mfcc, nec_no_stats, nec_no_text]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Graph A: Feature Sufficiency
bars1 = ax1.bar(modalities, sufficiency_values, color=['#4285F4', '#EA4335', '#FBBC05'], edgecolor='black', width=0.5)
ax1.axhline(baseline_test_acc, color='red', linestyle='--', label=f'Baseline ({baseline_test_acc:.4f})')
ax1.set_title("Feature Sufficiency Analysis\n(Inference Using Single Isolated Feature Branch)", fontsize=12, fontweight='bold')
ax1.set_ylabel("Test Set Accuracy Score", fontsize=11)
ax1.set_ylim(0, 1.0)
ax1.grid(axis='y', linestyle=':', alpha=0.6)
ax1.legend(loc='upper right')
for bar in bars1:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval + 0.02, f"{yval:.4f}", ha='center', va='bottom', fontweight='bold')

# Graph B: Feature Necessity
bars2 = ax2.bar(modalities, necessity_values, color=['#A0C2F9', '#F3A39C', '#FDE09A'], edgecolor='black', width=0.5)
ax2.axhline(baseline_test_acc, color='red', linestyle='--', label=f'Baseline ({baseline_test_acc:.4f})')
ax2.set_title("Feature Necessity Analysis\n(Performance Degradation when Feature Branch is Removed)", fontsize=12, fontweight='bold')
ax2.set_ylabel("Test Set Accuracy Score", fontsize=11)
ax2.set_ylim(0, 1.0)
ax2.grid(axis='y', linestyle=':', alpha=0.6)
ax2.legend(loc='upper right')
for bar in bars2:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval + 0.02, f"{yval:.4f}", ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# 1. Map the exact column indices for the Statistical Features (Total: 21 dims)
stat_feature_slices = {
    "Chroma (12 dims)": slice(0, 12),
    "Spectral Contrast (7 dims)": slice(12, 19),
    "ZCR (1 dim)": slice(19, 20),
    "RMS Energy (1 dim)": slice(20, 21)
}

def evaluate_detailed_stats(model, X_mfcc, X_stats, X_txt, y, target_feature, mode):
    """
    mode='sufficiency': Zeros out MFCC, Text, and all other stats EXCEPT the target.
    mode='necessity': Keeps everything active, but zeros out ONLY the target stat.
    """
    Xm, Xs, Xt = X_mfcc.copy(), X_stats.copy(), X_txt.copy()
    
    if mode == "sufficiency":
        # Turn off other main modalities completely
        Xm[:] = 0.0
        Xt[:] = 0.0
        
        # Create a blank stats array, then copy over ONLY the targeted statistical feature
        Xs_isolated = np.zeros_like(Xs)
        Xs_isolated[:, stat_feature_slices[target_feature]] = Xs[:, stat_feature_slices[target_feature]]
        Xs = Xs_isolated
        
    elif mode == "necessity":
        # Keep the joint model entirely active, just blind the model to this specific stat
        Xs[:, stat_feature_slices[target_feature]] = 0.0
        
    loss, acc = model.evaluate([Xm, Xs, Xt], y, verbose=0)
    return acc

# Calculate Baseline performance using the trained BAN model on the test dataset
baseline_test_acc = cnn_lstm_model.evaluate([X_test_mfcc, X_test_stats, X_test_txt], y_test, verbose=0)[1]

# 2. Compute Sufficiency and Necessity for each individual statistical feature
stat_features = list(stat_feature_slices.keys())
sufficiency_values = []
necessity_values = []

for feature in stat_features:
    suff_acc = evaluate_detailed_stats(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, feature, mode="sufficiency")
    nec_acc = evaluate_detailed_stats(cnn_lstm_model, X_test_mfcc, X_test_stats, X_test_txt, y_test, feature, mode="necessity")
    
    sufficiency_values.append(suff_acc)
    necessity_values.append(nec_acc)

# --- 3. PLOTTING DATA GENERATION ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

colors_suff = ['#FF9999', '#FFB366', '#FFCC99', '#FFE6CC']
colors_nec = ['#99CCFF', '#99E6FF', '#CCE6FF', '#E6F2FF']

# Graph A: Individual Feature Sufficiency
bars1 = ax1.bar(stat_features, sufficiency_values, color=colors_suff, edgecolor='black', width=0.5)
ax1.axhline(baseline_test_acc, color='red', linestyle='--', label=f'Baseline ({baseline_test_acc:.4f})')
ax1.set_title("Statistical Feature Sufficiency\n(Model Performance Using ONLY This Specific Feature)", fontsize=12, fontweight='bold')
ax1.set_ylabel("Test Set Accuracy Score", fontsize=11)
ax1.set_ylim(0, 1.0)
ax1.grid(axis='y', linestyle=':', alpha=0.6)
ax1.legend(loc='upper right')
for bar in bars1:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval + 0.015, f"{yval:.4f}", ha='center', va='bottom', fontweight='bold', fontsize=10)

# Graph B: Individual Feature Necessity
bars2 = ax2.bar(stat_features, necessity_values, color=colors_nec, edgecolor='black', width=0.5)
ax2.axhline(baseline_test_acc, color='red', linestyle='--', label=f'Baseline ({baseline_test_acc:.4f})')
ax2.set_title("Statistical Feature Necessity\n(Performance Degradation When ONLY This Feature is Dropped)", fontsize=12, fontweight='bold')
ax2.set_ylabel("Test Set Accuracy Score", fontsize=11)
ax2.set_ylim(0, 1.0)
ax2.grid(axis='y', linestyle=':', alpha=0.6)
ax2.legend(loc='upper right')
for bar in bars2:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval + 0.015, f"{yval:.4f}", ha='center', va='bottom', fontweight='bold', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. Ablation Study on Class Configuration

# %%
# Container for matching experiment rows
ablation_rows = []
per_class_matrix_rows = [] 
unique_test_labels = label_encoder.classes_

print("Starting Multi-Class Ablation Loop using Hybrid CNN-LSTM architecture layout...")

# --- 1. RUN BASELINE CONFIGURATION ---
print("\n[Experiment 0] running Baseline Joint Configuration (All 7 Classes)...")
y_pred_probs_base = cnn_lstm_model.predict([X_test_mfcc, X_test_stats, X_test_txt], verbose=0)
y_pred_base = np.argmax(y_pred_probs_base, axis=1)

base_report = classification_report(y_test, y_pred_base, target_names=unique_test_labels, output_dict=True, digits=4)

ablation_rows.append({
    "Dropped Class": "None (Baseline)",
    "Test Accuracy": base_report["accuracy"],
    "Macro Precision": base_report["macro avg"]["precision"],
    "Macro Recall": base_report["macro avg"]["recall"],
    "Macro F1-Score": base_report["macro avg"]["f1-score"]
})

# extract per-class recall and F1 for the baseline row
base_row_recall = {"Dropped Class": "None (Baseline)"}
base_row_f1 = {"Dropped Class": "None (Baseline)"}
for cls in unique_test_labels:
    base_row_recall[cls] = base_report[cls]["recall"]
    base_row_f1[f"{cls} (F1)"] = base_report[cls]["f1-score"]
per_class_matrix_rows.append({**base_row_recall, **base_row_f1})

# --- 2. LOOP TO DROPPED SINGLE CLASSES ---
for idx, target_drop_cls in enumerate(unique_test_labels):
    print(f"\n[Experiment {idx+1}/7] Evaluated Performance Excluding Class: '{target_drop_cls}'")
    
    # Calculate index mapping value
    encoded_drop_idx = label_encoder.transform([target_drop_cls])[0]
    
    # Isolate training segments
    train_mask = (y_train != encoded_drop_idx)
    dev_mask = (y_dev != encoded_drop_idx)
    test_mask = (y_test != encoded_drop_idx)
    
    # Subset target structures matching filter metrics
    X_tr_m, X_tr_s, X_tr_t, y_tr = X_train_mfcc[train_mask], X_train_stats[train_mask], X_train_txt[train_mask], y_train[train_mask]
    X_dv_m, X_dv_s, X_dv_t, y_dv = X_dev_mfcc[dev_mask], X_dev_stats[dev_mask], X_dev_txt[dev_mask], y_dev[dev_mask]
    X_ts_m, X_ts_s, X_ts_t, y_ts = X_test_mfcc[test_mask], X_test_stats[test_mask], X_test_txt[test_mask], y_test[test_mask]
    
    # Compute new subset balanced weights weights
    sub_cw = class_weight.compute_class_weight('balanced', classes=np.unique(y_tr), y=y_tr)
    sub_cw_dict = {cls: weight for cls, weight in zip(np.unique(y_tr), sub_cw)}
    
    # Instantiate new model architecture matching 7 class projection space layout
    tf.keras.backend.clear_session()
    ablation_model = build_hybrid_cnn_lstm(num_classes=len(Config.DEFAULT_CLASSES), stats_dim=X_tr_s.shape[1], sent_dim=X_tr_t.shape[1])
    
    # Train alternative classification space
    ablation_model.fit(
        [X_tr_m, X_tr_s, X_tr_t], y_tr,
        validation_data=([X_dv_m, X_dv_s, X_dv_t], y_dv),
        epochs=Config.EPOCHS, batch_size=Config.BATCH_SIZE, verbose=1
    )
    
    # Generate prediction bounds
    y_pred_probs = ablation_model.predict([X_ts_m, X_ts_s, X_ts_t], verbose=0)
    y_pred = np.argmax(y_pred_probs, axis=1)
    
    # Form conditional subset names list for evaluation report
    active_class_names = [cls for cls in unique_test_labels if cls != target_drop_cls]
    
    # Build localized metrics framework dictionary
    rep = classification_report(y_ts, y_pred, labels=np.unique(y_tr), target_names=active_class_names, output_dict=True, digits=4)
    
    ablation_rows.append({
        "Dropped Class": f"Excluding {target_drop_cls}",
        "Test Accuracy": rep["accuracy"],
        "Macro Precision": rep["macro avg"]["precision"],
        "Macro Recall": rep["macro avg"]["recall"],
        "Macro F1-Score": rep["macro avg"]["f1-score"]
    })

    # extract per-class recall and F1, leaving the dropped class blank (not 0.0)
    row_recall = {"Dropped Class": f"Excluding {target_drop_cls}"}
    row_f1 = {"Dropped Class": f"Excluding {target_drop_cls}"}
    for cls in unique_test_labels:
        if cls == target_drop_cls:
            row_recall[cls] = np.nan          # class wasn't in this run at all — NaN, not 0
            row_f1[f"{cls} (F1)"] = np.nan
        else:
            row_recall[cls] = rep[cls]["recall"]
            row_f1[f"{cls} (F1)"] = rep[cls]["f1-score"]
    per_class_matrix_rows.append({**row_recall, **row_f1})
    
    del ablation_model; gc.collect()

# --- 3. DISPLAY FINAL PERFORMANCE FRAMEWORK TABLE ---
df_class_ablation_report = pd.DataFrame(ablation_rows)
print("\n" + "="*30 + " CLASS ABLATION COMPARISON REPORT " + "="*30)
display(df_class_ablation_report.style.highlight_max(subset=["Test Accuracy", "Macro F1-Score"], color="darkred").format(precision=4))

# --- 4. NEW: DISPLAY PER-CLASS RECALL/F1 MATRIX ---
df_per_class_ablation = pd.DataFrame(per_class_matrix_rows).set_index("Dropped Class")
print("\n" + "="*30 + " PER-CLASS RECALL/F1 MATRIX (Class Ablation) " + "="*30)
display(df_per_class_ablation.style.format(precision=4, na_rep="—"))
# Out:
# Starting Multi-Class Ablation Loop using Hybrid CNN-LSTM architecture layout...
#
# [Experiment 0] running Baseline Joint Configuration (All 7 Classes)...
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# [Experiment 1/7] Evaluated Performance Excluding Class: 'anger'
# Epoch 1/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5466 - loss: 1.2969 - val_accuracy: 0.5089 - val_loss: 1.2915
# Epoch 2/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5595 - loss: 1.2191 - val_accuracy: 0.5173 - val_loss: 1.2906
# Epoch 3/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5646 - loss: 1.2090 - val_accuracy: 0.5204 - val_loss: 1.2877
# Epoch 4/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5657 - loss: 1.2005 - val_accuracy: 0.5277 - val_loss: 1.2995
# Epoch 5/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5694 - loss: 1.1969 - val_accuracy: 0.5173 - val_loss: 1.2841
# Epoch 6/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5698 - loss: 1.1932 - val_accuracy: 0.5309 - val_loss: 1.3052
# Epoch 7/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5702 - loss: 1.1894 - val_accuracy: 0.5257 - val_loss: 1.2949
# Epoch 8/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5675 - loss: 1.1881 - val_accuracy: 0.5267 - val_loss: 1.2991
# Epoch 9/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5721 - loss: 1.1869 - val_accuracy: 0.5225 - val_loss: 1.3011
# Epoch 10/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5713 - loss: 1.1854 - val_accuracy: 0.5309 - val_loss: 1.2881
# Epoch 11/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5747 - loss: 1.1836 - val_accuracy: 0.5215 - val_loss: 1.2913
# Epoch 12/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5716 - loss: 1.1854 - val_accuracy: 0.5236 - val_loss: 1.2803
# Epoch 13/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5717 - loss: 1.1829 - val_accuracy: 0.5257 - val_loss: 1.2809
# Epoch 14/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5729 - loss: 1.1818 - val_accuracy: 0.5372 - val_loss: 1.2782
# Epoch 15/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5727 - loss: 1.1819 - val_accuracy: 0.5194 - val_loss: 1.2985
# Epoch 16/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5730 - loss: 1.1795 - val_accuracy: 0.5298 - val_loss: 1.2789
# Epoch 17/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5715 - loss: 1.1778 - val_accuracy: 0.5319 - val_loss: 1.2844
# Epoch 18/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5755 - loss: 1.1779 - val_accuracy: 0.5277 - val_loss: 1.3059
# Epoch 19/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5769 - loss: 1.1756 - val_accuracy: 0.5257 - val_loss: 1.2818
# Epoch 20/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5729 - loss: 1.1783 - val_accuracy: 0.5288 - val_loss: 1.3002
# Epoch 21/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5716 - loss: 1.1796 - val_accuracy: 0.5267 - val_loss: 1.2883
# Epoch 22/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5726 - loss: 1.1772 - val_accuracy: 0.5267 - val_loss: 1.2987
# Epoch 23/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5734 - loss: 1.1736 - val_accuracy: 0.5246 - val_loss: 1.2965
# Epoch 24/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5788 - loss: 1.1710 - val_accuracy: 0.5298 - val_loss: 1.2966
# Epoch 25/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5752 - loss: 1.1707 - val_accuracy: 0.5246 - val_loss: 1.2926
# Epoch 26/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5752 - loss: 1.1711 - val_accuracy: 0.5330 - val_loss: 1.2911
# Epoch 27/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5763 - loss: 1.1702 - val_accuracy: 0.5277 - val_loss: 1.2988
# Epoch 28/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5753 - loss: 1.1701 - val_accuracy: 0.5351 - val_loss: 1.2875
# Epoch 29/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5763 - loss: 1.1689 - val_accuracy: 0.5298 - val_loss: 1.2923
# Epoch 30/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5756 - loss: 1.1690 - val_accuracy: 0.5330 - val_loss: 1.2954
# Epoch 31/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5768 - loss: 1.1669 - val_accuracy: 0.5393 - val_loss: 1.2888
# Epoch 32/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5770 - loss: 1.1606 - val_accuracy: 0.5382 - val_loss: 1.2877
# Epoch 33/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5777 - loss: 1.1628 - val_accuracy: 0.5267 - val_loss: 1.3122
# Epoch 34/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5789 - loss: 1.1647 - val_accuracy: 0.5330 - val_loss: 1.2904
# Epoch 35/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5766 - loss: 1.1654 - val_accuracy: 0.5330 - val_loss: 1.2860
# Epoch 36/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5788 - loss: 1.1609 - val_accuracy: 0.5372 - val_loss: 1.3007
# Epoch 37/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5746 - loss: 1.1643 - val_accuracy: 0.5257 - val_loss: 1.3054
# Epoch 38/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5726 - loss: 1.1639 - val_accuracy: 0.5330 - val_loss: 1.2977
# Epoch 39/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5757 - loss: 1.1608 - val_accuracy: 0.5246 - val_loss: 1.3022
# Epoch 40/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5783 - loss: 1.1591 - val_accuracy: 0.5162 - val_loss: 1.3211
# Epoch 41/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5815 - loss: 1.1509 - val_accuracy: 0.5393 - val_loss: 1.3090
# Epoch 42/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5781 - loss: 1.1545 - val_accuracy: 0.5257 - val_loss: 1.3082
# Epoch 43/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5810 - loss: 1.1556 - val_accuracy: 0.5257 - val_loss: 1.3069
# Epoch 44/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5782 - loss: 1.1592 - val_accuracy: 0.5225 - val_loss: 1.3395
# Epoch 45/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5789 - loss: 1.1545 - val_accuracy: 0.5215 - val_loss: 1.3108
# Epoch 46/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5771 - loss: 1.1550 - val_accuracy: 0.5330 - val_loss: 1.3151
# Epoch 47/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5757 - loss: 1.1556 - val_accuracy: 0.5257 - val_loss: 1.3203
# Epoch 48/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5815 - loss: 1.1561 - val_accuracy: 0.5288 - val_loss: 1.3099
# Epoch 49/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5788 - loss: 1.1525 - val_accuracy: 0.5351 - val_loss: 1.3071
# Epoch 50/50
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5851 - loss: 1.1492 - val_accuracy: 0.5298 - val_loss: 1.3185
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# [Experiment 2/7] Evaluated Performance Excluding Class: 'disgust'
# Epoch 1/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4946 - loss: 1.4250 - val_accuracy: 0.4779 - val_loss: 1.4238
# Epoch 2/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5240 - loss: 1.3355 - val_accuracy: 0.4761 - val_loss: 1.4133
# Epoch 3/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5249 - loss: 1.3176 - val_accuracy: 0.4779 - val_loss: 1.4354
# Epoch 4/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5300 - loss: 1.3131 - val_accuracy: 0.4696 - val_loss: 1.4431
# Epoch 5/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5323 - loss: 1.3095 - val_accuracy: 0.4742 - val_loss: 1.4497
# Epoch 6/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5292 - loss: 1.3094 - val_accuracy: 0.4816 - val_loss: 1.4662
# Epoch 7/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5319 - loss: 1.3104 - val_accuracy: 0.4853 - val_loss: 1.4333
# Epoch 8/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5333 - loss: 1.3052 - val_accuracy: 0.4834 - val_loss: 1.4199
# Epoch 9/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5314 - loss: 1.3039 - val_accuracy: 0.4825 - val_loss: 1.4153
# Epoch 10/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5308 - loss: 1.3063 - val_accuracy: 0.4871 - val_loss: 1.4107
# Epoch 11/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5310 - loss: 1.3007 - val_accuracy: 0.4834 - val_loss: 1.4294
# Epoch 12/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5328 - loss: 1.2986 - val_accuracy: 0.4788 - val_loss: 1.4203
# Epoch 13/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5319 - loss: 1.2954 - val_accuracy: 0.4853 - val_loss: 1.4379
# Epoch 14/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5337 - loss: 1.2956 - val_accuracy: 0.4816 - val_loss: 1.4246
# Epoch 15/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5323 - loss: 1.2943 - val_accuracy: 0.4779 - val_loss: 1.4341
# Epoch 16/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5300 - loss: 1.2949 - val_accuracy: 0.4816 - val_loss: 1.4297
# Epoch 17/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5358 - loss: 1.2930 - val_accuracy: 0.4843 - val_loss: 1.4432
# Epoch 18/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5321 - loss: 1.2909 - val_accuracy: 0.4816 - val_loss: 1.5024
# Epoch 19/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5337 - loss: 1.2890 - val_accuracy: 0.4862 - val_loss: 1.4501
# Epoch 20/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5356 - loss: 1.2877 - val_accuracy: 0.4917 - val_loss: 1.4718
# Epoch 21/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5340 - loss: 1.2882 - val_accuracy: 0.4862 - val_loss: 1.4623
# Epoch 22/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5390 - loss: 1.2852 - val_accuracy: 0.4862 - val_loss: 1.4606
# Epoch 23/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5352 - loss: 1.2828 - val_accuracy: 0.4834 - val_loss: 1.4625
# Epoch 24/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5385 - loss: 1.2848 - val_accuracy: 0.4788 - val_loss: 1.4587
# Epoch 25/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5384 - loss: 1.2814 - val_accuracy: 0.4816 - val_loss: 1.4425
# Epoch 26/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5362 - loss: 1.2795 - val_accuracy: 0.4834 - val_loss: 1.4796
# Epoch 27/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5358 - loss: 1.2801 - val_accuracy: 0.4807 - val_loss: 1.4569
# Epoch 28/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5386 - loss: 1.2790 - val_accuracy: 0.4853 - val_loss: 1.4601
# Epoch 29/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5382 - loss: 1.2766 - val_accuracy: 0.4816 - val_loss: 1.4862
# Epoch 30/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5392 - loss: 1.2763 - val_accuracy: 0.4862 - val_loss: 1.4540
# Epoch 31/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5369 - loss: 1.2746 - val_accuracy: 0.4549 - val_loss: 1.5486
# Epoch 32/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5375 - loss: 1.2741 - val_accuracy: 0.4890 - val_loss: 1.4607
# Epoch 33/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5370 - loss: 1.2701 - val_accuracy: 0.4945 - val_loss: 1.4482
# Epoch 34/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5404 - loss: 1.2721 - val_accuracy: 0.4816 - val_loss: 1.4672
# Epoch 35/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5391 - loss: 1.2737 - val_accuracy: 0.4843 - val_loss: 1.4802
# Epoch 36/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5380 - loss: 1.2726 - val_accuracy: 0.4797 - val_loss: 1.4789
# Epoch 37/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5431 - loss: 1.2710 - val_accuracy: 0.4917 - val_loss: 1.4574
# Epoch 38/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5399 - loss: 1.2691 - val_accuracy: 0.4770 - val_loss: 1.4769
# Epoch 39/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5391 - loss: 1.2720 - val_accuracy: 0.4890 - val_loss: 1.4696
# Epoch 40/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5387 - loss: 1.2716 - val_accuracy: 0.4770 - val_loss: 1.4836
# Epoch 41/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5408 - loss: 1.2652 - val_accuracy: 0.4715 - val_loss: 1.5001
# Epoch 42/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5383 - loss: 1.2671 - val_accuracy: 0.4779 - val_loss: 1.4836
# Epoch 43/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5378 - loss: 1.2666 - val_accuracy: 0.4825 - val_loss: 1.4668
# Epoch 44/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5421 - loss: 1.2643 - val_accuracy: 0.4890 - val_loss: 1.5252
# Epoch 45/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5418 - loss: 1.2625 - val_accuracy: 0.4761 - val_loss: 1.5159
# Epoch 46/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5474 - loss: 1.2557 - val_accuracy: 0.4742 - val_loss: 1.5209
# Epoch 47/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5441 - loss: 1.2618 - val_accuracy: 0.4659 - val_loss: 1.5751
# Epoch 48/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5454 - loss: 1.2591 - val_accuracy: 0.4779 - val_loss: 1.4902
# Epoch 49/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5429 - loss: 1.2596 - val_accuracy: 0.4751 - val_loss: 1.5506
# Epoch 50/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5419 - loss: 1.2629 - val_accuracy: 0.4724 - val_loss: 1.5174
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# [Experiment 3/7] Evaluated Performance Excluding Class: 'fear'
# Epoch 1/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5037 - loss: 1.3949 - val_accuracy: 0.4738 - val_loss: 1.3717
# Epoch 2/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5203 - loss: 1.3230 - val_accuracy: 0.4888 - val_loss: 1.3673
# Epoch 3/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5236 - loss: 1.3137 - val_accuracy: 0.4897 - val_loss: 1.3598
# Epoch 4/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5270 - loss: 1.3070 - val_accuracy: 0.4916 - val_loss: 1.3687
# Epoch 5/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5284 - loss: 1.3012 - val_accuracy: 0.4953 - val_loss: 1.3647
# Epoch 6/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5254 - loss: 1.2964 - val_accuracy: 0.4925 - val_loss: 1.3760
# Epoch 7/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5260 - loss: 1.2929 - val_accuracy: 0.4888 - val_loss: 1.3828
# Epoch 8/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5264 - loss: 1.2955 - val_accuracy: 0.4897 - val_loss: 1.3600
# Epoch 9/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5294 - loss: 1.2913 - val_accuracy: 0.4822 - val_loss: 1.3752
# Epoch 10/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5297 - loss: 1.2899 - val_accuracy: 0.4888 - val_loss: 1.3736
# Epoch 11/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5308 - loss: 1.2882 - val_accuracy: 0.4897 - val_loss: 1.3787
# Epoch 12/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5301 - loss: 1.2859 - val_accuracy: 0.4860 - val_loss: 1.3754
# Epoch 13/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5299 - loss: 1.2875 - val_accuracy: 0.4925 - val_loss: 1.3687
# Epoch 14/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5287 - loss: 1.2883 - val_accuracy: 0.4944 - val_loss: 1.3813
# Epoch 15/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5265 - loss: 1.2883 - val_accuracy: 0.4803 - val_loss: 1.3681
# Epoch 16/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5323 - loss: 1.2863 - val_accuracy: 0.4906 - val_loss: 1.3810
# Epoch 17/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5294 - loss: 1.2839 - val_accuracy: 0.4738 - val_loss: 1.3950
# Epoch 18/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5275 - loss: 1.2874 - val_accuracy: 0.4906 - val_loss: 1.3907
# Epoch 19/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5319 - loss: 1.2882 - val_accuracy: 0.4850 - val_loss: 1.3721
# Epoch 20/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5327 - loss: 1.2848 - val_accuracy: 0.4869 - val_loss: 1.3856
# Epoch 21/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5324 - loss: 1.2855 - val_accuracy: 0.4916 - val_loss: 1.3763
# Epoch 22/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5320 - loss: 1.2823 - val_accuracy: 0.4916 - val_loss: 1.3676
# Epoch 23/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5270 - loss: 1.2889 - val_accuracy: 0.4953 - val_loss: 1.3996
# Epoch 24/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5298 - loss: 1.2900 - val_accuracy: 0.4953 - val_loss: 1.3964
# Epoch 25/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5305 - loss: 1.2938 - val_accuracy: 0.4916 - val_loss: 1.3699
# Epoch 26/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5323 - loss: 1.2869 - val_accuracy: 0.4888 - val_loss: 1.3832
# Epoch 27/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5300 - loss: 1.2844 - val_accuracy: 0.4906 - val_loss: 1.3714
# Epoch 28/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5314 - loss: 1.2829 - val_accuracy: 0.4916 - val_loss: 1.3820
# Epoch 29/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5323 - loss: 1.2813 - val_accuracy: 0.4888 - val_loss: 1.3739
# Epoch 30/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5340 - loss: 1.2835 - val_accuracy: 0.4934 - val_loss: 1.3733
# Epoch 31/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5279 - loss: 1.2824 - val_accuracy: 0.4934 - val_loss: 1.3702
# Epoch 32/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5315 - loss: 1.2781 - val_accuracy: 0.4878 - val_loss: 1.3737
# Epoch 33/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5327 - loss: 1.2789 - val_accuracy: 0.4841 - val_loss: 1.3783
# Epoch 34/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5326 - loss: 1.2773 - val_accuracy: 0.4869 - val_loss: 1.3722
# Epoch 35/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5372 - loss: 1.2778 - val_accuracy: 0.4869 - val_loss: 1.3665
# Epoch 36/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5293 - loss: 1.2796 - val_accuracy: 0.4906 - val_loss: 1.3778
# Epoch 37/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5317 - loss: 1.2782 - val_accuracy: 0.4906 - val_loss: 1.3893
# Epoch 38/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5306 - loss: 1.2786 - val_accuracy: 0.4934 - val_loss: 1.3798
# Epoch 39/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5289 - loss: 1.2784 - val_accuracy: 0.4888 - val_loss: 1.3990
# Epoch 40/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5320 - loss: 1.2775 - val_accuracy: 0.4822 - val_loss: 1.3885
# Epoch 41/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5338 - loss: 1.2785 - val_accuracy: 0.4869 - val_loss: 1.3670
# Epoch 42/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5341 - loss: 1.2775 - val_accuracy: 0.4878 - val_loss: 1.3947
# Epoch 43/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5343 - loss: 1.2767 - val_accuracy: 0.4869 - val_loss: 1.3781
# Epoch 44/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5310 - loss: 1.2746 - val_accuracy: 0.4897 - val_loss: 1.3885
# Epoch 45/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5369 - loss: 1.2747 - val_accuracy: 0.4803 - val_loss: 1.3919
# Epoch 46/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5333 - loss: 1.2744 - val_accuracy: 0.4878 - val_loss: 1.3879
# Epoch 47/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5309 - loss: 1.2732 - val_accuracy: 0.4869 - val_loss: 1.3876
# Epoch 48/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5350 - loss: 1.2722 - val_accuracy: 0.4869 - val_loss: 1.3756
# Epoch 49/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5340 - loss: 1.2767 - val_accuracy: 0.4831 - val_loss: 1.3865
# Epoch 50/50
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5290 - loss: 1.2753 - val_accuracy: 0.4850 - val_loss: 1.4212
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# [Experiment 4/7] Evaluated Performance Excluding Class: 'joy'
# Epoch 1/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5631 - loss: 1.3212 - val_accuracy: 0.5101 - val_loss: 1.3352
# Epoch 2/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5782 - loss: 1.2250 - val_accuracy: 0.5143 - val_loss: 1.3208
# Epoch 3/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5797 - loss: 1.2161 - val_accuracy: 0.5037 - val_loss: 1.3564
# Epoch 4/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5833 - loss: 1.2107 - val_accuracy: 0.5206 - val_loss: 1.3296
# Epoch 5/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5841 - loss: 1.2087 - val_accuracy: 0.5323 - val_loss: 1.3216
# Epoch 6/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5875 - loss: 1.1973 - val_accuracy: 0.5270 - val_loss: 1.3185
# Epoch 7/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5867 - loss: 1.1919 - val_accuracy: 0.5249 - val_loss: 1.3169
# Epoch 8/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5885 - loss: 1.1967 - val_accuracy: 0.5143 - val_loss: 1.3338
# Epoch 9/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5862 - loss: 1.1885 - val_accuracy: 0.5386 - val_loss: 1.3558
# Epoch 10/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5873 - loss: 1.1870 - val_accuracy: 0.5302 - val_loss: 1.3103
# Epoch 11/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5859 - loss: 1.1942 - val_accuracy: 0.5344 - val_loss: 1.3400
# Epoch 12/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5874 - loss: 1.1888 - val_accuracy: 0.5206 - val_loss: 1.3383
# Epoch 13/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5908 - loss: 1.1818 - val_accuracy: 0.5196 - val_loss: 1.3124
# Epoch 14/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5894 - loss: 1.1756 - val_accuracy: 0.5397 - val_loss: 1.3388
# Epoch 15/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5908 - loss: 1.1759 - val_accuracy: 0.5175 - val_loss: 1.3167
# Epoch 16/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5903 - loss: 1.1764 - val_accuracy: 0.5228 - val_loss: 1.3234
# Epoch 17/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5888 - loss: 1.1846 - val_accuracy: 0.5259 - val_loss: 1.3308
# Epoch 18/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5882 - loss: 1.1769 - val_accuracy: 0.5238 - val_loss: 1.3194
# Epoch 19/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5881 - loss: 1.1870 - val_accuracy: 0.5249 - val_loss: 1.3046
# Epoch 20/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5903 - loss: 1.1767 - val_accuracy: 0.5418 - val_loss: 1.3133
# Epoch 21/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5899 - loss: 1.1758 - val_accuracy: 0.5354 - val_loss: 1.3220
# Epoch 22/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5899 - loss: 1.1768 - val_accuracy: 0.5365 - val_loss: 1.3252
# Epoch 23/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5943 - loss: 1.1675 - val_accuracy: 0.5323 - val_loss: 1.3058
# Epoch 24/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5919 - loss: 1.1679 - val_accuracy: 0.5249 - val_loss: 1.3239
# Epoch 25/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5937 - loss: 1.1680 - val_accuracy: 0.5280 - val_loss: 1.3122
# Epoch 26/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5947 - loss: 1.1584 - val_accuracy: 0.5302 - val_loss: 1.3521
# Epoch 27/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5950 - loss: 1.1661 - val_accuracy: 0.5333 - val_loss: 1.3232
# Epoch 28/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5989 - loss: 1.1577 - val_accuracy: 0.5312 - val_loss: 1.3680
# Epoch 29/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5960 - loss: 1.1594 - val_accuracy: 0.5397 - val_loss: 1.3077
# Epoch 30/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5959 - loss: 1.1565 - val_accuracy: 0.5365 - val_loss: 1.3449
# Epoch 31/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5965 - loss: 1.1551 - val_accuracy: 0.5365 - val_loss: 1.3214
# Epoch 32/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5993 - loss: 1.1493 - val_accuracy: 0.5217 - val_loss: 1.3287
# Epoch 33/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5985 - loss: 1.1573 - val_accuracy: 0.5397 - val_loss: 1.3288
# Epoch 34/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5954 - loss: 1.1540 - val_accuracy: 0.5175 - val_loss: 1.3671
# Epoch 35/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5979 - loss: 1.1514 - val_accuracy: 0.5291 - val_loss: 1.3614
# Epoch 36/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5993 - loss: 1.1464 - val_accuracy: 0.5302 - val_loss: 1.3610
# Epoch 37/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5970 - loss: 1.1496 - val_accuracy: 0.5365 - val_loss: 1.3677
# Epoch 38/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5979 - loss: 1.1485 - val_accuracy: 0.5206 - val_loss: 1.3333
# Epoch 39/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5930 - loss: 1.1531 - val_accuracy: 0.5238 - val_loss: 1.3568
# Epoch 40/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5979 - loss: 1.1471 - val_accuracy: 0.5354 - val_loss: 1.3787
# Epoch 41/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5992 - loss: 1.1444 - val_accuracy: 0.5249 - val_loss: 1.3473
# Epoch 42/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6012 - loss: 1.1377 - val_accuracy: 0.5249 - val_loss: 1.3845
# Epoch 43/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6021 - loss: 1.1382 - val_accuracy: 0.5312 - val_loss: 1.3610
# Epoch 44/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6008 - loss: 1.1411 - val_accuracy: 0.5153 - val_loss: 1.3969
# Epoch 45/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6070 - loss: 1.1284 - val_accuracy: 0.5270 - val_loss: 1.3890
# Epoch 46/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6069 - loss: 1.1248 - val_accuracy: 0.5312 - val_loss: 1.3557
# Epoch 47/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6080 - loss: 1.1234 - val_accuracy: 0.5302 - val_loss: 1.3909
# Epoch 48/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6046 - loss: 1.1309 - val_accuracy: 0.5259 - val_loss: 1.3581
# Epoch 49/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6049 - loss: 1.1252 - val_accuracy: 0.5175 - val_loss: 1.4501
# Epoch 50/50
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6092 - loss: 1.1194 - val_accuracy: 0.5386 - val_loss: 1.3532
#
# [Experiment 5/7] Evaluated Performance Excluding Class: 'neutral'
# Epoch 1/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3662 - loss: 1.5923 - val_accuracy: 0.3693 - val_loss: 1.5636
# Epoch 2/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4256 - loss: 1.4821 - val_accuracy: 0.3912 - val_loss: 1.5382
# Epoch 3/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4313 - loss: 1.4691 - val_accuracy: 0.4100 - val_loss: 1.5380
# Epoch 4/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4361 - loss: 1.4547 - val_accuracy: 0.3897 - val_loss: 1.5671
# Epoch 5/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4408 - loss: 1.4498 - val_accuracy: 0.3991 - val_loss: 1.5358
# Epoch 6/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4440 - loss: 1.4446 - val_accuracy: 0.3928 - val_loss: 1.5626
# Epoch 7/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4438 - loss: 1.4407 - val_accuracy: 0.3803 - val_loss: 1.5574
# Epoch 8/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4438 - loss: 1.4366 - val_accuracy: 0.3991 - val_loss: 1.5733
# Epoch 9/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4457 - loss: 1.4326 - val_accuracy: 0.4006 - val_loss: 1.5500
# Epoch 10/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4505 - loss: 1.4297 - val_accuracy: 0.3944 - val_loss: 1.5628
# Epoch 11/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4455 - loss: 1.4314 - val_accuracy: 0.4006 - val_loss: 1.5377
# Epoch 12/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4416 - loss: 1.4332 - val_accuracy: 0.4147 - val_loss: 1.5309
# Epoch 13/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4453 - loss: 1.4292 - val_accuracy: 0.4116 - val_loss: 1.5431
# Epoch 14/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4471 - loss: 1.4271 - val_accuracy: 0.3850 - val_loss: 1.5649
# Epoch 15/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4522 - loss: 1.4234 - val_accuracy: 0.3912 - val_loss: 1.5454
# Epoch 16/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4446 - loss: 1.4233 - val_accuracy: 0.3897 - val_loss: 1.5569
# Epoch 17/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4478 - loss: 1.4200 - val_accuracy: 0.4022 - val_loss: 1.5676
# Epoch 18/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4507 - loss: 1.4156 - val_accuracy: 0.3881 - val_loss: 1.5984
# Epoch 19/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4510 - loss: 1.4171 - val_accuracy: 0.3912 - val_loss: 1.5886
# Epoch 20/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4476 - loss: 1.4162 - val_accuracy: 0.3834 - val_loss: 1.5822
# Epoch 21/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4501 - loss: 1.4169 - val_accuracy: 0.3756 - val_loss: 1.5797
# Epoch 22/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4495 - loss: 1.4163 - val_accuracy: 0.3928 - val_loss: 1.5580
# Epoch 23/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4518 - loss: 1.4106 - val_accuracy: 0.3881 - val_loss: 1.5453
# Epoch 24/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4529 - loss: 1.4118 - val_accuracy: 0.3818 - val_loss: 1.5861
# Epoch 25/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4507 - loss: 1.4078 - val_accuracy: 0.3991 - val_loss: 1.5671
# Epoch 26/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4569 - loss: 1.4049 - val_accuracy: 0.3912 - val_loss: 1.5809
# Epoch 27/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4539 - loss: 1.4067 - val_accuracy: 0.4038 - val_loss: 1.5529
# Epoch 28/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4529 - loss: 1.4016 - val_accuracy: 0.3881 - val_loss: 1.5744
# Epoch 29/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4550 - loss: 1.4042 - val_accuracy: 0.3897 - val_loss: 1.6256
# Epoch 30/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4563 - loss: 1.4001 - val_accuracy: 0.3959 - val_loss: 1.5657
# Epoch 31/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4539 - loss: 1.3984 - val_accuracy: 0.3959 - val_loss: 1.5649
# Epoch 32/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4596 - loss: 1.3947 - val_accuracy: 0.3678 - val_loss: 1.6160
# Epoch 33/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4601 - loss: 1.3952 - val_accuracy: 0.3834 - val_loss: 1.6085
# Epoch 34/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4580 - loss: 1.3923 - val_accuracy: 0.3912 - val_loss: 1.5777
# Epoch 35/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4611 - loss: 1.3890 - val_accuracy: 0.3959 - val_loss: 1.5972
# Epoch 36/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4624 - loss: 1.3867 - val_accuracy: 0.3897 - val_loss: 1.6072
# Epoch 37/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4609 - loss: 1.3852 - val_accuracy: 0.3897 - val_loss: 1.5662
# Epoch 38/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4616 - loss: 1.3828 - val_accuracy: 0.3881 - val_loss: 1.5842
# Epoch 39/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4620 - loss: 1.3847 - val_accuracy: 0.3944 - val_loss: 1.6198
# Epoch 40/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4584 - loss: 1.3812 - val_accuracy: 0.3928 - val_loss: 1.5895
# Epoch 41/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4666 - loss: 1.3825 - val_accuracy: 0.3865 - val_loss: 1.6216
# Epoch 42/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4666 - loss: 1.3828 - val_accuracy: 0.3975 - val_loss: 1.6388
# Epoch 43/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4677 - loss: 1.3788 - val_accuracy: 0.3881 - val_loss: 1.6436
# Epoch 44/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4696 - loss: 1.3763 - val_accuracy: 0.3772 - val_loss: 1.6382
# Epoch 45/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4671 - loss: 1.3732 - val_accuracy: 0.3944 - val_loss: 1.5780
# Epoch 46/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4753 - loss: 1.3622 - val_accuracy: 0.3865 - val_loss: 1.6489
# Epoch 47/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4696 - loss: 1.3711 - val_accuracy: 0.3772 - val_loss: 1.7158
# Epoch 48/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4658 - loss: 1.3664 - val_accuracy: 0.3975 - val_loss: 1.6830
# Epoch 49/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4628 - loss: 1.3774 - val_accuracy: 0.3834 - val_loss: 1.6266
# Epoch 50/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4679 - loss: 1.3705 - val_accuracy: 0.3818 - val_loss: 1.7461
#
# [Experiment 6/7] Evaluated Performance Excluding Class: 'sadness'
# Epoch 1/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5160 - loss: 1.3399 - val_accuracy: 0.5206 - val_loss: 1.3066
# Epoch 2/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5459 - loss: 1.2640 - val_accuracy: 0.5226 - val_loss: 1.3017
# Epoch 3/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5487 - loss: 1.2533 - val_accuracy: 0.5246 - val_loss: 1.2852
# Epoch 4/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5522 - loss: 1.2449 - val_accuracy: 0.5276 - val_loss: 1.2906
# Epoch 5/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5536 - loss: 1.2401 - val_accuracy: 0.5276 - val_loss: 1.2799
# Epoch 6/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5546 - loss: 1.2371 - val_accuracy: 0.5286 - val_loss: 1.2837
# Epoch 7/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5534 - loss: 1.2363 - val_accuracy: 0.5266 - val_loss: 1.2859
# Epoch 8/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5541 - loss: 1.2322 - val_accuracy: 0.5336 - val_loss: 1.2682
# Epoch 9/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5572 - loss: 1.2285 - val_accuracy: 0.5296 - val_loss: 1.2770
# Epoch 10/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5580 - loss: 1.2294 - val_accuracy: 0.5286 - val_loss: 1.2676
# Epoch 11/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5569 - loss: 1.2259 - val_accuracy: 0.5396 - val_loss: 1.2693
# Epoch 12/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5587 - loss: 1.2264 - val_accuracy: 0.5236 - val_loss: 1.2772
# Epoch 13/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5558 - loss: 1.2279 - val_accuracy: 0.5286 - val_loss: 1.2721
# Epoch 14/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5588 - loss: 1.2270 - val_accuracy: 0.5286 - val_loss: 1.2691
# Epoch 15/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5550 - loss: 1.2183 - val_accuracy: 0.5336 - val_loss: 1.2662
# Epoch 16/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5538 - loss: 1.2270 - val_accuracy: 0.5356 - val_loss: 1.2706
# Epoch 17/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5549 - loss: 1.2205 - val_accuracy: 0.5216 - val_loss: 1.2931
# Epoch 18/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5583 - loss: 1.2203 - val_accuracy: 0.5406 - val_loss: 1.2818
# Epoch 19/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5596 - loss: 1.2147 - val_accuracy: 0.5306 - val_loss: 1.2685
# Epoch 20/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5586 - loss: 1.2160 - val_accuracy: 0.5366 - val_loss: 1.2531
# Epoch 21/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5584 - loss: 1.2141 - val_accuracy: 0.5326 - val_loss: 1.2754
# Epoch 22/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5631 - loss: 1.2114 - val_accuracy: 0.5456 - val_loss: 1.2652
# Epoch 23/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5624 - loss: 1.2101 - val_accuracy: 0.5436 - val_loss: 1.2634
# Epoch 24/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5636 - loss: 1.2064 - val_accuracy: 0.5476 - val_loss: 1.2473
# Epoch 25/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5670 - loss: 1.2039 - val_accuracy: 0.5366 - val_loss: 1.2591
# Epoch 26/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5626 - loss: 1.2065 - val_accuracy: 0.5316 - val_loss: 1.2752
# Epoch 27/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5624 - loss: 1.2020 - val_accuracy: 0.5326 - val_loss: 1.2693
# Epoch 28/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5640 - loss: 1.2008 - val_accuracy: 0.5376 - val_loss: 1.2480
# Epoch 29/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5661 - loss: 1.2018 - val_accuracy: 0.5396 - val_loss: 1.2630
# Epoch 30/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5654 - loss: 1.1981 - val_accuracy: 0.5476 - val_loss: 1.2576
# Epoch 31/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5632 - loss: 1.1959 - val_accuracy: 0.5416 - val_loss: 1.2574
# Epoch 32/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5642 - loss: 1.1967 - val_accuracy: 0.5386 - val_loss: 1.2500
# Epoch 33/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5649 - loss: 1.1986 - val_accuracy: 0.5346 - val_loss: 1.2594
# Epoch 34/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5690 - loss: 1.1930 - val_accuracy: 0.5386 - val_loss: 1.2478
# Epoch 35/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5661 - loss: 1.1908 - val_accuracy: 0.5396 - val_loss: 1.2519
# Epoch 36/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5677 - loss: 1.1901 - val_accuracy: 0.5296 - val_loss: 1.2602
# Epoch 37/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5674 - loss: 1.2016 - val_accuracy: 0.5256 - val_loss: 1.2557
# Epoch 38/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5649 - loss: 1.1941 - val_accuracy: 0.5486 - val_loss: 1.2426
# Epoch 39/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5699 - loss: 1.1843 - val_accuracy: 0.5356 - val_loss: 1.2452
# Epoch 40/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5682 - loss: 1.1850 - val_accuracy: 0.5346 - val_loss: 1.2604
# Epoch 41/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5698 - loss: 1.1763 - val_accuracy: 0.5366 - val_loss: 1.2505
# Epoch 42/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5694 - loss: 1.1741 - val_accuracy: 0.5346 - val_loss: 1.2571
# Epoch 43/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5766 - loss: 1.1719 - val_accuracy: 0.5276 - val_loss: 1.2723
# Epoch 44/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5731 - loss: 1.1674 - val_accuracy: 0.5356 - val_loss: 1.2727
# Epoch 45/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5766 - loss: 1.1660 - val_accuracy: 0.5356 - val_loss: 1.2764
# Epoch 46/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5767 - loss: 1.1644 - val_accuracy: 0.5406 - val_loss: 1.2650
# Epoch 47/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5765 - loss: 1.1628 - val_accuracy: 0.5436 - val_loss: 1.2500
# Epoch 48/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5818 - loss: 1.1575 - val_accuracy: 0.5406 - val_loss: 1.2827
# Epoch 49/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5785 - loss: 1.1531 - val_accuracy: 0.5416 - val_loss: 1.2847
# Epoch 50/50
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5783 - loss: 1.1516 - val_accuracy: 0.5316 - val_loss: 1.2714
#
# [Experiment 7/7] Evaluated Performance Excluding Class: 'surprise'
# Epoch 1/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5538 - loss: 1.2660 - val_accuracy: 0.5261 - val_loss: 1.3262
# Epoch 2/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5792 - loss: 1.1830 - val_accuracy: 0.5386 - val_loss: 1.2806
# Epoch 3/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5832 - loss: 1.1738 - val_accuracy: 0.5418 - val_loss: 1.2683
# Epoch 4/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5832 - loss: 1.1694 - val_accuracy: 0.5438 - val_loss: 1.2546
# Epoch 5/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5833 - loss: 1.1654 - val_accuracy: 0.5428 - val_loss: 1.2687
# Epoch 6/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5872 - loss: 1.1668 - val_accuracy: 0.5251 - val_loss: 1.2934
# Epoch 7/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5845 - loss: 1.1662 - val_accuracy: 0.5428 - val_loss: 1.2868
# Epoch 8/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5840 - loss: 1.1635 - val_accuracy: 0.5459 - val_loss: 1.2910
# Epoch 9/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5857 - loss: 1.1628 - val_accuracy: 0.5459 - val_loss: 1.2870
# Epoch 10/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5862 - loss: 1.1607 - val_accuracy: 0.5407 - val_loss: 1.2760
# Epoch 11/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5888 - loss: 1.1607 - val_accuracy: 0.5449 - val_loss: 1.2829
# Epoch 12/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5940 - loss: 1.1575 - val_accuracy: 0.5480 - val_loss: 1.2873
# Epoch 13/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5891 - loss: 1.1570 - val_accuracy: 0.5459 - val_loss: 1.2594
# Epoch 14/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5875 - loss: 1.1557 - val_accuracy: 0.5449 - val_loss: 1.2476
# Epoch 15/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5894 - loss: 1.1516 - val_accuracy: 0.5459 - val_loss: 1.2562
# Epoch 16/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5893 - loss: 1.1540 - val_accuracy: 0.5470 - val_loss: 1.2600
# Epoch 17/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5911 - loss: 1.1480 - val_accuracy: 0.5438 - val_loss: 1.2721
# Epoch 18/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5910 - loss: 1.1489 - val_accuracy: 0.5459 - val_loss: 1.2625
# Epoch 19/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5907 - loss: 1.1461 - val_accuracy: 0.5449 - val_loss: 1.2628
# Epoch 20/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5916 - loss: 1.1520 - val_accuracy: 0.5407 - val_loss: 1.2612
# Epoch 21/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5893 - loss: 1.1527 - val_accuracy: 0.5428 - val_loss: 1.2803
# Epoch 22/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5933 - loss: 1.1507 - val_accuracy: 0.5397 - val_loss: 1.2642
# Epoch 23/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5885 - loss: 1.1468 - val_accuracy: 0.5470 - val_loss: 1.2476
# Epoch 24/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5936 - loss: 1.1423 - val_accuracy: 0.5522 - val_loss: 1.2614
# Epoch 25/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5926 - loss: 1.1424 - val_accuracy: 0.5449 - val_loss: 1.2560
# Epoch 26/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5898 - loss: 1.1426 - val_accuracy: 0.5491 - val_loss: 1.2712
# Epoch 27/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5932 - loss: 1.1364 - val_accuracy: 0.5501 - val_loss: 1.2603
# Epoch 28/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5915 - loss: 1.1413 - val_accuracy: 0.5470 - val_loss: 1.2504
# Epoch 29/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5957 - loss: 1.1347 - val_accuracy: 0.5438 - val_loss: 1.2990
# Epoch 30/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5956 - loss: 1.1329 - val_accuracy: 0.5491 - val_loss: 1.2613
# Epoch 31/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5927 - loss: 1.1364 - val_accuracy: 0.5543 - val_loss: 1.2532
# Epoch 32/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5928 - loss: 1.1366 - val_accuracy: 0.5501 - val_loss: 1.2664
# Epoch 33/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5914 - loss: 1.1353 - val_accuracy: 0.5428 - val_loss: 1.2937
# Epoch 34/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5957 - loss: 1.1387 - val_accuracy: 0.5459 - val_loss: 1.2486
# Epoch 35/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5927 - loss: 1.1401 - val_accuracy: 0.5470 - val_loss: 1.2691
# Epoch 36/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5908 - loss: 1.1350 - val_accuracy: 0.5470 - val_loss: 1.2694
# Epoch 37/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5935 - loss: 1.1362 - val_accuracy: 0.5511 - val_loss: 1.2634
# Epoch 38/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5948 - loss: 1.1330 - val_accuracy: 0.5438 - val_loss: 1.2755
# Epoch 39/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5931 - loss: 1.1343 - val_accuracy: 0.5459 - val_loss: 1.2953
# Epoch 40/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5973 - loss: 1.1251 - val_accuracy: 0.5459 - val_loss: 1.2868
# Epoch 41/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5976 - loss: 1.1251 - val_accuracy: 0.5480 - val_loss: 1.2836
# Epoch 42/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5968 - loss: 1.1231 - val_accuracy: 0.5376 - val_loss: 1.2978
# Epoch 43/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5948 - loss: 1.1292 - val_accuracy: 0.5407 - val_loss: 1.2446
# Epoch 44/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5991 - loss: 1.1280 - val_accuracy: 0.5491 - val_loss: 1.2584
# Epoch 45/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5962 - loss: 1.1237 - val_accuracy: 0.5365 - val_loss: 1.2482
# Epoch 46/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5949 - loss: 1.1281 - val_accuracy: 0.5428 - val_loss: 1.2680
# Epoch 47/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5950 - loss: 1.1297 - val_accuracy: 0.5428 - val_loss: 1.2694
# Epoch 48/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5943 - loss: 1.1242 - val_accuracy: 0.5470 - val_loss: 1.2801
# Epoch 49/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5980 - loss: 1.1221 - val_accuracy: 0.5449 - val_loss: 1.2700
# Epoch 50/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5968 - loss: 1.1154 - val_accuracy: 0.5459 - val_loss: 1.2595
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\Downloads\[YTS]Github\FYP\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ============================== CLASS ABLATION COMPARISON REPORT ==============================
# <style type="text/css">
# #T_801b0_row3_col4, #T_801b0_row7_col1 {
#   background-color: darkred;
# }
# </style>
# <table id="T_801b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_801b0_level0_col0" class="col_heading level0 col0" >Dropped Class</th>
#       <th id="T_801b0_level0_col1" class="col_heading level0 col1" >Test Accuracy</th>
#       <th id="T_801b0_level0_col2" class="col_heading level0 col2" >Macro Precision</th>
#       <th id="T_801b0_level0_col3" class="col_heading level0 col3" >Macro Recall</th>
#       <th id="T_801b0_level0_col4" class="col_heading level0 col4" >Macro F1-Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_801b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_801b0_row0_col0" class="data row0 col0" >None (Baseline)</td>
#       <td id="T_801b0_row0_col1" class="data row0 col1" >0.5123</td>
#       <td id="T_801b0_row0_col2" class="data row0 col2" >0.2107</td>
#       <td id="T_801b0_row0_col3" class="data row0 col3" >0.2307</td>
#       <td id="T_801b0_row0_col4" class="data row0 col4" >0.1979</td>
#     </tr>
#     <tr>
#       <th id="T_801b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_801b0_row1_col0" class="data row1 col0" >Excluding anger</td>
#       <td id="T_801b0_row1_col1" class="data row1 col1" >0.5841</td>
#       <td id="T_801b0_row1_col2" class="data row1 col2" >0.2806</td>
#       <td id="T_801b0_row1_col3" class="data row1 col3" >0.2724</td>
#       <td id="T_801b0_row1_col4" class="data row1 col4" >0.2629</td>
#     </tr>
#     <tr>
#       <th id="T_801b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_801b0_row2_col0" class="data row2 col0" >Excluding disgust</td>
#       <td id="T_801b0_row2_col1" class="data row2 col1" >0.5114</td>
#       <td id="T_801b0_row2_col2" class="data row2 col2" >0.2972</td>
#       <td id="T_801b0_row2_col3" class="data row2 col3" >0.2964</td>
#       <td id="T_801b0_row2_col4" class="data row2 col4" >0.2808</td>
#     </tr>
#     <tr>
#       <th id="T_801b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_801b0_row3_col0" class="data row3 col0" >Excluding fear</td>
#       <td id="T_801b0_row3_col1" class="data row3 col1" >0.5023</td>
#       <td id="T_801b0_row3_col2" class="data row3 col2" >0.2942</td>
#       <td id="T_801b0_row3_col3" class="data row3 col3" >0.3019</td>
#       <td id="T_801b0_row3_col4" class="data row3 col4" >0.2876</td>
#     </tr>
#     <tr>
#       <th id="T_801b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_801b0_row4_col0" class="data row4 col0" >Excluding joy</td>
#       <td id="T_801b0_row4_col1" class="data row4 col1" >0.5765</td>
#       <td id="T_801b0_row4_col2" class="data row4 col2" >0.3041</td>
#       <td id="T_801b0_row4_col3" class="data row4 col3" >0.2166</td>
#       <td id="T_801b0_row4_col4" class="data row4 col4" >0.2089</td>
#     </tr>
#     <tr>
#       <th id="T_801b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_801b0_row5_col0" class="data row5 col0" >Excluding neutral</td>
#       <td id="T_801b0_row5_col1" class="data row5 col1" >0.4269</td>
#       <td id="T_801b0_row5_col2" class="data row5 col2" >0.2837</td>
#       <td id="T_801b0_row5_col3" class="data row5 col3" >0.2825</td>
#       <td id="T_801b0_row5_col4" class="data row5 col4" >0.2610</td>
#     </tr>
#     <tr>
#       <th id="T_801b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_801b0_row6_col0" class="data row6 col0" >Excluding sadness</td>
#       <td id="T_801b0_row6_col1" class="data row6 col1" >0.5629</td>
#       <td id="T_801b0_row6_col2" class="data row6 col2" >0.3721</td>
#       <td id="T_801b0_row6_col3" class="data row6 col3" >0.2859</td>
#       <td id="T_801b0_row6_col4" class="data row6 col4" >0.2743</td>
#     </tr>
#     <tr>
#       <th id="T_801b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_801b0_row7_col0" class="data row7 col0" >Excluding surprise</td>
#       <td id="T_801b0_row7_col1" class="data row7 col1" >0.5874</td>
#       <td id="T_801b0_row7_col2" class="data row7 col2" >0.2769</td>
#       <td id="T_801b0_row7_col3" class="data row7 col3" >0.2832</td>
#       <td id="T_801b0_row7_col4" class="data row7 col4" >0.2614</td>
#     </tr>
#   </tbody>
# </table>
# ============================== PER-CLASS RECALL/F1 MATRIX (Class Ablation) ==============================
# <style type="text/css">
# </style>
# <table id="T_1c020">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c020_level0_col0" class="col_heading level0 col0" >anger</th>
#       <th id="T_1c020_level0_col1" class="col_heading level0 col1" >disgust</th>
#       <th id="T_1c020_level0_col2" class="col_heading level0 col2" >fear</th>
#       <th id="T_1c020_level0_col3" class="col_heading level0 col3" >joy</th>
#       <th id="T_1c020_level0_col4" class="col_heading level0 col4" >neutral</th>
#       <th id="T_1c020_level0_col5" class="col_heading level0 col5" >sadness</th>
#       <th id="T_1c020_level0_col6" class="col_heading level0 col6" >surprise</th>
#       <th id="T_1c020_level0_col7" class="col_heading level0 col7" >anger (F1)</th>
#       <th id="T_1c020_level0_col8" class="col_heading level0 col8" >disgust (F1)</th>
#       <th id="T_1c020_level0_col9" class="col_heading level0 col9" >fear (F1)</th>
#       <th id="T_1c020_level0_col10" class="col_heading level0 col10" >joy (F1)</th>
#       <th id="T_1c020_level0_col11" class="col_heading level0 col11" >neutral (F1)</th>
#       <th id="T_1c020_level0_col12" class="col_heading level0 col12" >sadness (F1)</th>
#       <th id="T_1c020_level0_col13" class="col_heading level0 col13" >surprise (F1)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dropped Class</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c020_level0_row0" class="row_heading level0 row0" >None (Baseline)</th>
#       <td id="T_1c020_row0_col0" class="data row0 col0" >0.0725</td>
#       <td id="T_1c020_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_1c020_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_1c020_row0_col3" class="data row0 col3" >0.6891</td>
#       <td id="T_1c020_row0_col4" class="data row0 col4" >0.8177</td>
#       <td id="T_1c020_row0_col5" class="data row0 col5" >0.0288</td>
#       <td id="T_1c020_row0_col6" class="data row0 col6" >0.0071</td>
#       <td id="T_1c020_row0_col7" class="data row0 col7" >0.1174</td>
#       <td id="T_1c020_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_1c020_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_1c020_row0_col10" class="data row0 col10" >0.5394</td>
#       <td id="T_1c020_row0_col11" class="data row0 col11" >0.6712</td>
#       <td id="T_1c020_row0_col12" class="data row0 col12" >0.0444</td>
#       <td id="T_1c020_row0_col13" class="data row0 col13" >0.0127</td>
#     </tr>
#     <tr>
#       <th id="T_1c020_level0_row1" class="row_heading level0 row1" >Excluding anger</th>
#       <td id="T_1c020_row1_col0" class="data row1 col0" >—</td>
#       <td id="T_1c020_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_1c020_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_1c020_row1_col3" class="data row1 col3" >0.5473</td>
#       <td id="T_1c020_row1_col4" class="data row1 col4" >0.8320</td>
#       <td id="T_1c020_row1_col5" class="data row1 col5" >0.1875</td>
#       <td id="T_1c020_row1_col6" class="data row1 col6" >0.0676</td>
#       <td id="T_1c020_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_1c020_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_1c020_row1_col9" class="data row1 col9" >0.0000</td>
#       <td id="T_1c020_row1_col10" class="data row1 col10" >0.5263</td>
#       <td id="T_1c020_row1_col11" class="data row1 col11" >0.7313</td>
#       <td id="T_1c020_row1_col12" class="data row1 col12" >0.2108</td>
#       <td id="T_1c020_row1_col13" class="data row1 col13" >0.1092</td>
#     </tr>
#     <tr>
#       <th id="T_1c020_level0_row2" class="row_heading level0 row2" >Excluding disgust</th>
#       <td id="T_1c020_row2_col0" class="data row2 col0" >0.2464</td>
#       <td id="T_1c020_row2_col1" class="data row2 col1" >—</td>
#       <td id="T_1c020_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_1c020_row2_col3" class="data row2 col3" >0.6592</td>
#       <td id="T_1c020_row2_col4" class="data row2 col4" >0.7285</td>
#       <td id="T_1c020_row2_col5" class="data row2 col5" >0.0769</td>
#       <td id="T_1c020_row2_col6" class="data row2 col6" >0.0676</td>
#       <td id="T_1c020_row2_col7" class="data row2 col7" >0.2686</td>
#       <td id="T_1c020_row2_col8" class="data row2 col8" >—</td>
#       <td id="T_1c020_row2_col9" class="data row2 col9" >0.0000</td>
#       <td id="T_1c020_row2_col10" class="data row2 col10" >0.5327</td>
#       <td id="T_1c020_row2_col11" class="data row2 col11" >0.6728</td>
#       <td id="T_1c020_row2_col12" class="data row2 col12" >0.1208</td>
#       <td id="T_1c020_row2_col13" class="data row2 col13" >0.0903</td>
#     </tr>
#     <tr>
#       <th id="T_1c020_level0_row3" class="row_heading level0 row3" >Excluding fear</th>
#       <td id="T_1c020_row3_col0" class="data row3 col0" >0.3246</td>
#       <td id="T_1c020_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_1c020_row3_col2" class="data row3 col2" >—</td>
#       <td id="T_1c020_row3_col3" class="data row3 col3" >0.5821</td>
#       <td id="T_1c020_row3_col4" class="data row3 col4" >0.7062</td>
#       <td id="T_1c020_row3_col5" class="data row3 col5" >0.0385</td>
#       <td id="T_1c020_row3_col6" class="data row3 col6" >0.1601</td>
#       <td id="T_1c020_row3_col7" class="data row3 col7" >0.2983</td>
#       <td id="T_1c020_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_1c020_row3_col9" class="data row3 col9" >—</td>
#       <td id="T_1c020_row3_col10" class="data row3 col10" >0.5154</td>
#       <td id="T_1c020_row3_col11" class="data row3 col11" >0.6813</td>
#       <td id="T_1c020_row3_col12" class="data row3 col12" >0.0643</td>
#       <td id="T_1c020_row3_col13" class="data row3 col13" >0.1667</td>
#     </tr>
#     <tr>
#       <th id="T_1c020_level0_row4" class="row_heading level0 row4" >Excluding joy</th>
#       <td id="T_1c020_row4_col0" class="data row4 col0" >0.2435</td>
#       <td id="T_1c020_row4_col1" class="data row4 col1" >0.0147</td>
#       <td id="T_1c020_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_1c020_row4_col3" class="data row4 col3" >—</td>
#       <td id="T_1c020_row4_col4" class="data row4 col4" >0.9220</td>
#       <td id="T_1c020_row4_col5" class="data row4 col5" >0.0481</td>
#       <td id="T_1c020_row4_col6" class="data row4 col6" >0.0712</td>
#       <td id="T_1c020_row4_col7" class="data row4 col7" >0.2843</td>
#       <td id="T_1c020_row4_col8" class="data row4 col8" >0.0282</td>
#       <td id="T_1c020_row4_col9" class="data row4 col9" >0.0000</td>
#       <td id="T_1c020_row4_col10" class="data row4 col10" >—</td>
#       <td id="T_1c020_row4_col11" class="data row4 col11" >0.7469</td>
#       <td id="T_1c020_row4_col12" class="data row4 col12" >0.0797</td>
#       <td id="T_1c020_row4_col13" class="data row4 col13" >0.1143</td>
#     </tr>
#     <tr>
#       <th id="T_1c020_level0_row5" class="row_heading level0 row5" >Excluding neutral</th>
#       <td id="T_1c020_row5_col0" class="data row5 col0" >0.3072</td>
#       <td id="T_1c020_row5_col1" class="data row5 col1" >0.0147</td>
#       <td id="T_1c020_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_1c020_row5_col3" class="data row5 col3" >0.7761</td>
#       <td id="T_1c020_row5_col4" class="data row5 col4" >—</td>
#       <td id="T_1c020_row5_col5" class="data row5 col5" >0.1202</td>
#       <td id="T_1c020_row5_col6" class="data row5 col6" >0.4769</td>
#       <td id="T_1c020_row5_col7" class="data row5 col7" >0.3419</td>
#       <t

# %% [markdown]
# ## BAN Model (Training & Testing)

# %%
# TRAIN
ban_model = build_ban(num_classes, X_train_stats.shape[1], X_train_txt.shape[1])

print(f"Training BAN for exactly {Config.EPOCHS} epochs...")
history_ban = ban_model.fit(
    [X_train_mfcc, X_train_stats, X_train_txt], y_train,  
    validation_data=([X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev),
    epochs=Config.EPOCHS,
    batch_size=Config.BATCH_SIZE,
    verbose=1
)

# %%
# ==========================================
# 5. EVALUATE
# ==========================================
plot_training_history(history_ban, "Bimodal Attention Network (BAN)")
evaluate_model_performance(ban_model, [X_test_mfcc, X_test_stats, X_test_txt], y_test, "Bimodal Attention Network (BAN)")

# %%
evaluate_model_performance(ban_model, [X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev, "Bimodal Attention Network (BAN)")

# %% [markdown]
# ### 1. Baseline

# %%
print("Starting BAN Component Ablation Study...")
ban_component_results = []

# =========================================================================
# EXPERIMENT 1: BASELINE BAN (GATED ATTENTION)
# =========================================================================
print("\n[Experiment 1] Training Baseline BAN...")
tf.keras.backend.clear_session()
gc.collect()

# Build Baseline Model
base_model = build_ban(num_classes=len(Config.DEFAULT_CLASSES), 
                       stats_dim=X_train_stats.shape[1], 
                       sent_dim=X_train_txt.shape[1])

# Train Baseline
base_model.fit(
    [X_train_mfcc, X_train_stats, X_train_txt], y_train,
    validation_data=([X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev),
    epochs=Config.EPOCHS, 
    batch_size=Config.BATCH_SIZE, 
    verbose=0
)

# Predict & Evaluate
y_pred_base = np.argmax(base_model.predict([X_test_mfcc, X_test_stats, X_test_txt], verbose=0), axis=1)

print("\n--- Classification Report (Baseline BAN) ---")
print(classification_report(y_test, y_pred_base, target_names=Config.DEFAULT_CLASSES, digits=4))

rep_base = classification_report(y_test, y_pred_base, target_names=Config.DEFAULT_CLASSES, digits=4, output_dict=True)
ban_component_results.append({
    "Experiment": "Baseline BAN (Gated Attention)",
    "Accuracy": rep_base["accuracy"],
    "Macro Precision": rep_base["macro avg"]["precision"],
    "Macro Recall": rep_base["macro avg"]["recall"],
    "Macro F1-Score": rep_base["macro avg"]["f1-score"]
})

# %% [markdown]
# ### 2. No Attention
# The `Multiply()` attention layer is completely removed. Acoustic and textual projections are simply concatenated.

# %%
# =========================================================================
# EXPERIMENT 2: NO ATTENTION BAN
# =========================================================================
print("\n[Experiment 2] Training No Attention BAN...")
tf.keras.backend.clear_session()
gc.collect()

def build_ban_no_attention(num_classes, stats_dim, sent_dim):
    in_mfcc = layers.Input(shape=(Config.MAX_MFCC_LEN, Config.N_MFCC), name="in_mfcc")
    x_mfcc = layers.Conv1D(64, 3, activation='relu', padding='same')(in_mfcc)
    x_mfcc = layers.MaxPooling1D(2)(x_mfcc)
    x_mfcc = layers.LSTM(64)(x_mfcc)

    in_stats = layers.Input(shape=(stats_dim,), name="in_stats")
    x_stats = layers.Dense(32, activation='relu')(in_stats)
    x_stats = layers.BatchNormalization()(x_stats)

    x_audio_combined = layers.Concatenate()([x_mfcc, x_stats])
    x_audio_proj = layers.Dense(64, activation='relu')(x_audio_combined)

    in_text = layers.Input(shape=(sent_dim,), name="in_text")
    x_text = layers.Dense(64, activation='relu')(in_text)

    # Bypass attention scaling -> Direct Concatenation
    merged = layers.Concatenate()([x_audio_proj, x_text])
    x = layers.Dense(128, activation='relu')(merged)
    x = layers.Dropout(Config.DROPOUT)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=[in_mfcc, in_stats, in_text], outputs=outputs)
    model.compile(optimizer=optimizers.Adam(learning_rate=Config.LEARNING_RATE),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

no_att_model = build_ban_no_attention(num_classes=len(Config.DEFAULT_CLASSES), stats_dim=X_train_stats.shape[1], sent_dim=X_train_txt.shape[1])

no_att_model.fit(
    [X_train_mfcc, X_train_stats, X_train_txt], y_train,
    validation_data=([X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev),
    epochs=Config.EPOCHS, batch_size=Config.BATCH_SIZE, verbose=0
)

y_pred_no_att = np.argmax(no_att_model.predict([X_test_mfcc, X_test_stats, X_test_txt], verbose=0), axis=1)

print("\n--- Classification Report (No Attention BAN) ---")
print(classification_report(y_test, y_pred_no_att, target_names=Config.DEFAULT_CLASSES, digits=4))

rep_no_att = classification_report(y_test, y_pred_no_att, target_names=Config.DEFAULT_CLASSES, digits=4, output_dict=True)
ban_component_results.append({
    "Experiment": "No Attention BAN (Simple Fusion)",
    "Accuracy": rep_no_att["accuracy"],
    "Macro Precision": rep_no_att["macro avg"]["precision"],
    "Macro Recall": rep_no_att["macro avg"]["recall"],
    "Macro F1-Score": rep_no_att["macro avg"]["f1-score"]
})

# %% [markdown]
# ### 3. Cross-Modal Attention
# Uses `tf.keras.layers.Attention`. The acoustic features act as the *Query* to extract relevant context from the textual *Value*.

# %%
# =========================================================================
# EXPERIMENT 3: CROSS-MODAL ATTENTION BAN
# =========================================================================
print("\n[Experiment 3] Training Cross-Modal Attention BAN...")
tf.keras.backend.clear_session()
gc.collect()

def build_ban_cross_modal(num_classes, stats_dim, sent_dim):
    in_mfcc = layers.Input(shape=(Config.MAX_MFCC_LEN, Config.N_MFCC), name="in_mfcc")
    x_mfcc = layers.Conv1D(64, 3, activation='relu', padding='same')(in_mfcc)
    x_mfcc = layers.MaxPooling1D(2)(x_mfcc)
    x_mfcc = layers.LSTM(64)(x_mfcc)

    in_stats = layers.Input(shape=(stats_dim,), name="in_stats")
    x_stats = layers.Dense(32, activation='relu')(in_stats)
    x_stats = layers.BatchNormalization()(x_stats)

    x_audio_combined = layers.Concatenate()([x_mfcc, x_stats])
    x_audio_proj = layers.Dense(64, activation='relu')(x_audio_combined)

    in_text = layers.Input(shape=(sent_dim,), name="in_text")
    x_text = layers.Dense(64, activation='relu')(in_text)

    # Reshape for Keras Attention Layer (Requires 3D tensors: batch, steps, features)
    audio_reshaped = layers.Reshape((1, 64))(x_audio_proj)
    text_reshaped = layers.Reshape((1, 64))(x_text)

    # Formal Scaled Dot-Product Attention
    cross_attention_out = layers.Attention()([audio_reshaped, text_reshaped])
    cross_attention_flat = layers.Flatten()(cross_attention_out)

    merged = layers.Concatenate()([cross_attention_flat, x_audio_proj, x_text])
    x = layers.Dense(128, activation='relu')(merged)
    x = layers.Dropout(Config.DROPOUT)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=[in_mfcc, in_stats, in_text], outputs=outputs)
    model.compile(optimizer=optimizers.Adam(learning_rate=Config.LEARNING_RATE),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

cross_att_model = build_ban_cross_modal(num_classes=len(Config.DEFAULT_CLASSES), stats_dim=X_train_stats.shape[1], sent_dim=X_train_txt.shape[1])

cross_att_model.fit(
    [X_train_mfcc, X_train_stats, X_train_txt], y_train,
    validation_data=([X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev),
    epochs=Config.EPOCHS, batch_size=Config.BATCH_SIZE, verbose=0
)

y_pred_cross = np.argmax(cross_att_model.predict([X_test_mfcc, X_test_stats, X_test_txt], verbose=0), axis=1)

print("\n--- Classification Report (Cross-Modal Attention BAN) ---")
print(classification_report(y_test, y_pred_cross, target_names=Config.DEFAULT_CLASSES, digits=4))

rep_cross = classification_report(y_test, y_pred_cross, target_names=Config.DEFAULT_CLASSES, digits=4, output_dict=True)
ban_component_results.append({
    "Experiment": "Cross-Modal BAN (Scaled Dot-Product)",
    "Accuracy": rep_cross["accuracy"],
    "Macro Precision": rep_cross["macro avg"]["precision"],
    "Macro Recall": rep_cross["macro avg"]["recall"],
    "Macro F1-Score": rep_cross["macro avg"]["f1-score"]
})

# %% [markdown]
# ### 4. Textual Sentiment Masking
# The text inputs in the test set are explicitly zeroed out. Predictions are run using the previously trained Baseline BAN model.

# %%
# =========================================================================
# EXPERIMENT 4: TEXTUAL MASKING INFERENCE
# =========================================================================
print("\n[Experiment 4] Evaluating Baseline BAN with Masked Text...")

# Zero out the text modality for the test set
X_test_text_masked = np.zeros_like(X_test_txt)

# Predict using the base_model from Experiment 1
y_pred_masked = np.argmax(base_model.predict([X_test_mfcc, X_test_stats, X_test_text_masked], verbose=0), axis=1)

print("\n--- Classification Report (Masked Text BAN) ---")
print(classification_report(y_test, y_pred_masked, target_names=Config.DEFAULT_CLASSES, digits=4))

rep_masked = classification_report(y_test, y_pred_masked, target_names=Config.DEFAULT_CLASSES, digits=4, output_dict=True)
ban_component_results.append({
    "Experiment": "Masked Text BAN (Zeroed Text Branch)",
    "Accuracy": rep_masked["accuracy"],
    "Macro Precision": rep_masked["macro avg"]["precision"],
    "Macro Recall": rep_masked["macro avg"]["recall"],
    "Macro F1-Score": rep_masked["macro avg"]["f1-score"]
})

# %% [markdown]
# ### 5. Expanded Acoustic Kernel
# Broaden the receptive field of the initial 1D-Convolution layer by expanding the kernel size from `3` to `7`.

# %%
# =========================================================================
# EXPERIMENT 5: LARGE KERNEL BAN
# =========================================================================
print("\n[Experiment 5] Training Large Kernel BAN...")
tf.keras.backend.clear_session()
gc.collect()

def build_ban_large_kernel(num_classes, stats_dim, sent_dim):
    in_mfcc = layers.Input(shape=(Config.MAX_MFCC_LEN, Config.N_MFCC), name="in_mfcc")
    # Shift kernel size from 3 to 7
    x_mfcc = layers.Conv1D(64, 7, activation='relu', padding='same')(in_mfcc)
    x_mfcc = layers.MaxPooling1D(2)(x_mfcc)
    x_mfcc = layers.LSTM(64)(x_mfcc)

    in_stats = layers.Input(shape=(stats_dim,), name="in_stats")
    x_stats = layers.Dense(32, activation='relu')(in_stats)
    x_stats = layers.BatchNormalization()(x_stats)

    x_audio_combined = layers.Concatenate()([x_mfcc, x_stats])
    x_audio_proj = layers.Dense(64, activation='relu')(x_audio_combined)

    in_text = layers.Input(shape=(sent_dim,), name="in_text")
    x_text = layers.Dense(64, activation='relu')(in_text)

    attention_weights = layers.Dense(64, activation='sigmoid', name="text_guided_attention")(x_text)
    attended_audio = layers.Multiply(name="attended_audio")([x_audio_proj, attention_weights])

    merged = layers.Concatenate()([attended_audio, x_text])
    x = layers.Dense(128, activation='relu')(merged)
    x = layers.Dropout(Config.DROPOUT)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=[in_mfcc, in_stats, in_text], outputs=outputs)
    model.compile(optimizer=optimizers.Adam(learning_rate=Config.LEARNING_RATE),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

large_kernel_model = build_ban_large_kernel(num_classes=len(Config.DEFAULT_CLASSES), stats_dim=X_train_stats.shape[1], sent_dim=X_train_txt.shape[1])

large_kernel_model.fit(
    [X_train_mfcc, X_train_stats, X_train_txt], y_train,
    validation_data=([X_dev_mfcc, X_dev_stats, X_dev_txt], y_dev),
    epochs=Config.EPOCHS, batch_size=Config.BATCH_SIZE, verbose=0
)

y_pred_kernel = np.argmax(large_kernel_model.predict([X_test_mfcc, X_test_stats, X_test_txt], verbose=0), axis=1)

print("\n--- Classification Report (Large Kernel BAN) ---")
print(classification_report(y_test, y_pred_kernel, target_names=Config.DEFAULT_CLASSES, digits=4))

rep_kernel = classification_report(y_test, y_pred_kernel, target_names=Config.DEFAULT_CLASSES, digits=4, output_dict=True)
ban_component_results.append({
    "Experiment": "Large Kernel BAN (Conv1D size=7)",
    "Accuracy": rep_kernel["accuracy"],
    "Macro Precision": rep_kernel["macro avg"]["precision"],
    "Macro Recall": rep_kernel["macro avg"]["recall"],
    "Macro F1-Score": rep_kernel["macro avg"]["f1-score"]
})

# %% [markdown]
# ### Summary

# %%
# =========================================================================
# SUMMARY MATRIX OUTPUT
# =========================================================================
df_component_ablation = pd.DataFrame(ban_component_results)

print("\n" + "="*30 + " BAN COMPONENT ABLATION SUMMARY " + "="*30)
display(df_component_ablation.style.set_properties(**{'text-align': 'center'}).highlight_max(subset=["Accuracy", "Macro F1-Score"], color="darkred").format(precision=4))
